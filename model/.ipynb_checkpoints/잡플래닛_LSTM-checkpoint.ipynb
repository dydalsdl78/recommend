# %%
from collections import defaultdict
from collections import Counter

import torch.nn as nn
import torch
from torch.autograd import Variable
import torch.nn.functional as F

import random
import pandas as pd
import numpy as np

from eunjeon import Mecab
from tqdm import tqdm_notebook

# %% [markdown]
# # 데이터 불러오기

# %%
data = pd.read_csv(r"data\test_file.csv")
data
# Out:
#        링크 순서       기업   평점     산업분류 직원의 기업 추천율 직원이 전망하는 성장 가능성 이 기업의 CEO 지지율  \
# 0          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 1          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 2          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 3          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 4          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 5          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 6          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 7          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 8          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 9          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 10         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 11         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 12         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 13         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 14         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 15         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 16         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 17         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 18         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 19         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 20         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 21         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 22         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 23         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 24         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 25         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 26         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 27         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 28         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 29         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# ...      ...      ...  ...      ...        ...             ...           ...
# 98323     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98324     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98325     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98326     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98327     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98328     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98329     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98330     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98331     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98332     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98333     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98334     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98335     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98336     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98337     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98338     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98339     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98340     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98341     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98342     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98343     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98344     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98345     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98346     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98347     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98348     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98349     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98350     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98351     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98352     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
#
#        승진 기회 및 가능성  복지 및 급여  업무와 삶의 균형  ...  경영진  \
# 0              2.8      3.2        2.9  ...  2.2
# 1              2.8      3.2        2.9  ...  2.2
# 2              2.8      3.2        2.9  ...  2.2
# 3              2.8      3.2        2.9  ...  2.2
# 4              2.8      3.2        2.9  ...  2.2
# 5              2.8      3.2        2.9  ...  2.2
# 6              2.8      3.2        2.9  ...  2.2
# 7              2.8      3.2        2.9  ...  2.2
# 8              2.8      3.2        2.9  ...  2.2
# 9              2.8      3.2        2.9  ...  2.2
# 10             2.8      3.2        2.9  ...  2.2
# 11             2.8      3.2        2.9  ...  2.2
# 12             2.8      3.2        2.9  ...  2.2
# 13             2.8      3.2        2.9  ...  2.2
# 14             2.8      3.2        2.9  ...  2.2
# 15             2.8      3.2        2.9  ...  2.2
# 16             2.8      3.2        2.9  ...  2.2
# 17             2.8      3.2        2.9  ...  2.2
# 18             2.8      3.2        2.9  ...  2.2
# 19             2.8      3.2        2.9  ...  2.2
# 20             2.8      3.2        2.9  ...  2.2
# 21             2.8      3.2        2.9  ...  2.2
# 22             2.8      3.2        2.9  ...  2.2
# 23             2.8      3.2        2.9  ...  2.2
# 24             2.8      3.2        2.9  ...  2.2
# 25             2.8      3.2        2.9  ...  2.2
# 26             2.8      3.2        2.9  ...  2.2
# 27             2.8      3.2        2.9  ...  2.2
# 28             2.8      3.2        2.9  ...  2.2
# 29             2.8      3.2        2.9  ...  2.2
# ...            ...      ...        ...  ...  ...
# 98323          3.0      3.5        2.7  ...  2.7
# 98324          3.0      3.5        2.7  ...  2.7
# 98325          3.0      3.5        2.7  ...  2.7
# 98326          3.0      3.5        2.7  ...  2.7
# 98327          3.0      3.5        2.7  ...  2.7
# 98328          3.0      3.5        2.7  ...  2.7
# 98329          3.0      3.5        2.7  ...  2.7
# 98330          3.0      3.5        2.7  ...  2.7
# 98331          3.0      3.5        2.7  ...  2.7
# 98332          3.0      3.5        2.7  ...  2.7
# 98333          3.0      3.5        2.7  ...  2.7
# 98334          3.0      3.5        2.7  ...  2.7
# 98335          3.0      3.5        2.7  ...  2.7
# 98336          3.0      3.5        2.7  ...  2.7
# 98337          3.0      3.5        2.7  ...  2.7
# 98338          3.0      3.5        2.7  ...  2.7
# 98339          3.0      3.5        2.7  ...  2.7
# 98340          3.0      3.5        2.7  ...  2.7
# 98341          3.0      3.5        2.7  ...  2.7
# 98342          3.0      3.5        2.7  ...  2.7
# 98343          3.0      3.5        2.7  ...  2.7
# 98344          3.0      3.5        2.7  ...  2.7
# 98345          3.0      3.5        2.7  ...  2.7
# 98346          3.0      3.5        2.7  ...  2.7
# 98347          3.0      3.5        2.7  ...  2.7
# 98348          3.0      3.5        2.7  ...  2.7
# 98349          3.0      3.5        2.7  ...  2.7
# 98350          3.0      3.5        2.7  ...  2.7
# 98351          3.0      3.5        2.7  ...  2.7
# 98352          3.0      3.5        2.7  ...  2.7
#
#                                                       제목  \
# 0                       "관리만 하려하는 상위직급이 다수 사원 대리 과장은 적음"
# 1                   "변화가 없다. 근 10년동안 비슷한 프로젝트만 유지하고 있다."
# 2              "탄탄했던 회사 같음! 나쁘지 않아요! 복지좋고 편하게 다닐 수 있어요!"
# 3      "개발자와 기획자간의 괴리감이 크고 팀장과 팀원들과의 관계도 적대적인 분위기다. 줄...
# 4              "외국계 회사지만 실상은 국내 중소기업 분위기임. 합병이후 가치가 하락중"
# 5             "기존의 통신 서비스 사업 대신 새로운 사업을 추진하고 있지만 여의치 않음"
# 6                   "착하고 소심한 기업입니다. 공부밖엔 할 줄 모르는 모범생 느낌"
# 7              "개발 환경 좋고, 업계 기술력은 인정.\n다만 직급 높은 분들이 많아짐"
# 8      "IT기업치고는 보수적인 분위기 회사의 복지는 전혀 없다고 볼 수 있지만\n업무강도...
# 9      "통신사 협력사로서 예전에는 SKT라는 캐시카우가 있었지만 점점 볼륨이 줄고 있다....
# 10     "사회생활 몸담고 시작할만한 최소한의 조건을 준비한 회사.\n다만 성장이 정체된 듯...
# 11                       "개발자를 똥으로 아는 회사입니다. 맨날 외주만 강요함"
# 12     "개빌자로서 기술 향상에 초점을 둔다면 괜찮은 회사. 결국 한국에 있는 보통의 SI...
# 13     "신규사업 발굴에 실패하여 명맥만 유지되는 회사지만, 기존 사업이 튼튼하여 오래갈 ...
# 14                       "근무환경 나쁘지 않지만, 급여 수준이 업계 최저 임."
# 15                                "적은 인원이 많은 일을 해야하는 회사"
# 16                           "전문성보다는 그 때 그 때 필요한 일을 한다."
# 17     "개발자들이 경력 쌓기 좋은곳.\n서버와 클라이언트를 동시에 개발하면서 배우는 개발...
# 18                           "이동통신 사업 특성상 회사 수익이 안정적인 편"
# 19                    "부서 마다 차이가 있으나 개발자로서 일하기 나쁘지 않은 곳"
# 20                                "여러가지 복지가 좋으나 딱딱한 분위기"
# 21                  "복지가 괜찮은편이나 회사가 너무 노후함 심각한 역피라미드 구조"
# 22                   "부서마다 다르지만 대체로 다양한 개발 경험을 쌓을 수 있다."
# 23       "모험을 하지 않는 기업 문화로 안정적인 듯 보이나 결굴 조금씩 꺼져가고 있는 불씨"
# 24                     "개발자에 대한 대우가 좋지는 않으며 군대식 문화에 익숙함"
# 25      "오래다닌 사람이 참..... 많은 회사. 그 이유는!???? 그나마 복지 등은 좋음"
# 26                   "적당히 다니기 좋은 곳이다\n큰 꿈이 없는 사람에게 좋은 곳"
# 27                  "가족같은회사 경쟁없는회사 편한회사\n장점이자 단점이 분명한회사"
# 28                   "프로젝트를 접해보고 배울 수 있음, 정규직 계약직 차별 있음"
# 29     "실력있는 개발자가 많아 배울점도 많고 회사 복지도 괜찮은편. 업무는 복불복이 심하...
# ...                                                  ...
# 98323        "영업이 적성에 맞으면 오세요. 최근 외환은행과의\n합병으로 분위기 어수선함"
# 98324  "해외지점이여서 그랬는지는 모르나 일과 개인생활의 균형이 잘 맞추어진 삶을 살 수 ...
# 98325      "당시 외환은행과의 합병 후 통합 문제가 이슈여서 회사 내외부적으로 혼란스러웠음"
# 98326                   "외환은행과의 합병으로 앞으로 더 개선될 것이 기대됩니다"
# 98327  "전형적인 한국 금융권 조직문화를 가지고 있고 , 당연히 영업이 아주 중요한 업종이...
# 98328                 "외환은행과의 합병으로 앞으로의 성장성이 더욱 기대되는 은행"
# 98329  "기업문화가 보수적이고 본부는 회의준비가 많은편이다.\n대체로 연령대가 높아서 말한...
# 98330                  "인건비 절약해서 이익내는 회사. 뚜렷한 장점이 없는 은행"
# 98331          "타 은행에 비해 영업 압박이 덜한편, 여성이 많아 분위기가 여성적이다."
# 98332          "외환은행과 통합되면서 향후 전망은 좋으나 지금은 상당히 어수선한 분위기"
# 98333          "타행은 조직내 수직적 문화가 심하다고 하는데, 그런건 조금 덜한거 같음"
# 98334  "은행 본부의 분위기를 파악하는데는 도움이 되지만, 실직적인 은행업에 대해 배울 기...
# 98335                   "영업에 자신있으면 오세요. 영업력만 있으면 괜찮은 회사"
# 98336          "개인주의가 은행업 중에서 심한 회사. 조직의 체계가 다소 미약한 회사."
# 98337                "업무시간이 길고 강도가 높은데비해 급여수준이 낮아서 아쉽다."
# 98338   "타 은행과 크게 다르지 않으며 외환 은행과 합병으로 향후 방향성이 어떻게 될지 모름"
# 98339                    "업무강도는 쎄지만 그래도 은행원이라 연봉은 높은 편."
# 98340         "직원 1인당 업무량 과다하게 배분. 직원들 피로도 누적~ 실적강요로 피곤"
# 98341  "복지 좋고 연봉 좋고, 연봉 높은 만큼 일 또한 많다. 윗사람이 누가 걸리느냐가 ...
# 98342                         "발전 가능성이 있는 한국 대표 은행 중 하나"
# 98343                          "은행들 중에서는 탑급은 아니지만 괜찮은 곳"
# 98344  "여성이 다니기 좋은 직장. 하는일이 복잡하고 어려운 일은 아닌데. 단지 처리해야 ...
# 98345                         "힘든만큼 돌려받을 수있는 회사라고 생각합니다"
# 98346           "저는 영업점 근무는 아니라 그런지...\n부서 근무는 매우 좋습니다."
# 98347   "어떤 은행보다도 좋은 회사 분위기를 가지고 있으며 서로서로 협력하여 도와주는 분위기"
# 98348           "업계 중 연봉은 타은행대비 보통이나 잘하면 승진및 교육기회가 있는 곳"
# 98349         "가장효율적인 조직이며 위기에 강한은행 끝까지 마지막까지 살아남을 은행이다"
# 98350         "합병으로 인해 성장성이 돋보이는 회사임. 앞으로 두 회사의 시너지가 기대"
# 98351            "적당한 수준의 연봉과 적당한 수준의 개인생활을 유지하고 싶다면 추천"
# 98352                       "매일 몰려오는 손님들을 상대할 수 있는멘탈 필요"
#
#                                                       장점  \
# 0         10년차 정도면 it 중견기업 2~3년차 연봉에 맞먹음\n지원부서 대우가 높을수있음
# 1              자유로운 분위기, 타 IT 회사에 비해 경직되지 않고 근무를 할 수 있다.
# 2      사람들이랑 사이가 좋아서 즐겁게 다녔음 / 비품을 많이 사용할 수 있어서 좋았음\n...
# 3      해마다 복지카드가 나오고 원하는대로 쓸 수 있다. 연차나 휴가, 칼퇴에 대해 눈치보...
# 4                      사무용품 업계 1위업체. 워라벨은 보장 됨.연차사용 제약없음
# 5      직원들이 대체로 모난 사람이 없음. 자신의 할일만 하면 딱히 터치는 없는편. 프로젝...
# 6                인간적이고, 사람을 존중하는 문화가 있음. 개인의 사정을 이해하고 배려
# 7      복리후생 좋고, 건의사항 받아주려는 노력이 있음.\n콘도, 해외체험학습, 매년 인센...
# 8      전체적으로 업무에 대한 압박이 심하지 않은편 끈끈한 분위기는 아니지만\n개인적인 부...
# 9               어느정도 체계는 잡혀 있는 모습을 보이며, 회식 문화가 존재하지 않는다.
# 10      일단 임원들 인성은 매우 좋은 듯.\n복지가 괜찮고, 야근없는 분위기라 워라벨이 가능.
# 11     그냥 하는일 없이 월급은 걱정은 당분간 없을것 같습니다. 그냥 눌러앉아 있기 좋음\...
# 12     복지가 좋다. 연차 사용에 눈치 볼 필요 없다. 본인 역량 기준하에 충분히 워라벨을...
# 13                    야근이 많지 않고, 회식도 거의 없으며, 업무강도가 높지 않다
# 14                   연차를 눈치 보지 않는 것 외에는 딱히 장점을 찾아 보기 어려움
# 15     개발 외의 업무가 많지는 않다.\n개발자로서 성장할 여건은 된다.\n최신기술을 사용...
# 16         도서구입 및 교육에 대해서는 회사 지원으로 받을 수 있다. 일이 바쁘지 않다면..
# 17     비슷한 규모의 기업들에 비해 복지가 굉장히 좋다.(금전적 복지)\n사생활에 대한 터...
# 18     SKT에서 시작한 기업이라 복지가 비슷함\n해외 여행 및 핸드폰 지원금, 무이자 전...
# 19     연 복지비가 쎈편이다. 사용처를 가리지 않고 230정도 나옴. 고용문제에 관해 안정...
# 20     입사하면 여러가지 복지 혜택을 누를수 가 있어 좋고 출산을 하면 더 많은 혜택을 누...
# 21              복지는 좋다 회사 다니는 동안은 병원비나 그 외 돈걱정은 딱히 할게 없음
# 22         기업 규모에 비해 복지가 잘 되어 있고, 어느정도 유연한 사고가 통용 되는 회사.
# 23          복지비가 꽤 있고 오래된 기업문화에서 점점 자유로운 문화로 바뀌어가고 있는 시점
# 24     야근시 택시비 지원, 야근식대 7000원 제공, 병원 건강검진 지원, 연봉외 복지비...
# 25               오래 다니면 일단 회사가 직원 눈치를 봄. 직원은 회사 눈치 안봐도 됨
# 26                 일과 삶의 균형을 중시하는 사람에게 좋다\n크게 강요하는 것이 없다
# 27               의리가 있고 사람들이 다 착함...............\n,,,,,,
# 28                       칼퇴, 개인 생활에 터치 없음\n(팀별로 다를 수 있음)
# 29     실력있는 선배들이 많아 본인 노력에 따라서 많은것을 배울 수 있고 복지도 괜찮은편....
# ...                                                  ...
# 98323      여성에 대한 복지 좋음. 타 시중은행과 마찬가지로 급여 및 육아휴직 제도 good
# 98324  업무 분담이 확실하여 자기계발에 도움이 되긴 하지만 어떤 업무냐에 따라 상황이 다를...
# 98325  합병으로 인해 규모 면에서 많이 커졌다는 장점이 분명히 존재. 타 직종에 비해 어느...
# 98326                  휴가나 출산휴가를 눈치 안보고 쓸 수 있다는 점이 가장 좋음
# 98327  회식 문화는 1차에서 간결히 끝내는 것으로 조직문화가 많이 바뀌고 있고 권장 하고 ...
# 98328  외환은행과의 합병으로 기존 하나은행에 비해서는 연봉이 상승되었던 경향이 있으며 은행...
# 98329  회사체계에 대해 일배우기가 좋다.\n업무강도가 쎈편은 아니여서 누구나 쉽게 배울 수...
# 98330             조직 규모가 크고 통합 후 분위기 좋음. 김수현 광고 후 이미지 상승
# 98331  여성이 많은 부서에서 근무해서 그런지(마케팅 관련 부서), 사내 분위기가 좋고 회식...
# 98332  은행의 가장 큰 장점인 복지와 높은 연봉, 또한 외환은행과 합병되면서 향후 전망이 좋다.
# 98333                    일년에 십오영업일은 웬만하면 눈치안보고 휴가 쓸 수 있음
# 98334                비교적 자유로운 분위기, 친절한(?)직원들, 나름 긴 점심시간?
# 98335  영업을 끝장나게 배울수있음. 외환은행과의 합병으로 연봉도 오르고 기회가닿으면 외환은...
# 98336  근무 분위기가 은행업 중에서 자유로운 편입니다. 근무 분위기가 과도하게 경직되어 있...
# 98337                     직원들이 참여할수있는 사내행사에 투자를 많이 하는편이다
# 98338  직원들과 소통 원활 가족같은 분위기\n육아휴직 및 교육비 의료비 콘도사용이나 연차사...
# 98339           비교적 사내 분위기는 자유로운 편. 외환과 합병으로 성장가능성 무궁무진.
# 98340  15일의 연차사용 의무[연차비용 충당 안하고자 하는 기업의도지만, 직원들은 리프레시...
# 98341  연봉이 높음\n상사를 잘못 만나도 타 지점 발령날 때까지 버티면 됨\n주말, 공휴일...
# 98342  외환은행과의 통합으로 인하여 새로운 발전 잠재력을 창출할 기반을 마련함\n이로인하여...
# 98343                   연차사용에 무리가 없다. 본사 근무라면 퇴근이 늦지 않다.
# 98344  하는일에 비해 연봉이 적지 않다. 여직원이 많아 분위기가 딱딱하지 않다. 회식문화도...
# 98345  자유로운 분위기와 수평적인 조직문화로 다소 딱딱한 문화보다는 열린 분위기, 실적에 ...
# 98346              복지가 좋고 직원들간에 화목하고 행복합니다. 그리궁 음 안정적이죠.
# 98347  안정적이며 금융권에 대한 지식도 기본적으로 쌓아지며 경제 또한 쉽게 관찰하고 이해할...
# 98348                  역동적인 문화로 마케팅 ㅡ좋아하면 추천입니다 연봉은 보통수준
# 98349   외환은행 통합으로 글로벌과 자산관리에 강점이 있음\n철저한 비용관리로 리스크관리가 우수
# 98350  안정적인 급여와 은행원이라는 것에 대한 자부심을 느낄 수 있음 여자행원들에 대한 복...
# 98351  개인 휴가가 보장되어 있고 타 은행에 비해 비교적 퇴근이 빠름. 분위기도 뭔가 혁신...
# 98352  복지하나는 하나은행이 짱, 주말이 보장되고 현금성 복지가 있음, 전세자금 대출도 장...
#
#                                                       단점  \
# 0                   경직된 상하관계\n명령하달식 커뮤니케이션\n대우개선에대한 희망고문
# 1            성장세가 없다. 기존의 사업만 고수하고 신규사업에 대해 투자가 소홀한 편이다.
# 2      집에서 출퇴근길이 멀어서 힘들었음/ 딱히 단점이 없었던 회사\n2년 열심히 다니고 ...
# 3      단, 일이 많다. 팀마다 분위기가 상이하고 줄을 잘 서야한다. 야근이 강요되지 않지...
# 4                   연봉이 현저히 작음. 합병이후 시스템 이나 프로세스 통합이 미비함
# 5      통신망에서는 현재의 트렌트를 쫒아가지 못 하고 있고, 투자를 하지 않고 성과만 얻으...
# 6      사업적 결정을 하지 못하고 기준이 없음. 예전에 쉽게 수익을 내던 시절의 문화에서 ...
# 7      차/부장 직급자들이 점점 많아지고, 정치적인 분위기가 스물스물 올라오는 분위기.\n...
# 8      전혀 없다고 볼수있는 회사복지. 복지는 전혀 없다고 보면된다. 많은 사람들이 계약직...
# 9            타이트한 인력관리, 하지만 이건 개인의 업무 능력에 따라 장점이 될 수 있다.
# 10     신사업실패로 SI가 주인 부서는 바쁘기만하고 노잼.\n통신사 납품으로 연명.\nIT...
# 11             보고도 많고, 의심도 많아서 감시를 많이합니다. 개발관련한 교육도 안보내줌
# 12     차 부장이 너무 많다. 팀장,부장 들이 임원 눈치를 심하게 본다. 올라갈수록 힘들어...
# 13          역피라미드가 심하여 낮은 직위의 직원들이 힘들고, 회사 발전 가능성이 매우 낮다
# 14     급여 수준이 업계 평균이아하며, 경영진 마인드가 좋지 않음. 휴가 연차등 직원 복리...
# 15     시도 때도 없이 갑으로 부터 전화를 받게 된다.\n통신 개발 외 파트로 빠질 경우 ...
# 16     연봉이 낮다. 인상률도 높지 않다.\n미래 성장성도 낮은 편이다. 미래에 대한 투자...
# 17     역피라미드 구조이다.(윗사람들이 너무 많음)\n사원, 대리급들이 별로 없다.\n사업...
# 18                 회사의 노령화로 인해 시니어 개발자의 부재가 큼\n수직적인 조직문화
# 19               보고 문서 작업이 너무 많고 굉장히 수직적임. 요즘 하락세를 달림...
# 20             조직문화가 딱딱한 부분이 있음, 사무실 분위기는 조용하고 도서관 같은 느낌
# 21     역피라미드구조가 너무심해서 팀에 사원 대리가 거의없다 과장 보다 차장이 더많고 차장...
# 22     부서에 따라서 호불호가 갈리며, 중소기업이라는 한계상 연봉이 크지 않다는 점이 가장...
# 23     모험하지 않는 기업 문화로 새로운 시도를 잘 안함. 요구사항을 잘 안들어주는데 그만...
# 24     개인에게 바라는 능력치가 매우 크고 일에대한 해결보다 책임을 추궁하고 일에 포커스를...
# 25     신규 입시자가 3년을 버티지 못함. 왜 그런지 위는 관심 없음. 그저 나가는 사람이...
# 26                자기 발전 하기 어렵다\n회사가 너무 군대식이다\n판단이 너무 느리다
# 27          의리가 있다보니 경쟁심한 it업계에서 살아남기힘듬!!!!!!!!!!!!!!!!!
# 28     다이렉트로 일 처리 해도 될 것을 하나하나 돌려가며 일을 처리하여 일의 속도가 떨어...
# 29     회사가 점점 커가기보다는 점점 정체되어가고있다. 새로운 제품을 미리 만들어 미래를 ...
# ...                                                  ...
# 98323  영업실적 압박이 심하며, 특히 최근 경영진의 무리한 목표 설정으로 인해 직원들의 스...
# 98324  해외지점은 (상해지점) 아직 규모가 크지 않기 때문에 배움에 있어서 한계가 있을 수...
# 98325  보수적인 은행 특성상 굉장히 경직적인 문화가 많음, 어설픈 사내 문화 프로그램은 별...
# 98326            지점에 따라 다르지만 실적압박을 받을 수 있어 스트레스를 받을 수 있음
# 98327  어딜가나 부서by부서, 상사by상사 이지만, 전반적으로 상하 관계가 매우 확실하며,...
# 98328  2016년 들어서 은행 연봉 삭감에 관한 이야기들이 점점 더 많이 나오고 있으며 빡...
# 98329  출근시간이 회의준비로 대체로 일찍 와야하고 퇴근역시 마찬가지이다.\n잡일이 대다수....
# 98330              동종업계 대비 뚜렷한 장점과 특징이 없음. 전산 통합 후 혼란 예상
# 98331  은행권이라 영업의 압박은 어느 정도 있는 듯.... 영업점에 비해 본사에서 근무하면...
# 98332  높은 영업압박과 타 시중은행보다 상대적으로 낮은 연봉과 복지, 또한 야근도 만만치 ...
# 98333  실적압박이 정말 너무 심하고, 직원이 인사발령 나도 어지간해선 후임이 충원 잘 안돼...
# 98334                한국기업의 공통된 문제인 상사눈치보기, 융통적이지 못한 일처리?
# 98335            은행특유의 야근문화. 주말은 있다지만 글쎄... 주말에도 지인영업 필수
# 98336   조직에 의한 영업력이 약하고, 개인별 영업력에 의존하는 듯합니다. 업무량이 과다합니다.
# 98337             과반수이상의 직원들이 야근을하며, 타 은행과 비교하여 급여수준이 낮음
# 98338  지점이라면 실적 압박은 당연한것이긴하나 압박강도 꽤 있음 정부 정책에 따라 업무 영...
# 98339  업무강도가 많이 쎈 편이고 야근이 거의 생활화 돼있음.은행원이라고 정시 퇴근을 생각...
# 98340  출근시간 이르고 퇴근시간 늦음. 시간외 근무 시스템도 지점에 따라 다르기에 성향이 ...
# 98341  업무 많음(실적)\n소문 조심\n입 조심\n감정노동 다반사\n철저한 서비스직\n점심...
# 98342  영업 압박이 강하고, 문어발적으로 사업을 늘리지만 영 신통치 않음\n또한 연봉이 타...
# 98343  인턴을 기준으로 보았을때 아이디어만 빼먹는듯한 느낌을 받으며 분위기가 완전히 경쟁적...
# 98344  일이 어려운건 아닌데. 처리해야 할 업무가 많다. 영업시간중에는 자리를 비우기 어렵...
# 98345  업무 과중이 많고 실적압박이 심함 조직원들의 경쟁을 부추겨 조직원들의 스트레스도 상...
# 98346           회식이... 술을 좋아하시면 많습니다. 아.. 그냥 많을수 있습니다...
# 98347  은행특성상 야근이 많으며 각부서별로 고충이 있겠지만 특히 어느한부서가 심하게 야근이...
# 98348                     빡센문화 야근을 밥먹듯이하는사람많음 승진과열경쟁 부추김
# 98349                  다양한 은행이 모인만큼 문화가 다르지만 성과로 평가하는 은행
# 98350        과도한 업무와 합병에 따른 전산처리가 아직 미비한점 인사제도에 대한 개선 필요
# 98351  늘 그 자리에 머무는 연봉과 출신의 한계로 인한 넘사벽이 존재. 그리고 일단 비전없...
# 98352  진상고객들 처리가 최대의 단점. 고객들의 민원을 이겨낼 수 있는 멘탈관리와 성실함이...
#
#                                              경영진에게 바라는 점 각 리뷰 평점         직무  \
# 0                      낙하산 및 고인물의 교체 필요\n실무자에 대한 대우개선 필요       1     IT/인터넷
# 1                               기존 사업보다는 신규사업에 투자해야 할 시기       3     IT/인터넷
# 2               경영진에게 크게 바라는점은 없음 !! 그렇게 심한 터치가 없어서 편했나봄       2     IT/인터넷
# 3                 신규 사업에 대한 투자는 좋지만 사람도 돌보는 회사가 됐으면 좋겠다.       3     IT/인터넷
# 4           직원들에 대한 복지나 연봉을 개선하여 동기부여가 될 수 있게 해줬으면 하는 바람       2  경영/기획/컨설팅
# 5      기존 사업도 투자를 해야 발전이 있는 법인데 신규 사업에만 투자하지 말고 기존 사업...       1     IT/인터넷
# 6                                목표를 확실하게 하고 그에 맞는 결정 필요       3     IT/인터넷
# 7       기존사업 활성화에 더욱 중점을 두고, 신규사업도 사업성 잘 판단하여 진행하였으면 좋겠음       2     IT/인터넷
# 8      기존의 아이템 한계를 인정하고 새로운 시장을 적극적으로 개척하려는 경영진의 의지가 ...       3     IT/인터넷
# 9           비젼을 구성원에게 제시해주세요. 믿고 따라갈 빛이 보여야 힘이 날 것 같습니다.       2     IT/인터넷
# 10     IT로 성공하는 업체들이 개부럽다.\n계속 SI납품으로 연명하는 회사로 남을 것인지...       1     IT/인터넷
# 11                      이랬다 저랬다, 대기업의 눈치를 봐가며 사업하는게 한심함.       3     IT/인터넷
# 12     직원들의 이야기를 자신의 기준에 듣지 말고 직원의 기준으로 들엇으면. 듣고 나면 흘...       2     IT/인터넷
# 13       IT기업답게 변화하였으면 좋겠다. IT기업이 맞나 싶을정도로 구닥다리 경영이 심하다.       3     IT/인터넷
# 14     직원들 요구사항을 철저히 경청하고, 성의 있는 협의 자세를 가지기 바라며, 제품 로...       2     IT/인터넷
# 15     일을 그렇게 많이 시키면 연봉을 많이 주세요.\n적은 인원으로 일을 많이 시키니까 ...       1     IT/인터넷
# 16                조직간에 협업이 매우 부족하다.\n복리후생이 10년 넘게 그대로이다.       3     IT/인터넷
# 17     실질적으로 일하는 사원, 대리급들이 나가지 않게 조치가 필요합니다.\n실무에 투입시...       2     IT/인터넷
# 18                               시스템적으로 회사 문화 쇄신이 필요해 보임       3     IT/인터넷
# 19     연구개발본부 군대 문화는 임원 혼자서 바꿀 수 있는게 아닌듯. 이미 너무 오랜기간 ...       2     IT/인터넷
# 20     오래된 기업문화를 한번에 바꿀수는 없지만 조금더 창의적인 기업문화로 변화 되었으면 합니다       1     IT/인터넷
# 21     조금씩이라도 개선하는쪽으로 방향을 잡길 바랍니다. 지금상태로는 점차적인 하락세를 벗...       3        디자인
# 22     호황 때 축적했던 자본을 투자실패로 대부분 날린 만큼, 이를 만회하여 직원들에게 만...       2     IT/인터넷
# 23          매년 평가에 상관도 평가할 수 있게 하여 더 객관적인 평가가 이루어질 수 있도록       3     IT/인터넷
# 24                 공정한 평가가 필요하며, 실제 업무 기여도에따른 연봉 인상이 필요함       2     IT/인터넷
# 25                     왜 있는 사람은 계속 있고 새로운 사람이 나가는지 알길...       1     IT/인터넷
# 26             신기술이나 자체 기술력을 보유해야 할 것 같다\n신속한 의사결정이 필요하다       3     IT/인터넷
# 27                       전문경영인 체제로 가야할듯\n신규인력채용이 많이 필요할듯       2     IT/인터넷
# 28            개인주의 성향이 강한 것 같아 전체적으로 단합할 수 있는 기회가 많았으면 함       3     IT/인터넷
# 29     선행기술과 사람에 대한 투자가 필요합니다. 업무도 역량도 복지도 정체되어있는점에대해...       2     IT/인터넷
# ...                                                  ...     ...        ...
# 98323                  직원들의 불만을 듣고 비현실적인 영업목표를 수정했으면 좋겠음       4      금융/재무
# 98324  합리적인 복지 및 보상체계를 마련해 주었으면. 해외지점을 잘 이끌어줄 수 있는 윗계...       2      금융/재무
# 98325                        보수적인 은행 특성상 굉장히 경직적인 문화가 많음       3      금융/재무
# 98326                    비정규직에 대한 처우 개선이 필요하다고 생각 합니다 저는       2      금융/재무
# 98327  하드웨어 적으론 성장하고 커가고 있는 것 같으나(합병 등), 그만한 직원들에 대한 ...       3      인사/총무
# 98328  힘든 경제 상황 속에서도 채용을 늘리려 하고 복지를 향상시키려는 노력이 참 좋은 것...       4      금융/재무
# 98329  보수적인 문화가 개선되면 좋을 것 같습니다.\n지방일경우 연령대가 높아서 연고지를 ...       2      인사/총무
# 98330            전산 관리에 더 투자했으면...불안정한 시스템으로 업무 효율이 떨어진다       3      금융/재무
# 98331  은행권의 공통적인 문제점인 영업 압박...... 영업 압박이 줄어들었으면\n그치만 ...       2   마케팅/시장조사
# 98332                 높은 영업압박만 없으면 위의 단점들이 대부분 해결될 거라 본다       3      금융/재무
# 98333   직원들한테 실적압박좀 그만하고, 실적 압박할 시간에 좋은 상품 개발에 좀 더 노력할 것       4      금융/재무
# 98334                  적극적으로 인턴에게 일할 수 있는 기회를 부여했으면 좋겠다.       2      금융/재무
# 98335             은행업자체가 사장돼가는 느낌. 영업으로 메꿀수 있는 거 같진 않습니다       3      금융/재무
# 98336  조직에 의한 영업력 제고가 필요하다고 생각합니다. 조직의 체계를 조금더 체계화하면 ...       2      금융/재무
# 98337          외부에 보여지는것에만 너무 집중하지말았으면 하며 회의가 너무 빈번하고 길다       3  경영/기획/컨설팅
# 98338      제살 깎아 먹기 식의 실적 압박이 없어야 하며 수익이\n큰 기업영업에 집중이 필요       4      금융/재무
# 98339                           좀 더 경쟁력을 갖춘 마케팅이 필요해 보임.       2      금융/재무
# 98340  직원에 대한 제대로된 보상체계가 필요함. 회사에 대한 자긍심을 키워줄 수 있는 교육...       3      금융/재무
# 98341  타 기업과는 다르게 합리적인 복지혜택과 연봉이지만 그만큼 업무 또한 많은 곳 앞으로...       2      금융/재무
# 98342  불필요한 문어발식 사업확장을 하지말고 본인들이 잘하는 PB분야의 역량을 강화하고 기...       3      금융/재무
# 98343            신입이 들어오자마자 영업으로 내보내면 퇴사율이 높아질수 밖에 없습니다.       4      법률/법무
# 98344  이제 영업점 업무의 한계가 분명하기 때문에 사업구조 재편이 필요하다.새로운 상품개발...       2      영업/제휴
# 98345      실적보다는 다양한 사업플랫폼으로 다각화하는 하나금융그룹으로 성장할 수 있기바랍니다       3      금융/재무
# 98346       음 요즘 비용절감 많이 강조하시는데\n필요한 곳만 비용절감 하셨으면...합니다.       2     IT/인터넷
# 98347       이후 온라인은행이 더욱더 개발되면 현존하는 은행들과의 차별화된 강점을 설립해야함       3   서비스/고객지원
# 98348            야근을최소화하고 경쟁과 영업압박을 너무 주지않아야 임직원들이 버팀...       4      금융/재무
# 98349  단기실적 보단 지속가능 경영의 실현이 필요할때\n통합에 관한 제도 등의 결정은 빠르...       2      금융/재무
# 98350            합병 시너지를 행원들까지 누릴 수 있게 인사제도 개선이 필요해 보입니다       3      금융/재무
# 98351                               개인과 기업을 구분하지 말고 대우하길       2      금융/재무
# 98352  영업압박에 대한 부담감이 낮았으면 좋겠고, 은행원들의 고충을 좀 더 면밀하게 살펴서...       3      금융/재무
#
#       재직상태  지역 리뷰 좋아요 개수
# 0      전직원  경기         0
# 1      현직원  경기         0
# 2      전직원  경기         0
# 3      전직원  서울         0
# 4      전직원  서울         0
# 5      현직원  경기         1
# 6      현직원  경기         4
# 7      현직원  경기         2
# 8      전직원  경기         1
# 9      현직원  경기         2
# 10     현직원  경기         2
# 11     전직원  경기         1
# 12     전직원  경기         0
# 13     현직원  경기         0
# 14     전직원  경기         0
# 15     전직원  경기         0
# 16     현직원  경기         1
# 17     전직원  경기         0
# 18     전직원  경기         0
# 19     전직원  경기         0
# 20     전직원  경기         1
# 21     전직원  경기         1
# 22     현직원  경기         0
# 23     현직원  경기         1
# 24     현직원  경기         2
# 25     전직원  경기         1
# 26     전직원  경기         0
# 27     현직원  경기         0
# 28     전직원  경기         0
# 29     현직원  경기         0
# ...    ...  ..       ...
# 98323  현직원  서울         0
# 98324  전직원  해외         0
# 98325  전직원  서울         0
# 98326  전직원  서울         0
# 98327  전직원  서울         0
# 98328  전직원  서울         0
# 98329  전직원  충남         0
# 98330  전직원  충남         0
# 98331  전직원  서울         0
# 98332  전직원  대전         0
# 98333  현직원  서울         0
# 98334  전직원  서울         0
# 98335  현직원  서울         0
# 98336  전직원  서울         1
# 98337  전직원  서울         0
# 98338  현직원  서울         0
# 98339  전직원  서울         0
# 98340  전직원  서울         0
# 98341  전직원  서울         0
# 98342  전직원  충남         0
# 98343  전직원  서울         0
# 98344  전직원  서울         0
# 98345  현직원  경기         0
# 98346  현직원  서울         1
# 98347  전직원  기타         0
# 98348  전직원  서울         0
# 98349  현직원  서울         0
# 98350  현직원  서울         0
# 98351  전직원  서울         0
# 98352  현직원  서울         1
#
# [98353 rows x 21 columns]

# %%
# 데이터 순서 섞기
# data=data.sample(frac=1)
# data=data.reset_index(drop=True)

# %%
label = pd.read_csv(r"label.csv", names=['기업','label'] )
label['label'] = label['label'].astype(int) 
label
# Out:
#                         기업  label
# 0                   유엔젤(주)      1
# 1                  조이시티(주)      1
# 2                  중소기업연구원      4
# 5                  텔코웨어(주)      1
# 7                 평화홀딩스(주)      2
# 10               한국야쿠르트(주)      2
# 17                 보령제약(주)      2
# 26                  (주)벡스코      4
# 27                   (주)삼호      2
# 31                   (주)유젠      1
# 35                 가온전선(주)      2
# 36                 국립현대미술관      4
# 38           담코로지스틱스코리아(주)      3
# 40               도레이케미칼(주)      2
# 43    롯데지알에스(주) 티지아이프라이데이스      1
# 44            미원스페셜티케미칼(주)      2
# 45               버버리코리아(주)      3
# 46              비지에프리테일(주)      1
# 48                  삼양사(주)      2
# 51              아지앙스코리아(주)      3
# 52                에이앤아이(주)      1
# 55              에프에이모스트(주)      1
# 58                 잇츠스킨(주)      1
# 60                 저축은행중앙회      0
# 67       한국에머슨프로세스매니지먼트(주)      3
# 68              한국에이브이엘(주)      3
# 71            한국청소년상담복지개발원      4
# 75                 롯데건설(주)      2
# 77                 삼진제약(주)      2
# 97              리즘인터랙티브(주)      1
# ...                    ...    ...
# 1131             한국직업능력개발원      4
# 1132             한미정밀화학(주)      2
# 1133              현대백화점(주)      2
# 1139                리치빔(주)      1
# 1142            수산업협동조합중앙회      0
# 1145            에스엔패션그룹(주)      1
# 1149        제이티인터내셔널코리아(주)      3
# 1151              코오롱제약(주)      2
# 1153             한국생명공학연구원      4
# 1154            (재)대구테크노파크      4
# 1155                (주)녹십자      2
# 1156               (주)리틀팍스      1
# 1158             라이온코리아(주)      2
# 1160      아웃백스테이크하우스코리아(유)      1
# 1161             에스케이건설(주)      2
# 1164       에이치앤엠헤네스앤모리츠(주)      3
# 1167            코오롱플라스틱(주)      2
# 1169              한국교육방송공사      4
# 1172         (주)네모파트너즈에스씨지      3
# 1174             (주)케이티넥스알      1
# 1176              (주)트랜드메카      1
# 1180                마더텅(주)      1
# 1181             메타넷글로벌(유)      3
# 1184          씨제이푸드빌(주) 빕스      1
# 1186           에스큐아이소프트(주)      1
# 1189               충북대학교병원      4
# 1190           코오롱인더스트리(주)      2
# 1196          (주)스마일게이트게임즈      1
# 1202                 벽산(주)      2
# 1204           쌤소나이트코리아(주)      3
#
# [480 rows x 2 columns]

# %% [markdown]
# # 기업의 리뷰마다 labeling 해주기

# %%
total_data = pd.merge(data, label , on="기업", how='left')
total_data
# Out:
#        링크 순서       기업   평점     산업분류 직원의 기업 추천율 직원이 전망하는 성장 가능성 이 기업의 CEO 지지율  \
# 0          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 1          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 2          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 3          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 4          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 5          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 6          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 7          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 8          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 9          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 10         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 11         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 12         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 13         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 14         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 15         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 16         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 17         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 18         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 19         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 20         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 21         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 22         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 23         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 24         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 25         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 26         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 27         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 28         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 29         0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# ...      ...      ...  ...      ...        ...             ...           ...
# 98323     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98324     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98325     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98326     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98327     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98328     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98329     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98330     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98331     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98332     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98333     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98334     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98335     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98336     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98337     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98338     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98339     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98340     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98341     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98342     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98343     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98344     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98345     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98346     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98347     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98348     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98349     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98350     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98351     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98352     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
#
#        승진 기회 및 가능성  복지 및 급여  업무와 삶의 균형  ...  \
# 0              2.8      3.2        2.9  ...
# 1              2.8      3.2        2.9  ...
# 2              2.8      3.2        2.9  ...
# 3              2.8      3.2        2.9  ...
# 4              2.8      3.2        2.9  ...
# 5              2.8      3.2        2.9  ...
# 6              2.8      3.2        2.9  ...
# 7              2.8      3.2        2.9  ...
# 8              2.8      3.2        2.9  ...
# 9              2.8      3.2        2.9  ...
# 10             2.8      3.2        2.9  ...
# 11             2.8      3.2        2.9  ...
# 12             2.8      3.2        2.9  ...
# 13             2.8      3.2        2.9  ...
# 14             2.8      3.2        2.9  ...
# 15             2.8      3.2        2.9  ...
# 16             2.8      3.2        2.9  ...
# 17             2.8      3.2        2.9  ...
# 18             2.8      3.2        2.9  ...
# 19             2.8      3.2        2.9  ...
# 20             2.8      3.2        2.9  ...
# 21             2.8      3.2        2.9  ...
# 22             2.8      3.2        2.9  ...
# 23             2.8      3.2        2.9  ...
# 24             2.8      3.2        2.9  ...
# 25             2.8      3.2        2.9  ...
# 26             2.8      3.2        2.9  ...
# 27             2.8      3.2        2.9  ...
# 28             2.8      3.2        2.9  ...
# 29             2.8      3.2        2.9  ...
# ...            ...      ...        ...  ...
# 98323          3.0      3.5        2.7  ...
# 98324          3.0      3.5        2.7  ...
# 98325          3.0      3.5        2.7  ...
# 98326          3.0      3.5        2.7  ...
# 98327          3.0      3.5        2.7  ...
# 98328          3.0      3.5        2.7  ...
# 98329          3.0      3.5        2.7  ...
# 98330          3.0      3.5        2.7  ...
# 98331          3.0      3.5        2.7  ...
# 98332          3.0      3.5        2.7  ...
# 98333          3.0      3.5        2.7  ...
# 98334          3.0      3.5        2.7  ...
# 98335          3.0      3.5        2.7  ...
# 98336          3.0      3.5        2.7  ...
# 98337          3.0      3.5        2.7  ...
# 98338          3.0      3.5        2.7  ...
# 98339          3.0      3.5        2.7  ...
# 98340          3.0      3.5        2.7  ...
# 98341          3.0      3.5        2.7  ...
# 98342          3.0      3.5        2.7  ...
# 98343          3.0      3.5        2.7  ...
# 98344          3.0      3.5        2.7  ...
# 98345          3.0      3.5        2.7  ...
# 98346          3.0      3.5        2.7  ...
# 98347          3.0      3.5        2.7  ...
# 98348          3.0      3.5        2.7  ...
# 98349          3.0      3.5        2.7  ...
# 98350          3.0      3.5        2.7  ...
# 98351          3.0      3.5        2.7  ...
# 98352          3.0      3.5        2.7  ...
#
#                                                       제목  \
# 0                       "관리만 하려하는 상위직급이 다수 사원 대리 과장은 적음"
# 1                   "변화가 없다. 근 10년동안 비슷한 프로젝트만 유지하고 있다."
# 2              "탄탄했던 회사 같음! 나쁘지 않아요! 복지좋고 편하게 다닐 수 있어요!"
# 3      "개발자와 기획자간의 괴리감이 크고 팀장과 팀원들과의 관계도 적대적인 분위기다. 줄...
# 4              "외국계 회사지만 실상은 국내 중소기업 분위기임. 합병이후 가치가 하락중"
# 5             "기존의 통신 서비스 사업 대신 새로운 사업을 추진하고 있지만 여의치 않음"
# 6                   "착하고 소심한 기업입니다. 공부밖엔 할 줄 모르는 모범생 느낌"
# 7              "개발 환경 좋고, 업계 기술력은 인정.\n다만 직급 높은 분들이 많아짐"
# 8      "IT기업치고는 보수적인 분위기 회사의 복지는 전혀 없다고 볼 수 있지만\n업무강도...
# 9      "통신사 협력사로서 예전에는 SKT라는 캐시카우가 있었지만 점점 볼륨이 줄고 있다....
# 10     "사회생활 몸담고 시작할만한 최소한의 조건을 준비한 회사.\n다만 성장이 정체된 듯...
# 11                       "개발자를 똥으로 아는 회사입니다. 맨날 외주만 강요함"
# 12     "개빌자로서 기술 향상에 초점을 둔다면 괜찮은 회사. 결국 한국에 있는 보통의 SI...
# 13     "신규사업 발굴에 실패하여 명맥만 유지되는 회사지만, 기존 사업이 튼튼하여 오래갈 ...
# 14                       "근무환경 나쁘지 않지만, 급여 수준이 업계 최저 임."
# 15                                "적은 인원이 많은 일을 해야하는 회사"
# 16                           "전문성보다는 그 때 그 때 필요한 일을 한다."
# 17     "개발자들이 경력 쌓기 좋은곳.\n서버와 클라이언트를 동시에 개발하면서 배우는 개발...
# 18                           "이동통신 사업 특성상 회사 수익이 안정적인 편"
# 19                    "부서 마다 차이가 있으나 개발자로서 일하기 나쁘지 않은 곳"
# 20                                "여러가지 복지가 좋으나 딱딱한 분위기"
# 21                  "복지가 괜찮은편이나 회사가 너무 노후함 심각한 역피라미드 구조"
# 22                   "부서마다 다르지만 대체로 다양한 개발 경험을 쌓을 수 있다."
# 23       "모험을 하지 않는 기업 문화로 안정적인 듯 보이나 결굴 조금씩 꺼져가고 있는 불씨"
# 24                     "개발자에 대한 대우가 좋지는 않으며 군대식 문화에 익숙함"
# 25      "오래다닌 사람이 참..... 많은 회사. 그 이유는!???? 그나마 복지 등은 좋음"
# 26                   "적당히 다니기 좋은 곳이다\n큰 꿈이 없는 사람에게 좋은 곳"
# 27                  "가족같은회사 경쟁없는회사 편한회사\n장점이자 단점이 분명한회사"
# 28                   "프로젝트를 접해보고 배울 수 있음, 정규직 계약직 차별 있음"
# 29     "실력있는 개발자가 많아 배울점도 많고 회사 복지도 괜찮은편. 업무는 복불복이 심하...
# ...                                                  ...
# 98323        "영업이 적성에 맞으면 오세요. 최근 외환은행과의\n합병으로 분위기 어수선함"
# 98324  "해외지점이여서 그랬는지는 모르나 일과 개인생활의 균형이 잘 맞추어진 삶을 살 수 ...
# 98325      "당시 외환은행과의 합병 후 통합 문제가 이슈여서 회사 내외부적으로 혼란스러웠음"
# 98326                   "외환은행과의 합병으로 앞으로 더 개선될 것이 기대됩니다"
# 98327  "전형적인 한국 금융권 조직문화를 가지고 있고 , 당연히 영업이 아주 중요한 업종이...
# 98328                 "외환은행과의 합병으로 앞으로의 성장성이 더욱 기대되는 은행"
# 98329  "기업문화가 보수적이고 본부는 회의준비가 많은편이다.\n대체로 연령대가 높아서 말한...
# 98330                  "인건비 절약해서 이익내는 회사. 뚜렷한 장점이 없는 은행"
# 98331          "타 은행에 비해 영업 압박이 덜한편, 여성이 많아 분위기가 여성적이다."
# 98332          "외환은행과 통합되면서 향후 전망은 좋으나 지금은 상당히 어수선한 분위기"
# 98333          "타행은 조직내 수직적 문화가 심하다고 하는데, 그런건 조금 덜한거 같음"
# 98334  "은행 본부의 분위기를 파악하는데는 도움이 되지만, 실직적인 은행업에 대해 배울 기...
# 98335                   "영업에 자신있으면 오세요. 영업력만 있으면 괜찮은 회사"
# 98336          "개인주의가 은행업 중에서 심한 회사. 조직의 체계가 다소 미약한 회사."
# 98337                "업무시간이 길고 강도가 높은데비해 급여수준이 낮아서 아쉽다."
# 98338   "타 은행과 크게 다르지 않으며 외환 은행과 합병으로 향후 방향성이 어떻게 될지 모름"
# 98339                    "업무강도는 쎄지만 그래도 은행원이라 연봉은 높은 편."
# 98340         "직원 1인당 업무량 과다하게 배분. 직원들 피로도 누적~ 실적강요로 피곤"
# 98341  "복지 좋고 연봉 좋고, 연봉 높은 만큼 일 또한 많다. 윗사람이 누가 걸리느냐가 ...
# 98342                         "발전 가능성이 있는 한국 대표 은행 중 하나"
# 98343                          "은행들 중에서는 탑급은 아니지만 괜찮은 곳"
# 98344  "여성이 다니기 좋은 직장. 하는일이 복잡하고 어려운 일은 아닌데. 단지 처리해야 ...
# 98345                         "힘든만큼 돌려받을 수있는 회사라고 생각합니다"
# 98346           "저는 영업점 근무는 아니라 그런지...\n부서 근무는 매우 좋습니다."
# 98347   "어떤 은행보다도 좋은 회사 분위기를 가지고 있으며 서로서로 협력하여 도와주는 분위기"
# 98348           "업계 중 연봉은 타은행대비 보통이나 잘하면 승진및 교육기회가 있는 곳"
# 98349         "가장효율적인 조직이며 위기에 강한은행 끝까지 마지막까지 살아남을 은행이다"
# 98350         "합병으로 인해 성장성이 돋보이는 회사임. 앞으로 두 회사의 시너지가 기대"
# 98351            "적당한 수준의 연봉과 적당한 수준의 개인생활을 유지하고 싶다면 추천"
# 98352                       "매일 몰려오는 손님들을 상대할 수 있는멘탈 필요"
#
#                                                       장점  \
# 0         10년차 정도면 it 중견기업 2~3년차 연봉에 맞먹음\n지원부서 대우가 높을수있음
# 1              자유로운 분위기, 타 IT 회사에 비해 경직되지 않고 근무를 할 수 있다.
# 2      사람들이랑 사이가 좋아서 즐겁게 다녔음 / 비품을 많이 사용할 수 있어서 좋았음\n...
# 3      해마다 복지카드가 나오고 원하는대로 쓸 수 있다. 연차나 휴가, 칼퇴에 대해 눈치보...
# 4                      사무용품 업계 1위업체. 워라벨은 보장 됨.연차사용 제약없음
# 5      직원들이 대체로 모난 사람이 없음. 자신의 할일만 하면 딱히 터치는 없는편. 프로젝...
# 6                인간적이고, 사람을 존중하는 문화가 있음. 개인의 사정을 이해하고 배려
# 7      복리후생 좋고, 건의사항 받아주려는 노력이 있음.\n콘도, 해외체험학습, 매년 인센...
# 8      전체적으로 업무에 대한 압박이 심하지 않은편 끈끈한 분위기는 아니지만\n개인적인 부...
# 9               어느정도 체계는 잡혀 있는 모습을 보이며, 회식 문화가 존재하지 않는다.
# 10      일단 임원들 인성은 매우 좋은 듯.\n복지가 괜찮고, 야근없는 분위기라 워라벨이 가능.
# 11     그냥 하는일 없이 월급은 걱정은 당분간 없을것 같습니다. 그냥 눌러앉아 있기 좋음\...
# 12     복지가 좋다. 연차 사용에 눈치 볼 필요 없다. 본인 역량 기준하에 충분히 워라벨을...
# 13                    야근이 많지 않고, 회식도 거의 없으며, 업무강도가 높지 않다
# 14                   연차를 눈치 보지 않는 것 외에는 딱히 장점을 찾아 보기 어려움
# 15     개발 외의 업무가 많지는 않다.\n개발자로서 성장할 여건은 된다.\n최신기술을 사용...
# 16         도서구입 및 교육에 대해서는 회사 지원으로 받을 수 있다. 일이 바쁘지 않다면..
# 17     비슷한 규모의 기업들에 비해 복지가 굉장히 좋다.(금전적 복지)\n사생활에 대한 터...
# 18     SKT에서 시작한 기업이라 복지가 비슷함\n해외 여행 및 핸드폰 지원금, 무이자 전...
# 19     연 복지비가 쎈편이다. 사용처를 가리지 않고 230정도 나옴. 고용문제에 관해 안정...
# 20     입사하면 여러가지 복지 혜택을 누를수 가 있어 좋고 출산을 하면 더 많은 혜택을 누...
# 21              복지는 좋다 회사 다니는 동안은 병원비나 그 외 돈걱정은 딱히 할게 없음
# 22         기업 규모에 비해 복지가 잘 되어 있고, 어느정도 유연한 사고가 통용 되는 회사.
# 23          복지비가 꽤 있고 오래된 기업문화에서 점점 자유로운 문화로 바뀌어가고 있는 시점
# 24     야근시 택시비 지원, 야근식대 7000원 제공, 병원 건강검진 지원, 연봉외 복지비...
# 25               오래 다니면 일단 회사가 직원 눈치를 봄. 직원은 회사 눈치 안봐도 됨
# 26                 일과 삶의 균형을 중시하는 사람에게 좋다\n크게 강요하는 것이 없다
# 27               의리가 있고 사람들이 다 착함...............\n,,,,,,
# 28                       칼퇴, 개인 생활에 터치 없음\n(팀별로 다를 수 있음)
# 29     실력있는 선배들이 많아 본인 노력에 따라서 많은것을 배울 수 있고 복지도 괜찮은편....
# ...                                                  ...
# 98323      여성에 대한 복지 좋음. 타 시중은행과 마찬가지로 급여 및 육아휴직 제도 good
# 98324  업무 분담이 확실하여 자기계발에 도움이 되긴 하지만 어떤 업무냐에 따라 상황이 다를...
# 98325  합병으로 인해 규모 면에서 많이 커졌다는 장점이 분명히 존재. 타 직종에 비해 어느...
# 98326                  휴가나 출산휴가를 눈치 안보고 쓸 수 있다는 점이 가장 좋음
# 98327  회식 문화는 1차에서 간결히 끝내는 것으로 조직문화가 많이 바뀌고 있고 권장 하고 ...
# 98328  외환은행과의 합병으로 기존 하나은행에 비해서는 연봉이 상승되었던 경향이 있으며 은행...
# 98329  회사체계에 대해 일배우기가 좋다.\n업무강도가 쎈편은 아니여서 누구나 쉽게 배울 수...
# 98330             조직 규모가 크고 통합 후 분위기 좋음. 김수현 광고 후 이미지 상승
# 98331  여성이 많은 부서에서 근무해서 그런지(마케팅 관련 부서), 사내 분위기가 좋고 회식...
# 98332  은행의 가장 큰 장점인 복지와 높은 연봉, 또한 외환은행과 합병되면서 향후 전망이 좋다.
# 98333                    일년에 십오영업일은 웬만하면 눈치안보고 휴가 쓸 수 있음
# 98334                비교적 자유로운 분위기, 친절한(?)직원들, 나름 긴 점심시간?
# 98335  영업을 끝장나게 배울수있음. 외환은행과의 합병으로 연봉도 오르고 기회가닿으면 외환은...
# 98336  근무 분위기가 은행업 중에서 자유로운 편입니다. 근무 분위기가 과도하게 경직되어 있...
# 98337                     직원들이 참여할수있는 사내행사에 투자를 많이 하는편이다
# 98338  직원들과 소통 원활 가족같은 분위기\n육아휴직 및 교육비 의료비 콘도사용이나 연차사...
# 98339           비교적 사내 분위기는 자유로운 편. 외환과 합병으로 성장가능성 무궁무진.
# 98340  15일의 연차사용 의무[연차비용 충당 안하고자 하는 기업의도지만, 직원들은 리프레시...
# 98341  연봉이 높음\n상사를 잘못 만나도 타 지점 발령날 때까지 버티면 됨\n주말, 공휴일...
# 98342  외환은행과의 통합으로 인하여 새로운 발전 잠재력을 창출할 기반을 마련함\n이로인하여...
# 98343                   연차사용에 무리가 없다. 본사 근무라면 퇴근이 늦지 않다.
# 98344  하는일에 비해 연봉이 적지 않다. 여직원이 많아 분위기가 딱딱하지 않다. 회식문화도...
# 98345  자유로운 분위기와 수평적인 조직문화로 다소 딱딱한 문화보다는 열린 분위기, 실적에 ...
# 98346              복지가 좋고 직원들간에 화목하고 행복합니다. 그리궁 음 안정적이죠.
# 98347  안정적이며 금융권에 대한 지식도 기본적으로 쌓아지며 경제 또한 쉽게 관찰하고 이해할...
# 98348                  역동적인 문화로 마케팅 ㅡ좋아하면 추천입니다 연봉은 보통수준
# 98349   외환은행 통합으로 글로벌과 자산관리에 강점이 있음\n철저한 비용관리로 리스크관리가 우수
# 98350  안정적인 급여와 은행원이라는 것에 대한 자부심을 느낄 수 있음 여자행원들에 대한 복...
# 98351  개인 휴가가 보장되어 있고 타 은행에 비해 비교적 퇴근이 빠름. 분위기도 뭔가 혁신...
# 98352  복지하나는 하나은행이 짱, 주말이 보장되고 현금성 복지가 있음, 전세자금 대출도 장...
#
#                                                       단점  \
# 0                   경직된 상하관계\n명령하달식 커뮤니케이션\n대우개선에대한 희망고문
# 1            성장세가 없다. 기존의 사업만 고수하고 신규사업에 대해 투자가 소홀한 편이다.
# 2      집에서 출퇴근길이 멀어서 힘들었음/ 딱히 단점이 없었던 회사\n2년 열심히 다니고 ...
# 3      단, 일이 많다. 팀마다 분위기가 상이하고 줄을 잘 서야한다. 야근이 강요되지 않지...
# 4                   연봉이 현저히 작음. 합병이후 시스템 이나 프로세스 통합이 미비함
# 5      통신망에서는 현재의 트렌트를 쫒아가지 못 하고 있고, 투자를 하지 않고 성과만 얻으...
# 6      사업적 결정을 하지 못하고 기준이 없음. 예전에 쉽게 수익을 내던 시절의 문화에서 ...
# 7      차/부장 직급자들이 점점 많아지고, 정치적인 분위기가 스물스물 올라오는 분위기.\n...
# 8      전혀 없다고 볼수있는 회사복지. 복지는 전혀 없다고 보면된다. 많은 사람들이 계약직...
# 9            타이트한 인력관리, 하지만 이건 개인의 업무 능력에 따라 장점이 될 수 있다.
# 10     신사업실패로 SI가 주인 부서는 바쁘기만하고 노잼.\n통신사 납품으로 연명.\nIT...
# 11             보고도 많고, 의심도 많아서 감시를 많이합니다. 개발관련한 교육도 안보내줌
# 12     차 부장이 너무 많다. 팀장,부장 들이 임원 눈치를 심하게 본다. 올라갈수록 힘들어...
# 13          역피라미드가 심하여 낮은 직위의 직원들이 힘들고, 회사 발전 가능성이 매우 낮다
# 14     급여 수준이 업계 평균이아하며, 경영진 마인드가 좋지 않음. 휴가 연차등 직원 복리...
# 15     시도 때도 없이 갑으로 부터 전화를 받게 된다.\n통신 개발 외 파트로 빠질 경우 ...
# 16     연봉이 낮다. 인상률도 높지 않다.\n미래 성장성도 낮은 편이다. 미래에 대한 투자...
# 17     역피라미드 구조이다.(윗사람들이 너무 많음)\n사원, 대리급들이 별로 없다.\n사업...
# 18                 회사의 노령화로 인해 시니어 개발자의 부재가 큼\n수직적인 조직문화
# 19               보고 문서 작업이 너무 많고 굉장히 수직적임. 요즘 하락세를 달림...
# 20             조직문화가 딱딱한 부분이 있음, 사무실 분위기는 조용하고 도서관 같은 느낌
# 21     역피라미드구조가 너무심해서 팀에 사원 대리가 거의없다 과장 보다 차장이 더많고 차장...
# 22     부서에 따라서 호불호가 갈리며, 중소기업이라는 한계상 연봉이 크지 않다는 점이 가장...
# 23     모험하지 않는 기업 문화로 새로운 시도를 잘 안함. 요구사항을 잘 안들어주는데 그만...
# 24     개인에게 바라는 능력치가 매우 크고 일에대한 해결보다 책임을 추궁하고 일에 포커스를...
# 25     신규 입시자가 3년을 버티지 못함. 왜 그런지 위는 관심 없음. 그저 나가는 사람이...
# 26                자기 발전 하기 어렵다\n회사가 너무 군대식이다\n판단이 너무 느리다
# 27          의리가 있다보니 경쟁심한 it업계에서 살아남기힘듬!!!!!!!!!!!!!!!!!
# 28     다이렉트로 일 처리 해도 될 것을 하나하나 돌려가며 일을 처리하여 일의 속도가 떨어...
# 29     회사가 점점 커가기보다는 점점 정체되어가고있다. 새로운 제품을 미리 만들어 미래를 ...
# ...                                                  ...
# 98323  영업실적 압박이 심하며, 특히 최근 경영진의 무리한 목표 설정으로 인해 직원들의 스...
# 98324  해외지점은 (상해지점) 아직 규모가 크지 않기 때문에 배움에 있어서 한계가 있을 수...
# 98325  보수적인 은행 특성상 굉장히 경직적인 문화가 많음, 어설픈 사내 문화 프로그램은 별...
# 98326            지점에 따라 다르지만 실적압박을 받을 수 있어 스트레스를 받을 수 있음
# 98327  어딜가나 부서by부서, 상사by상사 이지만, 전반적으로 상하 관계가 매우 확실하며,...
# 98328  2016년 들어서 은행 연봉 삭감에 관한 이야기들이 점점 더 많이 나오고 있으며 빡...
# 98329  출근시간이 회의준비로 대체로 일찍 와야하고 퇴근역시 마찬가지이다.\n잡일이 대다수....
# 98330              동종업계 대비 뚜렷한 장점과 특징이 없음. 전산 통합 후 혼란 예상
# 98331  은행권이라 영업의 압박은 어느 정도 있는 듯.... 영업점에 비해 본사에서 근무하면...
# 98332  높은 영업압박과 타 시중은행보다 상대적으로 낮은 연봉과 복지, 또한 야근도 만만치 ...
# 98333  실적압박이 정말 너무 심하고, 직원이 인사발령 나도 어지간해선 후임이 충원 잘 안돼...
# 98334                한국기업의 공통된 문제인 상사눈치보기, 융통적이지 못한 일처리?
# 98335            은행특유의 야근문화. 주말은 있다지만 글쎄... 주말에도 지인영업 필수
# 98336   조직에 의한 영업력이 약하고, 개인별 영업력에 의존하는 듯합니다. 업무량이 과다합니다.
# 98337             과반수이상의 직원들이 야근을하며, 타 은행과 비교하여 급여수준이 낮음
# 98338  지점이라면 실적 압박은 당연한것이긴하나 압박강도 꽤 있음 정부 정책에 따라 업무 영...
# 98339  업무강도가 많이 쎈 편이고 야근이 거의 생활화 돼있음.은행원이라고 정시 퇴근을 생각...
# 98340  출근시간 이르고 퇴근시간 늦음. 시간외 근무 시스템도 지점에 따라 다르기에 성향이 ...
# 98341  업무 많음(실적)\n소문 조심\n입 조심\n감정노동 다반사\n철저한 서비스직\n점심...
# 98342  영업 압박이 강하고, 문어발적으로 사업을 늘리지만 영 신통치 않음\n또한 연봉이 타...
# 98343  인턴을 기준으로 보았을때 아이디어만 빼먹는듯한 느낌을 받으며 분위기가 완전히 경쟁적...
# 98344  일이 어려운건 아닌데. 처리해야 할 업무가 많다. 영업시간중에는 자리를 비우기 어렵...
# 98345  업무 과중이 많고 실적압박이 심함 조직원들의 경쟁을 부추겨 조직원들의 스트레스도 상...
# 98346           회식이... 술을 좋아하시면 많습니다. 아.. 그냥 많을수 있습니다...
# 98347  은행특성상 야근이 많으며 각부서별로 고충이 있겠지만 특히 어느한부서가 심하게 야근이...
# 98348                     빡센문화 야근을 밥먹듯이하는사람많음 승진과열경쟁 부추김
# 98349                  다양한 은행이 모인만큼 문화가 다르지만 성과로 평가하는 은행
# 98350        과도한 업무와 합병에 따른 전산처리가 아직 미비한점 인사제도에 대한 개선 필요
# 98351  늘 그 자리에 머무는 연봉과 출신의 한계로 인한 넘사벽이 존재. 그리고 일단 비전없...
# 98352  진상고객들 처리가 최대의 단점. 고객들의 민원을 이겨낼 수 있는 멘탈관리와 성실함이...
#
#                                              경영진에게 바라는 점 각 리뷰 평점         직무  \
# 0                      낙하산 및 고인물의 교체 필요\n실무자에 대한 대우개선 필요       1     IT/인터넷
# 1                               기존 사업보다는 신규사업에 투자해야 할 시기       3     IT/인터넷
# 2               경영진에게 크게 바라는점은 없음 !! 그렇게 심한 터치가 없어서 편했나봄       2     IT/인터넷
# 3                 신규 사업에 대한 투자는 좋지만 사람도 돌보는 회사가 됐으면 좋겠다.       3     IT/인터넷
# 4           직원들에 대한 복지나 연봉을 개선하여 동기부여가 될 수 있게 해줬으면 하는 바람       2  경영/기획/컨설팅
# 5      기존 사업도 투자를 해야 발전이 있는 법인데 신규 사업에만 투자하지 말고 기존 사업...       1     IT/인터넷
# 6                                목표를 확실하게 하고 그에 맞는 결정 필요       3     IT/인터넷
# 7       기존사업 활성화에 더욱 중점을 두고, 신규사업도 사업성 잘 판단하여 진행하였으면 좋겠음       2     IT/인터넷
# 8      기존의 아이템 한계를 인정하고 새로운 시장을 적극적으로 개척하려는 경영진의 의지가 ...       3     IT/인터넷
# 9           비젼을 구성원에게 제시해주세요. 믿고 따라갈 빛이 보여야 힘이 날 것 같습니다.       2     IT/인터넷
# 10     IT로 성공하는 업체들이 개부럽다.\n계속 SI납품으로 연명하는 회사로 남을 것인지...       1     IT/인터넷
# 11                      이랬다 저랬다, 대기업의 눈치를 봐가며 사업하는게 한심함.       3     IT/인터넷
# 12     직원들의 이야기를 자신의 기준에 듣지 말고 직원의 기준으로 들엇으면. 듣고 나면 흘...       2     IT/인터넷
# 13       IT기업답게 변화하였으면 좋겠다. IT기업이 맞나 싶을정도로 구닥다리 경영이 심하다.       3     IT/인터넷
# 14     직원들 요구사항을 철저히 경청하고, 성의 있는 협의 자세를 가지기 바라며, 제품 로...       2     IT/인터넷
# 15     일을 그렇게 많이 시키면 연봉을 많이 주세요.\n적은 인원으로 일을 많이 시키니까 ...       1     IT/인터넷
# 16                조직간에 협업이 매우 부족하다.\n복리후생이 10년 넘게 그대로이다.       3     IT/인터넷
# 17     실질적으로 일하는 사원, 대리급들이 나가지 않게 조치가 필요합니다.\n실무에 투입시...       2     IT/인터넷
# 18                               시스템적으로 회사 문화 쇄신이 필요해 보임       3     IT/인터넷
# 19     연구개발본부 군대 문화는 임원 혼자서 바꿀 수 있는게 아닌듯. 이미 너무 오랜기간 ...       2     IT/인터넷
# 20     오래된 기업문화를 한번에 바꿀수는 없지만 조금더 창의적인 기업문화로 변화 되었으면 합니다       1     IT/인터넷
# 21     조금씩이라도 개선하는쪽으로 방향을 잡길 바랍니다. 지금상태로는 점차적인 하락세를 벗...       3        디자인
# 22     호황 때 축적했던 자본을 투자실패로 대부분 날린 만큼, 이를 만회하여 직원들에게 만...       2     IT/인터넷
# 23          매년 평가에 상관도 평가할 수 있게 하여 더 객관적인 평가가 이루어질 수 있도록       3     IT/인터넷
# 24                 공정한 평가가 필요하며, 실제 업무 기여도에따른 연봉 인상이 필요함       2     IT/인터넷
# 25                     왜 있는 사람은 계속 있고 새로운 사람이 나가는지 알길...       1     IT/인터넷
# 26             신기술이나 자체 기술력을 보유해야 할 것 같다\n신속한 의사결정이 필요하다       3     IT/인터넷
# 27                       전문경영인 체제로 가야할듯\n신규인력채용이 많이 필요할듯       2     IT/인터넷
# 28            개인주의 성향이 강한 것 같아 전체적으로 단합할 수 있는 기회가 많았으면 함       3     IT/인터넷
# 29     선행기술과 사람에 대한 투자가 필요합니다. 업무도 역량도 복지도 정체되어있는점에대해...       2     IT/인터넷
# ...                                                  ...     ...        ...
# 98323                  직원들의 불만을 듣고 비현실적인 영업목표를 수정했으면 좋겠음       4      금융/재무
# 98324  합리적인 복지 및 보상체계를 마련해 주었으면. 해외지점을 잘 이끌어줄 수 있는 윗계...       2      금융/재무
# 98325                        보수적인 은행 특성상 굉장히 경직적인 문화가 많음       3      금융/재무
# 98326                    비정규직에 대한 처우 개선이 필요하다고 생각 합니다 저는       2      금융/재무
# 98327  하드웨어 적으론 성장하고 커가고 있는 것 같으나(합병 등), 그만한 직원들에 대한 ...       3      인사/총무
# 98328  힘든 경제 상황 속에서도 채용을 늘리려 하고 복지를 향상시키려는 노력이 참 좋은 것...       4      금융/재무
# 98329  보수적인 문화가 개선되면 좋을 것 같습니다.\n지방일경우 연령대가 높아서 연고지를 ...       2      인사/총무
# 98330            전산 관리에 더 투자했으면...불안정한 시스템으로 업무 효율이 떨어진다       3      금융/재무
# 98331  은행권의 공통적인 문제점인 영업 압박...... 영업 압박이 줄어들었으면\n그치만 ...       2   마케팅/시장조사
# 98332                 높은 영업압박만 없으면 위의 단점들이 대부분 해결될 거라 본다       3      금융/재무
# 98333   직원들한테 실적압박좀 그만하고, 실적 압박할 시간에 좋은 상품 개발에 좀 더 노력할 것       4      금융/재무
# 98334                  적극적으로 인턴에게 일할 수 있는 기회를 부여했으면 좋겠다.       2      금융/재무
# 98335             은행업자체가 사장돼가는 느낌. 영업으로 메꿀수 있는 거 같진 않습니다       3      금융/재무
# 98336  조직에 의한 영업력 제고가 필요하다고 생각합니다. 조직의 체계를 조금더 체계화하면 ...       2      금융/재무
# 98337          외부에 보여지는것에만 너무 집중하지말았으면 하며 회의가 너무 빈번하고 길다       3  경영/기획/컨설팅
# 98338      제살 깎아 먹기 식의 실적 압박이 없어야 하며 수익이\n큰 기업영업에 집중이 필요       4      금융/재무
# 98339                           좀 더 경쟁력을 갖춘 마케팅이 필요해 보임.       2      금융/재무
# 98340  직원에 대한 제대로된 보상체계가 필요함. 회사에 대한 자긍심을 키워줄 수 있는 교육...       3      금융/재무
# 98341  타 기업과는 다르게 합리적인 복지혜택과 연봉이지만 그만큼 업무 또한 많은 곳 앞으로...       2      금융/재무
# 98342  불필요한 문어발식 사업확장을 하지말고 본인들이 잘하는 PB분야의 역량을 강화하고 기...       3      금융/재무
# 98343            신입이 들어오자마자 영업으로 내보내면 퇴사율이 높아질수 밖에 없습니다.       4      법률/법무
# 98344  이제 영업점 업무의 한계가 분명하기 때문에 사업구조 재편이 필요하다.새로운 상품개발...       2      영업/제휴
# 98345      실적보다는 다양한 사업플랫폼으로 다각화하는 하나금융그룹으로 성장할 수 있기바랍니다       3      금융/재무
# 98346       음 요즘 비용절감 많이 강조하시는데\n필요한 곳만 비용절감 하셨으면...합니다.       2     IT/인터넷
# 98347       이후 온라인은행이 더욱더 개발되면 현존하는 은행들과의 차별화된 강점을 설립해야함       3   서비스/고객지원
# 98348            야근을최소화하고 경쟁과 영업압박을 너무 주지않아야 임직원들이 버팀...       4      금융/재무
# 98349  단기실적 보단 지속가능 경영의 실현이 필요할때\n통합에 관한 제도 등의 결정은 빠르...       2      금융/재무
# 98350            합병 시너지를 행원들까지 누릴 수 있게 인사제도 개선이 필요해 보입니다       3      금융/재무
# 98351                               개인과 기업을 구분하지 말고 대우하길       2      금융/재무
# 98352  영업압박에 대한 부담감이 낮았으면 좋겠고, 은행원들의 고충을 좀 더 면밀하게 살펴서...       3      금융/재무
#
#        재직상태  지역 리뷰 좋아요 개수 label
# 0       전직원  경기         0   1.0
# 1       현직원  경기         0   1.0
# 2       전직원  경기         0   1.0
# 3       전직원  서울         0   1.0
# 4       전직원  서울         0   1.0
# 5       현직원  경기         1   1.0
# 6       현직원  경기         4   1.0
# 7       현직원  경기         2   1.0
# 8       전직원  경기         1   1.0
# 9       현직원  경기         2   1.0
# 10      현직원  경기         2   1.0
# 11      전직원  경기         1   1.0
# 12      전직원  경기         0   1.0
# 13      현직원  경기         0   1.0
# 14      전직원  경기         0   1.0
# 15      전직원  경기         0   1.0
# 16      현직원  경기         1   1.0
# 17      전직원  경기         0   1.0
# 18      전직원  경기         0   1.0
# 19      전직원  경기         0   1.0
# 20      전직원  경기         1   1.0
# 21      전직원  경기         1   1.0
# 22      현직원  경기         0   1.0
# 23      현직원  경기         1   1.0
# 24      현직원  경기         2   1.0
# 25      전직원  경기         1   1.0
# 26      전직원  경기         0   1.0
# 27      현직원  경기         0   1.0
# 28      전직원  경기         0   1.0
# 29      현직원  경기         0   1.0
# ...     ...  ..       ...   ...
# 98323   현직원  서울         0   0.0
# 98324   전직원  해외         0   0.0
# 98325   전직원  서울         0   0.0
# 98326   전직원  서울         0   0.0
# 98327   전직원  서울         0   0.0
# 98328   전직원  서울         0   0.0
# 98329   전직원  충남         0   0.0
# 98330   전직원  충남         0   0.0
# 98331   전직원  서울         0   0.0
# 98332   전직원  대전         0   0.0
# 98333   현직원  서울         0   0.0
# 98334   전직원  서울         0   0.0
# 98335   현직원  서울         0   0.0
# 98336   전직원  서울         1   0.0
# 98337   전직원  서울         0   0.0
# 98338   현직원  서울         0   0.0
# 98339   전직원  서울         0   0.0
# 98340   전직원  서울         0   0.0
# 98341   전직원  서울         0   0.0
# 98342   전직원  충남         0   0.0
# 98343   전직원  서울         0   0.0
# 98344   전직원  서울         0   0.0
# 98345   현직원  경기         0   0.0
# 98346   현직원  서울         1   0.0
# 98347   전직원  기타         0   0.0
# 98348   전직원  서울         0   0.0
# 98349   현직원  서울         0   0.0
# 98350   현직원  서울         0   0.0
# 98351   전직원  서울         0   0.0
# 98352   현직원  서울         1   0.0
#
# [98353 rows x 22 columns]

# %%
total_data = total_data.dropna(axis=0)
total_data.reset_index(inplace=True)
total_data['label'] = total_data['label'].astype(int)
total_data
# Out:
# C:\Anaconda3\envs\study\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        index  링크 순서       기업   평점     산업분류 직원의 기업 추천율 직원이 전망하는 성장 가능성  \
# 0          0      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 1          1      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 2          2      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 3          3      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 4          4      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 5          5      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 6          6      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 7          7      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 8          8      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 9          9      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 10        10      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 11        11      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 12        12      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 13        13      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 14        14      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 15        15      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 16        16      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 17        17      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 18        18      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 19        19      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 20        20      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 21        21      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 22        22      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 23        23      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 24        24      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 25        25      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 26        26      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 27        27      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 28        28      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# 29        29      0   유엔젤(주)  3.0  IT/웹/통신        35%              5%
# ...      ...    ...      ...  ...      ...        ...             ...
# 38061  98323     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38062  98324     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38063  98325     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38064  98326     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38065  98327     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38066  98328     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38067  98329     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38068  98330     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38069  98331     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38070  98332     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38071  98333     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38072  98334     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38073  98335     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38074  98336     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38075  98337     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38076  98338     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38077  98339     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38078  98340     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38079  98341     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38080  98342     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38081  98343     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38082  98344     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38083  98345     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38084  98346     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38085  98347     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38086  98348     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38087  98349     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38088  98350     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38089  98351     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 38090  98352     65  하나은행(주)  3.1   은행/금융업        43%             37%
#
#       이 기업의 CEO 지지율  승진 기회 및 가능성  복지 및 급여  ...  \
# 0               53%          2.8      3.2  ...
# 1               53%          2.8      3.2  ...
# 2               53%          2.8      3.2  ...
# 3               53%          2.8      3.2  ...
# 4               53%          2.8      3.2  ...
# 5               53%          2.8      3.2  ...
# 6               53%          2.8      3.2  ...
# 7               53%          2.8      3.2  ...
# 8               53%          2.8      3.2  ...
# 9               53%          2.8      3.2  ...
# 10              53%          2.8      3.2  ...
# 11              53%          2.8      3.2  ...
# 12              53%          2.8      3.2  ...
# 13              53%          2.8      3.2  ...
# 14              53%          2.8      3.2  ...
# 15              53%          2.8      3.2  ...
# 16              53%          2.8      3.2  ...
# 17              53%          2.8      3.2  ...
# 18              53%          2.8      3.2  ...
# 19              53%          2.8      3.2  ...
# 20              53%          2.8      3.2  ...
# 21              53%          2.8      3.2  ...
# 22              53%          2.8      3.2  ...
# 23              53%          2.8      3.2  ...
# 24              53%          2.8      3.2  ...
# 25              53%          2.8      3.2  ...
# 26              53%          2.8      3.2  ...
# 27              53%          2.8      3.2  ...
# 28              53%          2.8      3.2  ...
# 29              53%          2.8      3.2  ...
# ...             ...          ...      ...  ...
# 38061           44%          3.0      3.5  ...
# 38062           44%          3.0      3.5  ...
# 38063           44%          3.0      3.5  ...
# 38064           44%          3.0      3.5  ...
# 38065           44%          3.0      3.5  ...
# 38066           44%          3.0      3.5  ...
# 38067           44%          3.0      3.5  ...
# 38068           44%          3.0      3.5  ...
# 38069           44%          3.0      3.5  ...
# 38070           44%          3.0      3.5  ...
# 38071           44%          3.0      3.5  ...
# 38072           44%          3.0      3.5  ...
# 38073           44%          3.0      3.5  ...
# 38074           44%          3.0      3.5  ...
# 38075           44%          3.0      3.5  ...
# 38076           44%          3.0      3.5  ...
# 38077           44%          3.0      3.5  ...
# 38078           44%          3.0      3.5  ...
# 38079           44%          3.0      3.5  ...
# 38080           44%          3.0      3.5  ...
# 38081           44%          3.0      3.5  ...
# 38082           44%          3.0      3.5  ...
# 38083           44%          3.0      3.5  ...
# 38084           44%          3.0      3.5  ...
# 38085           44%          3.0      3.5  ...
# 38086           44%          3.0      3.5  ...
# 38087           44%          3.0      3.5  ...
# 38088           44%          3.0      3.5  ...
# 38089           44%          3.0      3.5  ...
# 38090           44%          3.0      3.5  ...
#
#                                                       제목  \
# 0                       "관리만 하려하는 상위직급이 다수 사원 대리 과장은 적음"
# 1                   "변화가 없다. 근 10년동안 비슷한 프로젝트만 유지하고 있다."
# 2              "탄탄했던 회사 같음! 나쁘지 않아요! 복지좋고 편하게 다닐 수 있어요!"
# 3      "개발자와 기획자간의 괴리감이 크고 팀장과 팀원들과의 관계도 적대적인 분위기다. 줄...
# 4              "외국계 회사지만 실상은 국내 중소기업 분위기임. 합병이후 가치가 하락중"
# 5             "기존의 통신 서비스 사업 대신 새로운 사업을 추진하고 있지만 여의치 않음"
# 6                   "착하고 소심한 기업입니다. 공부밖엔 할 줄 모르는 모범생 느낌"
# 7              "개발 환경 좋고, 업계 기술력은 인정.\n다만 직급 높은 분들이 많아짐"
# 8      "IT기업치고는 보수적인 분위기 회사의 복지는 전혀 없다고 볼 수 있지만\n업무강도...
# 9      "통신사 협력사로서 예전에는 SKT라는 캐시카우가 있었지만 점점 볼륨이 줄고 있다....
# 10     "사회생활 몸담고 시작할만한 최소한의 조건을 준비한 회사.\n다만 성장이 정체된 듯...
# 11                       "개발자를 똥으로 아는 회사입니다. 맨날 외주만 강요함"
# 12     "개빌자로서 기술 향상에 초점을 둔다면 괜찮은 회사. 결국 한국에 있는 보통의 SI...
# 13     "신규사업 발굴에 실패하여 명맥만 유지되는 회사지만, 기존 사업이 튼튼하여 오래갈 ...
# 14                       "근무환경 나쁘지 않지만, 급여 수준이 업계 최저 임."
# 15                                "적은 인원이 많은 일을 해야하는 회사"
# 16                           "전문성보다는 그 때 그 때 필요한 일을 한다."
# 17     "개발자들이 경력 쌓기 좋은곳.\n서버와 클라이언트를 동시에 개발하면서 배우는 개발...
# 18                           "이동통신 사업 특성상 회사 수익이 안정적인 편"
# 19                    "부서 마다 차이가 있으나 개발자로서 일하기 나쁘지 않은 곳"
# 20                                "여러가지 복지가 좋으나 딱딱한 분위기"
# 21                  "복지가 괜찮은편이나 회사가 너무 노후함 심각한 역피라미드 구조"
# 22                   "부서마다 다르지만 대체로 다양한 개발 경험을 쌓을 수 있다."
# 23       "모험을 하지 않는 기업 문화로 안정적인 듯 보이나 결굴 조금씩 꺼져가고 있는 불씨"
# 24                     "개발자에 대한 대우가 좋지는 않으며 군대식 문화에 익숙함"
# 25      "오래다닌 사람이 참..... 많은 회사. 그 이유는!???? 그나마 복지 등은 좋음"
# 26                   "적당히 다니기 좋은 곳이다\n큰 꿈이 없는 사람에게 좋은 곳"
# 27                  "가족같은회사 경쟁없는회사 편한회사\n장점이자 단점이 분명한회사"
# 28                   "프로젝트를 접해보고 배울 수 있음, 정규직 계약직 차별 있음"
# 29     "실력있는 개발자가 많아 배울점도 많고 회사 복지도 괜찮은편. 업무는 복불복이 심하...
# ...                                                  ...
# 38061        "영업이 적성에 맞으면 오세요. 최근 외환은행과의\n합병으로 분위기 어수선함"
# 38062  "해외지점이여서 그랬는지는 모르나 일과 개인생활의 균형이 잘 맞추어진 삶을 살 수 ...
# 38063      "당시 외환은행과의 합병 후 통합 문제가 이슈여서 회사 내외부적으로 혼란스러웠음"
# 38064                   "외환은행과의 합병으로 앞으로 더 개선될 것이 기대됩니다"
# 38065  "전형적인 한국 금융권 조직문화를 가지고 있고 , 당연히 영업이 아주 중요한 업종이...
# 38066                 "외환은행과의 합병으로 앞으로의 성장성이 더욱 기대되는 은행"
# 38067  "기업문화가 보수적이고 본부는 회의준비가 많은편이다.\n대체로 연령대가 높아서 말한...
# 38068                  "인건비 절약해서 이익내는 회사. 뚜렷한 장점이 없는 은행"
# 38069          "타 은행에 비해 영업 압박이 덜한편, 여성이 많아 분위기가 여성적이다."
# 38070          "외환은행과 통합되면서 향후 전망은 좋으나 지금은 상당히 어수선한 분위기"
# 38071          "타행은 조직내 수직적 문화가 심하다고 하는데, 그런건 조금 덜한거 같음"
# 38072  "은행 본부의 분위기를 파악하는데는 도움이 되지만, 실직적인 은행업에 대해 배울 기...
# 38073                   "영업에 자신있으면 오세요. 영업력만 있으면 괜찮은 회사"
# 38074          "개인주의가 은행업 중에서 심한 회사. 조직의 체계가 다소 미약한 회사."
# 38075                "업무시간이 길고 강도가 높은데비해 급여수준이 낮아서 아쉽다."
# 38076   "타 은행과 크게 다르지 않으며 외환 은행과 합병으로 향후 방향성이 어떻게 될지 모름"
# 38077                    "업무강도는 쎄지만 그래도 은행원이라 연봉은 높은 편."
# 38078         "직원 1인당 업무량 과다하게 배분. 직원들 피로도 누적~ 실적강요로 피곤"
# 38079  "복지 좋고 연봉 좋고, 연봉 높은 만큼 일 또한 많다. 윗사람이 누가 걸리느냐가 ...
# 38080                         "발전 가능성이 있는 한국 대표 은행 중 하나"
# 38081                          "은행들 중에서는 탑급은 아니지만 괜찮은 곳"
# 38082  "여성이 다니기 좋은 직장. 하는일이 복잡하고 어려운 일은 아닌데. 단지 처리해야 ...
# 38083                         "힘든만큼 돌려받을 수있는 회사라고 생각합니다"
# 38084           "저는 영업점 근무는 아니라 그런지...\n부서 근무는 매우 좋습니다."
# 38085   "어떤 은행보다도 좋은 회사 분위기를 가지고 있으며 서로서로 협력하여 도와주는 분위기"
# 38086           "업계 중 연봉은 타은행대비 보통이나 잘하면 승진및 교육기회가 있는 곳"
# 38087         "가장효율적인 조직이며 위기에 강한은행 끝까지 마지막까지 살아남을 은행이다"
# 38088         "합병으로 인해 성장성이 돋보이는 회사임. 앞으로 두 회사의 시너지가 기대"
# 38089            "적당한 수준의 연봉과 적당한 수준의 개인생활을 유지하고 싶다면 추천"
# 38090                       "매일 몰려오는 손님들을 상대할 수 있는멘탈 필요"
#
#                                                       장점  \
# 0         10년차 정도면 it 중견기업 2~3년차 연봉에 맞먹음\n지원부서 대우가 높을수있음
# 1              자유로운 분위기, 타 IT 회사에 비해 경직되지 않고 근무를 할 수 있다.
# 2      사람들이랑 사이가 좋아서 즐겁게 다녔음 / 비품을 많이 사용할 수 있어서 좋았음\n...
# 3      해마다 복지카드가 나오고 원하는대로 쓸 수 있다. 연차나 휴가, 칼퇴에 대해 눈치보...
# 4                      사무용품 업계 1위업체. 워라벨은 보장 됨.연차사용 제약없음
# 5      직원들이 대체로 모난 사람이 없음. 자신의 할일만 하면 딱히 터치는 없는편. 프로젝...
# 6                인간적이고, 사람을 존중하는 문화가 있음. 개인의 사정을 이해하고 배려
# 7      복리후생 좋고, 건의사항 받아주려는 노력이 있음.\n콘도, 해외체험학습, 매년 인센...
# 8      전체적으로 업무에 대한 압박이 심하지 않은편 끈끈한 분위기는 아니지만\n개인적인 부...
# 9               어느정도 체계는 잡혀 있는 모습을 보이며, 회식 문화가 존재하지 않는다.
# 10      일단 임원들 인성은 매우 좋은 듯.\n복지가 괜찮고, 야근없는 분위기라 워라벨이 가능.
# 11     그냥 하는일 없이 월급은 걱정은 당분간 없을것 같습니다. 그냥 눌러앉아 있기 좋음\...
# 12     복지가 좋다. 연차 사용에 눈치 볼 필요 없다. 본인 역량 기준하에 충분히 워라벨을...
# 13                    야근이 많지 않고, 회식도 거의 없으며, 업무강도가 높지 않다
# 14                   연차를 눈치 보지 않는 것 외에는 딱히 장점을 찾아 보기 어려움
# 15     개발 외의 업무가 많지는 않다.\n개발자로서 성장할 여건은 된다.\n최신기술을 사용...
# 16         도서구입 및 교육에 대해서는 회사 지원으로 받을 수 있다. 일이 바쁘지 않다면..
# 17     비슷한 규모의 기업들에 비해 복지가 굉장히 좋다.(금전적 복지)\n사생활에 대한 터...
# 18     SKT에서 시작한 기업이라 복지가 비슷함\n해외 여행 및 핸드폰 지원금, 무이자 전...
# 19     연 복지비가 쎈편이다. 사용처를 가리지 않고 230정도 나옴. 고용문제에 관해 안정...
# 20     입사하면 여러가지 복지 혜택을 누를수 가 있어 좋고 출산을 하면 더 많은 혜택을 누...
# 21              복지는 좋다 회사 다니는 동안은 병원비나 그 외 돈걱정은 딱히 할게 없음
# 22         기업 규모에 비해 복지가 잘 되어 있고, 어느정도 유연한 사고가 통용 되는 회사.
# 23          복지비가 꽤 있고 오래된 기업문화에서 점점 자유로운 문화로 바뀌어가고 있는 시점
# 24     야근시 택시비 지원, 야근식대 7000원 제공, 병원 건강검진 지원, 연봉외 복지비...
# 25               오래 다니면 일단 회사가 직원 눈치를 봄. 직원은 회사 눈치 안봐도 됨
# 26                 일과 삶의 균형을 중시하는 사람에게 좋다\n크게 강요하는 것이 없다
# 27               의리가 있고 사람들이 다 착함...............\n,,,,,,
# 28                       칼퇴, 개인 생활에 터치 없음\n(팀별로 다를 수 있음)
# 29     실력있는 선배들이 많아 본인 노력에 따라서 많은것을 배울 수 있고 복지도 괜찮은편....
# ...                                                  ...
# 38061      여성에 대한 복지 좋음. 타 시중은행과 마찬가지로 급여 및 육아휴직 제도 good
# 38062  업무 분담이 확실하여 자기계발에 도움이 되긴 하지만 어떤 업무냐에 따라 상황이 다를...
# 38063  합병으로 인해 규모 면에서 많이 커졌다는 장점이 분명히 존재. 타 직종에 비해 어느...
# 38064                  휴가나 출산휴가를 눈치 안보고 쓸 수 있다는 점이 가장 좋음
# 38065  회식 문화는 1차에서 간결히 끝내는 것으로 조직문화가 많이 바뀌고 있고 권장 하고 ...
# 38066  외환은행과의 합병으로 기존 하나은행에 비해서는 연봉이 상승되었던 경향이 있으며 은행...
# 38067  회사체계에 대해 일배우기가 좋다.\n업무강도가 쎈편은 아니여서 누구나 쉽게 배울 수...
# 38068             조직 규모가 크고 통합 후 분위기 좋음. 김수현 광고 후 이미지 상승
# 38069  여성이 많은 부서에서 근무해서 그런지(마케팅 관련 부서), 사내 분위기가 좋고 회식...
# 38070  은행의 가장 큰 장점인 복지와 높은 연봉, 또한 외환은행과 합병되면서 향후 전망이 좋다.
# 38071                    일년에 십오영업일은 웬만하면 눈치안보고 휴가 쓸 수 있음
# 38072                비교적 자유로운 분위기, 친절한(?)직원들, 나름 긴 점심시간?
# 38073  영업을 끝장나게 배울수있음. 외환은행과의 합병으로 연봉도 오르고 기회가닿으면 외환은...
# 38074  근무 분위기가 은행업 중에서 자유로운 편입니다. 근무 분위기가 과도하게 경직되어 있...
# 38075                     직원들이 참여할수있는 사내행사에 투자를 많이 하는편이다
# 38076  직원들과 소통 원활 가족같은 분위기\n육아휴직 및 교육비 의료비 콘도사용이나 연차사...
# 38077           비교적 사내 분위기는 자유로운 편. 외환과 합병으로 성장가능성 무궁무진.
# 38078  15일의 연차사용 의무[연차비용 충당 안하고자 하는 기업의도지만, 직원들은 리프레시...
# 38079  연봉이 높음\n상사를 잘못 만나도 타 지점 발령날 때까지 버티면 됨\n주말, 공휴일...
# 38080  외환은행과의 통합으로 인하여 새로운 발전 잠재력을 창출할 기반을 마련함\n이로인하여...
# 38081                   연차사용에 무리가 없다. 본사 근무라면 퇴근이 늦지 않다.
# 38082  하는일에 비해 연봉이 적지 않다. 여직원이 많아 분위기가 딱딱하지 않다. 회식문화도...
# 38083  자유로운 분위기와 수평적인 조직문화로 다소 딱딱한 문화보다는 열린 분위기, 실적에 ...
# 38084              복지가 좋고 직원들간에 화목하고 행복합니다. 그리궁 음 안정적이죠.
# 38085  안정적이며 금융권에 대한 지식도 기본적으로 쌓아지며 경제 또한 쉽게 관찰하고 이해할...
# 38086                  역동적인 문화로 마케팅 ㅡ좋아하면 추천입니다 연봉은 보통수준
# 38087   외환은행 통합으로 글로벌과 자산관리에 강점이 있음\n철저한 비용관리로 리스크관리가 우수
# 38088  안정적인 급여와 은행원이라는 것에 대한 자부심을 느낄 수 있음 여자행원들에 대한 복...
# 38089  개인 휴가가 보장되어 있고 타 은행에 비해 비교적 퇴근이 빠름. 분위기도 뭔가 혁신...
# 38090  복지하나는 하나은행이 짱, 주말이 보장되고 현금성 복지가 있음, 전세자금 대출도 장...
#
#                                                       단점  \
# 0                   경직된 상하관계\n명령하달식 커뮤니케이션\n대우개선에대한 희망고문
# 1            성장세가 없다. 기존의 사업만 고수하고 신규사업에 대해 투자가 소홀한 편이다.
# 2      집에서 출퇴근길이 멀어서 힘들었음/ 딱히 단점이 없었던 회사\n2년 열심히 다니고 ...
# 3      단, 일이 많다. 팀마다 분위기가 상이하고 줄을 잘 서야한다. 야근이 강요되지 않지...
# 4                   연봉이 현저히 작음. 합병이후 시스템 이나 프로세스 통합이 미비함
# 5      통신망에서는 현재의 트렌트를 쫒아가지 못 하고 있고, 투자를 하지 않고 성과만 얻으...
# 6      사업적 결정을 하지 못하고 기준이 없음. 예전에 쉽게 수익을 내던 시절의 문화에서 ...
# 7      차/부장 직급자들이 점점 많아지고, 정치적인 분위기가 스물스물 올라오는 분위기.\n...
# 8      전혀 없다고 볼수있는 회사복지. 복지는 전혀 없다고 보면된다. 많은 사람들이 계약직...
# 9            타이트한 인력관리, 하지만 이건 개인의 업무 능력에 따라 장점이 될 수 있다.
# 10     신사업실패로 SI가 주인 부서는 바쁘기만하고 노잼.\n통신사 납품으로 연명.\nIT...
# 11             보고도 많고, 의심도 많아서 감시를 많이합니다. 개발관련한 교육도 안보내줌
# 12     차 부장이 너무 많다. 팀장,부장 들이 임원 눈치를 심하게 본다. 올라갈수록 힘들어...
# 13          역피라미드가 심하여 낮은 직위의 직원들이 힘들고, 회사 발전 가능성이 매우 낮다
# 14     급여 수준이 업계 평균이아하며, 경영진 마인드가 좋지 않음. 휴가 연차등 직원 복리...
# 15     시도 때도 없이 갑으로 부터 전화를 받게 된다.\n통신 개발 외 파트로 빠질 경우 ...
# 16     연봉이 낮다. 인상률도 높지 않다.\n미래 성장성도 낮은 편이다. 미래에 대한 투자...
# 17     역피라미드 구조이다.(윗사람들이 너무 많음)\n사원, 대리급들이 별로 없다.\n사업...
# 18                 회사의 노령화로 인해 시니어 개발자의 부재가 큼\n수직적인 조직문화
# 19               보고 문서 작업이 너무 많고 굉장히 수직적임. 요즘 하락세를 달림...
# 20             조직문화가 딱딱한 부분이 있음, 사무실 분위기는 조용하고 도서관 같은 느낌
# 21     역피라미드구조가 너무심해서 팀에 사원 대리가 거의없다 과장 보다 차장이 더많고 차장...
# 22     부서에 따라서 호불호가 갈리며, 중소기업이라는 한계상 연봉이 크지 않다는 점이 가장...
# 23     모험하지 않는 기업 문화로 새로운 시도를 잘 안함. 요구사항을 잘 안들어주는데 그만...
# 24     개인에게 바라는 능력치가 매우 크고 일에대한 해결보다 책임을 추궁하고 일에 포커스를...
# 25     신규 입시자가 3년을 버티지 못함. 왜 그런지 위는 관심 없음. 그저 나가는 사람이...
# 26                자기 발전 하기 어렵다\n회사가 너무 군대식이다\n판단이 너무 느리다
# 27          의리가 있다보니 경쟁심한 it업계에서 살아남기힘듬!!!!!!!!!!!!!!!!!
# 28     다이렉트로 일 처리 해도 될 것을 하나하나 돌려가며 일을 처리하여 일의 속도가 떨어...
# 29     회사가 점점 커가기보다는 점점 정체되어가고있다. 새로운 제품을 미리 만들어 미래를 ...
# ...                                                  ...
# 38061  영업실적 압박이 심하며, 특히 최근 경영진의 무리한 목표 설정으로 인해 직원들의 스...
# 38062  해외지점은 (상해지점) 아직 규모가 크지 않기 때문에 배움에 있어서 한계가 있을 수...
# 38063  보수적인 은행 특성상 굉장히 경직적인 문화가 많음, 어설픈 사내 문화 프로그램은 별...
# 38064            지점에 따라 다르지만 실적압박을 받을 수 있어 스트레스를 받을 수 있음
# 38065  어딜가나 부서by부서, 상사by상사 이지만, 전반적으로 상하 관계가 매우 확실하며,...
# 38066  2016년 들어서 은행 연봉 삭감에 관한 이야기들이 점점 더 많이 나오고 있으며 빡...
# 38067  출근시간이 회의준비로 대체로 일찍 와야하고 퇴근역시 마찬가지이다.\n잡일이 대다수....
# 38068              동종업계 대비 뚜렷한 장점과 특징이 없음. 전산 통합 후 혼란 예상
# 38069  은행권이라 영업의 압박은 어느 정도 있는 듯.... 영업점에 비해 본사에서 근무하면...
# 38070  높은 영업압박과 타 시중은행보다 상대적으로 낮은 연봉과 복지, 또한 야근도 만만치 ...
# 38071  실적압박이 정말 너무 심하고, 직원이 인사발령 나도 어지간해선 후임이 충원 잘 안돼...
# 38072                한국기업의 공통된 문제인 상사눈치보기, 융통적이지 못한 일처리?
# 38073            은행특유의 야근문화. 주말은 있다지만 글쎄... 주말에도 지인영업 필수
# 38074   조직에 의한 영업력이 약하고, 개인별 영업력에 의존하는 듯합니다. 업무량이 과다합니다.
# 38075             과반수이상의 직원들이 야근을하며, 타 은행과 비교하여 급여수준이 낮음
# 38076  지점이라면 실적 압박은 당연한것이긴하나 압박강도 꽤 있음 정부 정책에 따라 업무 영...
# 38077  업무강도가 많이 쎈 편이고 야근이 거의 생활화 돼있음.은행원이라고 정시 퇴근을 생각...
# 38078  출근시간 이르고 퇴근시간 늦음. 시간외 근무 시스템도 지점에 따라 다르기에 성향이 ...
# 38079  업무 많음(실적)\n소문 조심\n입 조심\n감정노동 다반사\n철저한 서비스직\n점심...
# 38080  영업 압박이 강하고, 문어발적으로 사업을 늘리지만 영 신통치 않음\n또한 연봉이 타...
# 38081  인턴을 기준으로 보았을때 아이디어만 빼먹는듯한 느낌을 받으며 분위기가 완전히 경쟁적...
# 38082  일이 어려운건 아닌데. 처리해야 할 업무가 많다. 영업시간중에는 자리를 비우기 어렵...
# 38083  업무 과중이 많고 실적압박이 심함 조직원들의 경쟁을 부추겨 조직원들의 스트레스도 상...
# 38084           회식이... 술을 좋아하시면 많습니다. 아.. 그냥 많을수 있습니다...
# 38085  은행특성상 야근이 많으며 각부서별로 고충이 있겠지만 특히 어느한부서가 심하게 야근이...
# 38086                     빡센문화 야근을 밥먹듯이하는사람많음 승진과열경쟁 부추김
# 38087                  다양한 은행이 모인만큼 문화가 다르지만 성과로 평가하는 은행
# 38088        과도한 업무와 합병에 따른 전산처리가 아직 미비한점 인사제도에 대한 개선 필요
# 38089  늘 그 자리에 머무는 연봉과 출신의 한계로 인한 넘사벽이 존재. 그리고 일단 비전없...
# 38090  진상고객들 처리가 최대의 단점. 고객들의 민원을 이겨낼 수 있는 멘탈관리와 성실함이...
#
#                                              경영진에게 바라는 점 각 리뷰 평점         직무  \
# 0                      낙하산 및 고인물의 교체 필요\n실무자에 대한 대우개선 필요       1     IT/인터넷
# 1                               기존 사업보다는 신규사업에 투자해야 할 시기       3     IT/인터넷
# 2               경영진에게 크게 바라는점은 없음 !! 그렇게 심한 터치가 없어서 편했나봄       2     IT/인터넷
# 3                 신규 사업에 대한 투자는 좋지만 사람도 돌보는 회사가 됐으면 좋겠다.       3     IT/인터넷
# 4           직원들에 대한 복지나 연봉을 개선하여 동기부여가 될 수 있게 해줬으면 하는 바람       2  경영/기획/컨설팅
# 5      기존 사업도 투자를 해야 발전이 있는 법인데 신규 사업에만 투자하지 말고 기존 사업...       1     IT/인터넷
# 6                                목표를 확실하게 하고 그에 맞는 결정 필요       3     IT/인터넷
# 7       기존사업 활성화에 더욱 중점을 두고, 신규사업도 사업성 잘 판단하여 진행하였으면 좋겠음       2     IT/인터넷
# 8      기존의 아이템 한계를 인정하고 새로운 시장을 적극적으로 개척하려는 경영진의 의지가 ...       3     IT/인터넷
# 9           비젼을 구성원에게 제시해주세요. 믿고 따라갈 빛이 보여야 힘이 날 것 같습니다.       2     IT/인터넷
# 10     IT로 성공하는 업체들이 개부럽다.\n계속 SI납품으로 연명하는 회사로 남을 것인지...       1     IT/인터넷
# 11                      이랬다 저랬다, 대기업의 눈치를 봐가며 사업하는게 한심함.       3     IT/인터넷
# 12     직원들의 이야기를 자신의 기준에 듣지 말고 직원의 기준으로 들엇으면. 듣고 나면 흘...       2     IT/인터넷
# 13       IT기업답게 변화하였으면 좋겠다. IT기업이 맞나 싶을정도로 구닥다리 경영이 심하다.       3     IT/인터넷
# 14     직원들 요구사항을 철저히 경청하고, 성의 있는 협의 자세를 가지기 바라며, 제품 로...       2     IT/인터넷
# 15     일을 그렇게 많이 시키면 연봉을 많이 주세요.\n적은 인원으로 일을 많이 시키니까 ...       1     IT/인터넷
# 16                조직간에 협업이 매우 부족하다.\n복리후생이 10년 넘게 그대로이다.       3     IT/인터넷
# 17     실질적으로 일하는 사원, 대리급들이 나가지 않게 조치가 필요합니다.\n실무에 투입시...       2     IT/인터넷
# 18                               시스템적으로 회사 문화 쇄신이 필요해 보임       3     IT/인터넷
# 19     연구개발본부 군대 문화는 임원 혼자서 바꿀 수 있는게 아닌듯. 이미 너무 오랜기간 ...       2     IT/인터넷
# 20     오래된 기업문화를 한번에 바꿀수는 없지만 조금더 창의적인 기업문화로 변화 되었으면 합니다       1     IT/인터넷
# 21     조금씩이라도 개선하는쪽으로 방향을 잡길 바랍니다. 지금상태로는 점차적인 하락세를 벗...       3        디자인
# 22     호황 때 축적했던 자본을 투자실패로 대부분 날린 만큼, 이를 만회하여 직원들에게 만...       2     IT/인터넷
# 23          매년 평가에 상관도 평가할 수 있게 하여 더 객관적인 평가가 이루어질 수 있도록       3     IT/인터넷
# 24                 공정한 평가가 필요하며, 실제 업무 기여도에따른 연봉 인상이 필요함       2     IT/인터넷
# 25                     왜 있는 사람은 계속 있고 새로운 사람이 나가는지 알길...       1     IT/인터넷
# 26             신기술이나 자체 기술력을 보유해야 할 것 같다\n신속한 의사결정이 필요하다       3     IT/인터넷
# 27                       전문경영인 체제로 가야할듯\n신규인력채용이 많이 필요할듯       2     IT/인터넷
# 28            개인주의 성향이 강한 것 같아 전체적으로 단합할 수 있는 기회가 많았으면 함       3     IT/인터넷
# 29     선행기술과 사람에 대한 투자가 필요합니다. 업무도 역량도 복지도 정체되어있는점에대해...       2     IT/인터넷
# ...                                                  ...     ...        ...
# 38061                  직원들의 불만을 듣고 비현실적인 영업목표를 수정했으면 좋겠음       4      금융/재무
# 38062  합리적인 복지 및 보상체계를 마련해 주었으면. 해외지점을 잘 이끌어줄 수 있는 윗계...       2      금융/재무
# 38063                        보수적인 은행 특성상 굉장히 경직적인 문화가 많음       3      금융/재무
# 38064                    비정규직에 대한 처우 개선이 필요하다고 생각 합니다 저는       2      금융/재무
# 38065  하드웨어 적으론 성장하고 커가고 있는 것 같으나(합병 등), 그만한 직원들에 대한 ...       3      인사/총무
# 38066  힘든 경제 상황 속에서도 채용을 늘리려 하고 복지를 향상시키려는 노력이 참 좋은 것...       4      금융/재무
# 38067  보수적인 문화가 개선되면 좋을 것 같습니다.\n지방일경우 연령대가 높아서 연고지를 ...       2      인사/총무
# 38068            전산 관리에 더 투자했으면...불안정한 시스템으로 업무 효율이 떨어진다       3      금융/재무
# 38069  은행권의 공통적인 문제점인 영업 압박...... 영업 압박이 줄어들었으면\n그치만 ...       2   마케팅/시장조사
# 38070                 높은 영업압박만 없으면 위의 단점들이 대부분 해결될 거라 본다       3      금융/재무
# 38071   직원들한테 실적압박좀 그만하고, 실적 압박할 시간에 좋은 상품 개발에 좀 더 노력할 것       4      금융/재무
# 38072                  적극적으로 인턴에게 일할 수 있는 기회를 부여했으면 좋겠다.       2      금융/재무
# 38073             은행업자체가 사장돼가는 느낌. 영업으로 메꿀수 있는 거 같진 않습니다       3      금융/재무
# 38074  조직에 의한 영업력 제고가 필요하다고 생각합니다. 조직의 체계를 조금더 체계화하면 ...       2      금융/재무
# 38075          외부에 보여지는것에만 너무 집중하지말았으면 하며 회의가 너무 빈번하고 길다       3  경영/기획/컨설팅
# 38076      제살 깎아 먹기 식의 실적 압박이 없어야 하며 수익이\n큰 기업영업에 집중이 필요       4      금융/재무
# 38077                           좀 더 경쟁력을 갖춘 마케팅이 필요해 보임.       2      금융/재무
# 38078  직원에 대한 제대로된 보상체계가 필요함. 회사에 대한 자긍심을 키워줄 수 있는 교육...       3      금융/재무
# 38079  타 기업과는 다르게 합리적인 복지혜택과 연봉이지만 그만큼 업무 또한 많은 곳 앞으로...       2      금융/재무
# 38080  불필요한 문어발식 사업확장을 하지말고 본인들이 잘하는 PB분야의 역량을 강화하고 기...       3      금융/재무
# 38081            신입이 들어오자마자 영업으로 내보내면 퇴사율이 높아질수 밖에 없습니다.       4      법률/법무
# 38082  이제 영업점 업무의 한계가 분명하기 때문에 사업구조 재편이 필요하다.새로운 상품개발...       2      영업/제휴
# 38083      실적보다는 다양한 사업플랫폼으로 다각화하는 하나금융그룹으로 성장할 수 있기바랍니다       3      금융/재무
# 38084       음 요즘 비용절감 많이 강조하시는데\n필요한 곳만 비용절감 하셨으면...합니다.       2     IT/인터넷
# 38085       이후 온라인은행이 더욱더 개발되면 현존하는 은행들과의 차별화된 강점을 설립해야함       3   서비스/고객지원
# 38086            야근을최소화하고 경쟁과 영업압박을 너무 주지않아야 임직원들이 버팀...       4      금융/재무
# 38087  단기실적 보단 지속가능 경영의 실현이 필요할때\n통합에 관한 제도 등의 결정은 빠르...       2      금융/재무
# 38088            합병 시너지를 행원들까지 누릴 수 있게 인사제도 개선이 필요해 보입니다       3      금융/재무
# 38089                               개인과 기업을 구분하지 말고 대우하길       2      금융/재무
# 38090  영업압박에 대한 부담감이 낮았으면 좋겠고, 은행원들의 고충을 좀 더 면밀하게 살펴서...       3      금융/재무
#
#       재직상태  지역 리뷰 좋아요 개수 label
# 0      전직원  경기         0     1
# 1      현직원  경기         0     1
# 2      전직원  경기         0     1
# 3      전직원  서울         0     1
# 4      전직원  서울         0     1
# 5      현직원  경기         1     1
# 6      현직원  경기         4     1
# 7      현직원  경기         2     1
# 8      전직원  경기         1     1
# 9      현직원  경기         2     1
# 10     현직원  경기         2     1
# 11     전직원  경기         1     1
# 12     전직원  경기         0     1
# 13     현직원  경기         0     1
# 14     전직원  경기         0     1
# 15     전직원  경기         0     1
# 16     현직원  경기         1     1
# 17     전직원  경기         0     1
# 18     전직원  경기         0     1
# 19     전직원  경기         0     1
# 20     전직원  경기         1     1
# 21     전직원  경기         1     1
# 22     현직원  경기         0     1
# 23     현직원  경기         1     1
# 24     현직원  경기         2     1
# 25     전직원  경기         1     1
# 26     전직원  경기         0     1
# 27     현직원  경기         0     1
# 28     전직원  경기         0     1
# 29     현직원  경기         0     1
# ...    ...  ..       ...   ...
# 38061  현직원  서울         0     0
# 38062  전직원  해외         0     0
# 38063  전직원  서울         0     0
# 38064  전직원  서울         0     0
# 38065  전직원  서울         0     0
# 38066  전직원  서울         0     0
# 38067  전직원  충남         0     0
# 38068  전직원  충남         0     0
# 38069  전직원  서울         0     0
# 38070  전직원  대전         0     0
# 38071  현직원  서울         0     0
# 38072  전직원  서울         0     0
# 38073  현직원  서울         0     0
# 38074  전직원  서울         1     0
# 38075  전직원  서울         0     0
# 38076  현직원  서울         0     0
# 38077  전직원  서울         0     0
# 38078  전직원  서울         0     0
# 38079  전직원  서울         0     0
# 38080  전직원  충남         0     0
# 38081  전직원  서울         0     0
# 38082  전직원  서울         0     0
# 38083  현직원  경기         0     0
# 38084  현직원  서울         1     0
# 38085  전직원  기타         0     0
# 38086  전직원  서울         0     0
# 38087  현직원  서울         0     0
# 38088  현직원  서울         0     0
# 38089  전직원  서울         0     0
# 38090  현직원  서울         1     0
#
# [38091 rows x 23 columns]

# %% [markdown]
# # label 비중

# %%
label_cnt = list(total_data.groupby('label').size())

# %%
label_per = []

for i in range(len(label_cnt)):
    per = label_cnt[i]/sum(label_cnt) * 100
    label_per.append(per)

# %%
label_per
# Out:
# [16.074663306292823,
#  20.256753563833975,
#  32.317345304665146,
#  11.005224331206847,
#  20.34601349400121]

# %% [markdown]
# # 특수문자 제거

# %%
data['제목'] = data['제목'].str.replace("[^a-zA-Zㄱ-ㅎ가-힣0-9]", " ")
data['장점'] = data['장점'].str.replace("[^a-zA-Zㄱ-ㅎ가-힣0-9]", " ")
data['단점'] = data['단점'].str.replace("[^a-zA-Zㄱ-ㅎ가-힣0-9]", " ")
data['경영진에게 바라는 점'] = data['경영진에게 바라는 점'].str.replace("[^a-zA-Zㄱ-ㅎ가-힣0-9]", " ")

# %% [markdown]
# # 형태소화, pos태그 카운트, 불용품사, 불용어, 단어 길이 1개 토큰 제거

# %%
total_word=[]
tag_count=[]

for i in tqdm_notebook(range(len(total_data))):
    
    mecab=Mecab()
    mecab_text=total_data['장점'][i]

    Mecab_tag=mecab.pos(mecab_text)
    
    tag_count.append(Counter(Mecab_tag).most_common())
    

    mecab.morphs(mecab_text)
    
    
    stopPos=['MAJ','IC','JKS','JKC','JKG','JKO','JKB','JKV','JKQ','JX','JC','XSA','EP','EF','EC','ETN','ETM','VV','VA','VX','MM','SF']

    stopwords = pd.read_csv('stopwords.csv', dtype=str, sep=',', encoding='utf-8', names=['stopword'])
    stopWord = np.array(stopwords['stopword'])

    
    # 불용품사, 불용어 제거 및 한 글자 토큰 제거
    word = []
    for tag in Mecab_tag:
        if tag[1] not in stopPos:
            if tag[0] not in stopWord :
                if len(tag[0]) > 1 :
                    word.append(tag[0])
       
    
    
    total_word.append(word)
# Out:
# HBox(children=(IntProgress(value=0, max=38091), HTML(value='')))

# %% [markdown]
# # 특정 갯수 이하 토큰 제거

# %%
cnt_ls =[]

for a in range(len(total_word)):
    cnt_ls += total_word[a]
    
counter_word=Counter(cnt_ls).most_common()  

c=counter_word

# %%
c
# Out:
# [('분위기', 8829),
#  ('복지', 7939),
#  ('회사', 7245),
#  ('업무', 7101),
#  ('자유', 6266),
#  ('기업', 5780),
#  ('가능', 5447),
#  ('연봉', 5424),
#  ('연차', 5280),
#  ('근무', 4867),
#  ('사람', 4568),
#  ('직원', 4371),
#  ('문화', 3971),
#  ('사용', 3092),
#  ('눈치', 3066),
#  ('로운', 2946),
#  ('안정', 2940),
#  ('많이', 2883),
#  ('장점', 2788),
#  ('휴가', 2755),
#  ('수평', 2678),
#  ('다양', 2663),
#  ('부서', 2380),
#  ('지원', 2346),
#  ('야근', 2339),
#  ('퇴근', 2253),
#  ('환경', 2142),
#  ('급여', 2026),
#  ('비교', 2021),
#  ('업계', 1981),
#  ('보장', 1898),
#  ('생각', 1863),
#  ('기회', 1806),
#  ('사내', 1779),
#  ('경험', 1711),
#  ('수준', 1696),
#  ('강도', 1652),
#  ('제공', 1638),
#  ('출퇴근', 1606),
#  ('연구', 1561),
#  ('매우', 1529),
#  ('비해', 1524),
#  ('때문', 1511),
#  ('대한', 1480),
#  ('경우', 1401),
#  ('배울', 1394),
#  ('개인', 1359),
#  ('정도', 1352),
#  ('교육', 1301),
#  ('나름', 1223),
#  ('최고', 1214),
#  ('조직', 1213),
#  ('입니다', 1203),
#  ('기관', 1168),
#  ('성장', 1159),
#  ('체계', 1133),
#  ('위치', 1122),
#  ('직장', 1108),
#  ('자부심', 1092),
#  ('합니다', 1035),
#  ('노력', 994),
#  ('본인', 964),
#  ('출근', 963),
#  ('워라', 954),
#  ('회식', 948),
#  ('수당', 940),
#  ('사업', 938),
#  ('대부분', 937),
#  ('제도', 935),
#  ('개발', 920),
#  ('가족', 915),
#  ('시스템', 903),
#  ('대비', 901),
#  ('관계', 879),
#  ('월급', 868),
#  ('점심', 859),
#  ('공기업', 853),
#  ('정말', 843),
#  ('국내', 831),
#  ('없이', 821),
#  ('시설', 817),
#  ('해외', 816),
#  ('혜택', 815),
#  ('만큼', 800),
#  ('영업', 790),
#  ('자율', 789),
#  ('서로', 788),
#  ('해서', 769),
#  ('분야', 766),
#  ('동종', 761),
#  ('능력', 759),
#  ('서울', 745),
#  ('은행', 738),
#  ('다닐', 727),
#  ('복리', 722),
#  ('정년', 715),
#  ('프로젝트', 713),
#  ('인턴', 706),
#  ('후생', 678),
#  ('구조', 675),
#  ('압박', 671),
#  ('글로벌', 665),
#  ('생활', 658),
#  ('사원', 640),
#  ('사무실', 640),
#  ('신입', 633),
#  ('공공', 633),
#  ('정규직', 630),
#  ('자유로움', 628),
#  ('챙겨', 627),
#  ('그룹', 627),
#  ('식당', 627),
#  ('본사', 613),
#  ('육아', 609),
#  ('발전', 607),
#  ('상대', 604),
#  ('휴직', 593),
#  ('칼퇴근', 585),
#  ('만족', 580),
#  ('상사', 575),
#  ('존중', 560),
#  ('스트레스', 558),
#  ('여성', 555),
#  ('외국', 552),
#  ('오래', 551),
#  ('보수', 549),
#  ('계발', 539),
#  ('계약직', 535),
#  ('초봉', 530),
#  ('복장', 526),
#  ('윗사람', 508),
#  ('정시', 505),
#  ('할인', 502),
#  ('승진', 501),
#  ('부분', 499),
#  ('강요', 499),
#  ('관련', 498),
#  ('규모', 493),
#  ('필요', 492),
#  ('지급', 492),
#  ('해도', 490),
#  ('성과', 489),
#  ('로움', 489),
#  ('전반', 488),
#  ('유연', 487),
#  ('기본', 482),
#  ('지점', 481),
#  ('금융', 475),
#  ('굉장히', 471),
#  ('느낌', 470),
#  ('아주', 465),
#  ('연구원', 465),
#  ('관리', 465),
#  ('병원', 458),
#  ('실적', 454),
#  ('확실', 453),
#  ('전문', 452),
#  ('자체', 446),
#  ('네임', 444),
#  ('위한', 443),
#  ('제외', 441),
#  ('경력', 441),
#  ('대체로', 440),
#  ('역량', 439),
#  ('주말', 439),
#  ('여유', 436),
#  ('대우', 435),
#  ('전체', 435),
#  ('차이', 433),
#  ('동료', 432),
#  ('노조', 430),
#  ('저녁', 429),
#  ('현장', 428),
#  ('된다', 426),
#  ('직급', 425),
#  ('이용', 425),
#  ('적당', 424),
#  ('건물', 422),
#  ('식사', 422),
#  ('나옴', 421),
#  ('고객', 420),
#  ('브랜드', 419),
#  ('기숙사', 418),
#  ('여자', 414),
#  ('대해', 413),
#  ('아르바이트', 413),
#  ('진행', 407),
#  ('준다', 406),
#  ('우수', 405),
#  ('계열사', 404),
#  ('느낄', 403),
#  ('편안', 398),
#  ('위해', 398),
#  ('해줌', 396),
#  ('대체', 392),
#  ('서비스', 391),
#  ('마인드', 386),
#  ('10', 385),
#  ('신경', 385),
#  ('무료', 381),
#  ('지역', 378),
#  ('너무', 376),
#  ('특성', 375),
#  ('운영', 375),
#  ('고용', 372),
#  ('상당히', 372),
#  ('산업', 370),
#  ('상위', 367),
#  ('열심히', 365),
#  ('추천', 360),
#  ('박사', 359),
#  ('평균', 356),
#  ('기술', 349),
#  ('입사', 347),
#  ('자동차', 346),
#  ('이미지', 342),
#  ('공무원', 342),
#  ('의견', 340),
#  ('아님', 340),
#  ('보임', 340),
#  ('끼리', 339),
#  ('일반', 336),
#  ('인간', 334),
#  ('도움', 333),
#  ('기반', 330),
#  ('터치', 329),
#  ('식대', 327),
#  ('존재', 322),
#  ('됩니다', 319),
#  ('근속', 315),
#  ('중소기업', 313),
#  ('연구소', 306),
#  ('해야', 304),
#  ('훌륭', 301),
#  ('계속', 300),
#  ('투자', 300),
#  ('배려', 296),
#  ('매출', 295),
#  ('제품', 295),
#  ('기준', 294),
#  ('직무', 294),
#  ('30', 294),
#  ('카페', 293),
#  ('활동', 293),
#  ('시장', 293),
#  ('수직', 288),
#  ('균형', 287),
#  ('탄탄', 286),
#  ('부산', 286),
#  ('택시', 284),
#  ('영어', 283),
#  ('개선', 283),
#  ('현대', 282),
#  ('통해', 281),
#  ('주변', 280),
#  ('편한', 280),
#  ('빠른', 280),
#  ('수행', 279),
#  ('인정', 279),
#  ('아닌', 279),
#  ('중요', 277),
#  ('구내식당', 277),
#  ('인지', 277),
#  ('깨끗', 276),
#  ('제약', 276),
#  ('합리', 276),
#  ('비슷', 275),
#  ('국가', 274),
#  ('아침', 273),
#  ('별로', 273),
#  ('대표', 273),
#  ('그만큼', 272),
#  ('한다는', 271),
#  ('무난', 270),
#  ('편함', 269),
#  ('포인트', 269),
#  ('이직', 269),
#  ('문제', 267),
#  ('밸류', 266),
#  ('잡혀', 265),
#  ('가질', 265),
#  ('깔끔', 264),
#  ('그나마', 264),
#  ('경영진', 264),
#  ('사기업', 262),
#  ('임금', 261),
#  ('내부', 260),
#  ('비용', 258),
#  ('친절', 258),
#  ('기간', 256),
#  ('활용', 255),
#  ('다름', 255),
#  ('공부', 254),
#  ('쾌적', 252),
#  ('지속', 252),
#  ('그냥', 251),
#  ('걱정', 251),
#  ('보유', 250),
#  ('경쟁', 250),
#  ('학교', 250),
#  ('라서', 250),
#  ('성과급', 250),
#  ('정부', 248),
#  ('업체', 247),
#  ('버스', 247),
#  ('바이', 246),
#  ('소통', 246),
#  ('평가', 244),
#  ('지방', 243),
#  ('실력', 241),
#  ('부담', 240),
#  ('새로운', 240),
#  ('행사', 240),
#  ('관심', 239),
#  ('팀장', 238),
#  ('커리어', 235),
#  ('처리', 233),
#  ('순환', 233),
#  ('차별', 233),
#  ('꼰대', 232),
#  ('인센티브', 231),
#  ('단점', 231),
#  ('보상', 231),
#  ('한국', 230),
#  ('변화', 229),
#  ('출장', 229),
#  ('시급', 229),
#  ('장비', 228),
#  ('집중', 227),
#  ('공장', 227),
#  ('편리', 226),
#  ('탄력', 226),
#  ('카드', 225),
#  ('사장', 224),
#  ('그런지', 223),
#  ('비해서', 222),
#  ('상승', 221),
#  ('지켜', 221),
#  ('안전', 221),
#  ('간식', 220),
#  ('지사', 219),
#  ('사회', 218),
#  ('경영', 218),
#  ('조정', 217),
#  ('명절', 216),
#  ('사이', 215),
#  ('개발자', 215),
#  ('휴일', 215),
#  ('출연', 215),
#  ('구성원', 215),
#  ('영화', 214),
#  ('적극', 213),
#  ('확실히', 212),
#  ('의지', 210),
#  ('52', 210),
#  ('유지', 209),
#  ('헬스', 208),
#  ('딱히', 207),
#  ('전혀', 206),
#  ('무제', 206),
#  ('휴식', 206),
#  ('수도', 205),
#  ('사택', 205),
#  ('IT', 204),
#  ('자주', 204),
#  ('누릴', 203),
#  ('게임', 203),
#  ('미래', 203),
#  ('마음', 203),
#  ('점점', 202),
#  ('프로세스', 202),
#  ('나이', 201),
#  ('인력', 201),
#  ('분담', 200),
#  ('워크', 199),
#  ('유연근', 198),
#  ('현재', 198),
#  ('최대', 196),
#  ('보통', 194),
#  ('인해', 194),
#  ('이름', 193),
#  ('바케', 193),
#  ('연수', 192),
#  ('매년', 191),
#  ('과제', 191),
#  ('정확', 191),
#  ('세계', 190),
#  ('외부', 190),
#  ('컨설팅', 189),
#  ('충분히', 188),
#  ('여건', 188),
#  ('인사', 188),
#  ('인지도', 188),
#  ('20', 187),
#  ('책임', 187),
#  ('성격', 187),
#  ('교통', 185),
#  ('스케줄', 185),
#  ('퇴사', 184),
#  ('일부', 184),
#  ('기대', 182),
#  ('밸런스', 182),
#  ('이전', 181),
#  ('저렴', 180),
#  ('중견', 178),
#  ('대신', 178),
#  ('대학', 177),
#  ('건설', 176),
#  ('생산', 175),
#  ('시도', 174),
#  ('망할', 174),
#  ('50', 174),
#  ('자리', 174),
#  ('절대', 173),
#  ('도서', 172),
#  ('적응', 172),
#  ('향상', 172),
#  ('통근', 172),
#  ('적절', 172),
#  ('공간', 172),
#  ('일정', 171),
#  ('선물', 171),
#  ('항상', 171),
#  ('계열', 170),
#  ('사옥', 170),
#  ('업종', 169),
#  ('커피', 169),
#  ('보너스', 169),
#  ('따로', 168),
#  ('협력', 168),
#  ('줍니다', 168),
#  ('음료', 168),
#  ('형성', 168),
#  ('연령', 166),
#  ('준수', 166),
#  ('임원', 165),
#  ('출산', 165),
#  ('얘기', 165),
#  ('매장', 165),
#  ('메리트', 164),
#  ('참여', 164),
#  ('수익', 163),
#  ('상하', 163),
#  ('프로그램', 163),
#  ('여행', 162),
#  ('학생', 162),
#  ('팀원', 161),
#  ('월차', 161),
#  ('재무', 160),
#  ('지금', 160),
#  ('근무지', 160),
#  ('일찍', 159),
#  ('갖춰져', 159),
#  ('직접', 159),
#  ('에선', 159),
#  ('정책', 158),
#  ('엄청', 156),
#  ('공휴일', 156),
#  ('휴무', 156),
#  ('모습', 154),
#  ('특별', 154),
#  ('딱딱', 154),
#  ('상여금', 154),
#  ('무조건', 154),
#  ('왠만', 153),
#  ('비율', 153),
#  ('출신', 153),
#  ('스스로', 153),
#  ('이동', 152),
#  ('시작', 151),
#  ('인상', 151),
#  ('실험', 151),
#  ('열정', 151),
#  ('지식', 150),
#  ('건강', 150),
#  ('인한', 150),
#  ('만날', 150),
#  ('인재', 149),
#  ('도입', 149),
#  ('벨류', 149),
#  ('광고', 149),
#  ('대리', 148),
#  ('가끔', 148),
#  ('힘든', 148),
#  ('시행', 148),
#  ('진급', 148),
#  ('매니저', 148),
#  ('담당', 147),
#  ('커뮤니케이션', 146),
#  ('구입', 145),
#  ('추가', 145),
#  ('보람', 145),
#  ('부족', 145),
#  ('화학', 145),
#  ('시중', 145),
#  ('적당히', 144),
#  ('라이프', 144),
#  ('의사', 144),
#  ('제일', 143),
#  ('연말', 143),
#  ('해당', 142),
#  ('욕심', 142),
#  ('다를', 140),
#  ('제한', 140),
#  ('이익', 140),
#  ('연구실', 140),
#  ('그렇게', 139),
#  ('위주', 139),
#  ('에겐', 138),
#  ('선택', 138),
#  ('유일', 138),
#  ('조용', 138),
#  ('특유', 138),
#  ('추구', 137),
#  ('제대로', 137),
#  ('진짜', 137),
#  ('빨리', 136),
#  ('식품', 136),
#  ('타사', 136),
#  ('조건', 136),
#  ('나라', 135),
#  ('유동', 135),
#  ('용이', 134),
#  ('대졸', 134),
#  ('건설사', 134),
#  ('부여', 133),
#  ('포함', 133),
#  ('금요일', 132),
#  ('중간', 131),
#  ('협업', 131),
#  ('이외', 131),
#  ('중심', 131),
#  ('봐도', 130),
#  ('적용', 130),
#  ('샌드위치', 130),
#  ('채용', 130),
#  ('장기', 128),
#  ('불구', 127),
#  ('결정', 127),
#  ('기술력', 126),
#  ('접할', 126),
#  ('파견', 126),
#  ('철저히', 126),
#  ('연금', 126),
#  ('활발', 125),
#  ('본부', 124),
#  ('클라이언트', 124),
#  ('중시', 123),
#  ('가정', 123),
#  ('젠틀', 123),
#  ('과장', 123),
#  ('상호', 123),
#  ('임직원', 123),
#  ('삼성', 123),
#  ('동호회', 122),
#  ('구축', 122),
#  ('가진', 122),
#  ('SK', 121),
#  ('근로', 121),
#  ('장려', 120),
#  ('년수', 120),
#  ('서비스업', 120),
#  ('과정', 119),
#  ('비정규직', 119),
#  ('권장', 119),
#  ('또래', 119),
#  ('어려움', 118),
#  ('사고', 118),
#  ('카페테리아', 118),
#  ('상황', 118),
#  ('개개인', 118),
#  ('직종', 118),
#  ('교대', 118),
#  ('개인주의', 117),
#  ('유통', 117),
#  ('예전', 117),
#  ('반차', 116),
#  ('인원', 116),
#  ('효율', 116),
#  ('수월', 116),
#  ('엔지니어', 116),
#  ('친구', 115),
#  ('보단', 115),
#  ('식비', 115),
#  ('강제', 115),
#  ('선배', 114),
#  ('편의', 114),
#  ('널널', 114),
#  ('정치', 113),
#  ('마련', 113),
#  ('이벤트', 113),
#  ('철저', 113),
#  ('공짜', 113),
#  ('제조업', 113),
#  ('여의도', 113),
#  ('인프라', 113),
#  ('합병', 113),
#  ('군대', 112),
#  ('반영', 112),
#  ('남자', 112),
#  ('센터', 112),
#  ('셔틀버스', 112),
#  ('구매', 112),
#  ('충분', 111),
#  ('매일', 111),
#  ('프로', 111),
#  ('차량', 111),
#  ('그리', 110),
#  ('100', 110),
#  ('통한', 110),
#  ('여직', 110),
#  ('스러운', 110),
#  ('사무', 109),
#  ('이해', 109),
#  ('준비', 109),
#  ('해결', 109),
#  ('평등', 109),
#  ('성향', 108),
#  ('웬만', 108),
#  ('보험', 108),
#  ('교수', 108),
#  ('처음', 107),
#  ('도서관', 107),
#  ('전문가', 107),
#  ('작업', 106),
#  ('계약', 106),
#  ('자녀', 106),
#  ('역사', 106),
#  ('하루', 106),
#  ('빵빵', 106),
#  ('타이틀', 106),
#  ('다운', 105),
#  ('구성', 105),
#  ('비전', 105),
#  ('메뉴', 105),
#  ('교대근무', 105),
#  ('근무자', 104),
#  ('소소', 104),
#  ('음식', 104),
#  ('생산직', 104),
#  ('호봉', 104),
#  ('경기', 103),
#  ('바쁜', 103),
#  ('전공', 103),
#  ('단위', 103),
#  ('조성', 103),
#  ('상관없이', 102),
#  ('키울', 102),
#  ('뛰어난', 102),
#  ('인식', 102),
#  ('근처', 102),
#  ('여름', 102),
#  ('특정', 102),
#  ('최대한', 102),
#  ('인성', 101),
#  ('케이스', 101),
#  ('연장', 101),
#  ('법인', 101),
#  ('열려', 101),
#  ('여름휴가', 100),
#  ('판교', 100),
#  ('역할', 100),
#  ('디자인', 100),
#  ('배치', 100),
#  ('외근', 100),
#  ('시험', 100),
#  ('사소', 100),
#  ('운편', 99),
#  ('조절', 99),
#  ('긍정', 99),
#  ('상당', 99),
#  ('라면', 99),
#  ('현대차', 99),
#  ('페이', 98),
#  ('확보', 98),
#  ('대출', 97),
#  ('호칭', 97),
#  ('마음껏', 97),
#  ('프리', 97),
#  ('홍보', 97),
#  ('가치', 97),
#  ('최상위', 97),
#  ('회의', 97),
#  ('수주', 97),
#  ('기획', 97),
#  ('설계', 97),
#  ('정신', 97),
#  ('지향', 96),
#  ('경쟁력', 96),
#  ('도전', 96),
#  ('신청', 95),
#  ('시기', 95),
#  ('학자금', 95),
#  ('향후', 95),
#  ('이야기', 95),
#  ('꾸준', 95),
#  ('대학교', 95),
#  ('나온다', 94),
#  ('측면', 94),
#  ('마케팅', 94),
#  ('대외', 94),
#  ('강압', 94),
#  ('오프', 94),
#  ('네트워크', 93),
#  ('현금', 93),
#  ('동일', 93),
#  ('안마', 93),
#  ('직군', 93),
#  ('전환', 93),
#  ('혁신', 93),
#  ('형태', 93),
#  ('처우', 93),
#  ('기본급', 93),
#  ('어린이집', 93),
#  ('끈끈', 92),
#  ('부장', 92),
#  ('개월', 92),
#  ('휴게실', 92),
#  ('수요일', 92),
#  ('똑똑', 92),
#  ('어려운', 91),
#  ('접근', 91),
#  ('간섭', 91),
#  ('강점', 91),
#  ('오너', 91),
#  ('기한', 91),
#  ('여서', 91),
#  ('아무래도', 91),
#  ('줘서', 90),
#  ('실제로', 90),
#  ('도와', 90),
#  ('교통비', 90),
#  ('요즘', 90),
#  ('주어짐', 89),
#  ('꼬박꼬박', 89),
#  ('방향', 89),
#  ('명확', 89),
#  ('실무', 89),
#  ('유명', 89),
#  ('신규', 88),
#  ('주도', 88),
#  ('이사', 88),
#  ('입장', 88),
#  ('스타트업', 88),
#  ('교육비', 87),
#  ('알바', 87),
#  ('대전', 87),
#  ('주로', 86),
#  ('영역', 86),
#  ('주일', 86),
#  ('사무소', 86),
#  ('40', 85),
#  ('된다면', 85),
#  ('군대식', 85),
#  ('운동', 85),
#  ('맞춰', 85),
#  ('빠름', 85),
#  ('직업', 85),
#  ('들어왔', 85),
#  ('상이', 84),
#  ('롯데', 84),
#  ('파트', 84),
#  ('메이저', 84),
#  ('청소', 84),
#  ('동기', 83),
#  ('생일', 83),
#  ('단순', 83),
#  ('추세', 83),
#  ('원활', 83),
#  ('심야', 83),
#  ('석유', 83),
#  ('금전', 82),
#  ('장기근속', 82),
#  ('교류', 82),
#  ('정보', 82),
#  ('부바', 82),
#  ('프레쉬', 82),
#  ('대한민국', 82),
#  ('체험', 81),
#  ('자랑', 81),
#  ('넉넉', 81),
#  ('성공', 81),
#  ('프라이드', 81),
#  ('공사', 81),
#  ('전국', 81),
#  ('선입', 81),
#  ('석사', 80),
#  ('만족도', 80),
#  ('의료비', 80),
#  ('행정', 80),
#  ('진출', 80),
#  ('적합', 80),
#  ('스펙', 80),
#  ('양호', 80),
#  ('선출', 80),
#  ('덕분', 79),
#  ('에너지', 79),
#  ('포트폴리오', 79),
#  ('구비', 79),
#  ('활성', 78),
#  ('배움', 78),
#  ('외국인', 78),
#  ('사학', 78),
#  ('특별히', 77),
#  ('고민', 77),
#  ('무리', 77),
#  ('무시', 77),
#  ('습득', 77),
#  ('소속', 77),
#  ('추진', 77),
#  ('주휴', 77),
#  ('즐길', 77),
#  ('가격', 77),
#  ('화목', 77),
#  ('실시', 77),
#  ('달리', 77),
#  ('발비', 77),
#  ('근태', 76),
#  ('의자', 76),
#  ('평생', 76),
#  ('공정', 76),
#  ('특근', 76),
#  ('된다는', 76),
#  ('데이', 76),
#  ('야간', 76),
#  ('기를', 76),
#  ('분석', 76),
#  ('건설업', 76),
#  ('아이템', 75),
#  ('휴가비', 75),
#  ('학원', 75),
#  ('매점', 75),
#  ('대학원', 75),
#  ('운행', 75),
#  ('의료', 75),
#  ('난이도', 75),
#  ('단축', 75),
#  ('검진', 74),
#  ('사실', 74),
#  ('영향', 74),
#  ('어학', 74),
#  ('매달', 74),
#  ('중식', 74),
#  ('패밀리', 74),
#  ('파워', 74),
#  ('엄청난', 74),
#  ('동아리', 74),
#  ('오픈', 74),
#  ('자연', 74),
#  ('제때', 74),
#  ('사무직', 74),
#  ('모난', 73),
#  ('선후배', 73),
#  ('결혼', 73),
#  ('원한다면', 73),
#  ('특수', 73),
#  ('거리', 73),
#  ('정착', 73),
#  ('공채', 73),
#  ('기억', 73),
#  ('시즌', 73),
#  ('편차', 72),
#  ('유한', 72),
#  ('한편', 72),
#  ('튼튼', 72),
#  ('의사소통', 72),
#  ('알려', 72),
#  ('바쁠', 72),
#  ('판매', 72),
#  ('석식', 72),
#  ('발생', 72),
#  ('개방', 72),
#  ('남녀', 72),
#  ('타행', 72),
#  ('방학', 72),
#  ('국책은행', 72),
#  ('라인', 71),
#  ('영업직', 71),
#  ('정직', 71),
#  ('지리', 71),
#  ('잔업', 71),
#  ('정해진', 71),
#  ('공기', 71),
#  ('설비', 71),
#  ('데이터', 71),
#  ('생김', 70),
#  ('노하우', 70),
#  ('초반', 70),
#  ('부드러운', 70),
#  ('강한', 70),
#  ('공유', 70),
#  ('스타일', 70),
#  ('방식', 70),
#  ('착함', 69),
#  ('해고', 69),
#  ('해외여행', 69),
#  ('강함', 69),
#  ('연월', 69),
#  ('자기계', 69),
#  ('그대로', 68),
#  ('세미나', 68),
#  ('까진', 68),
#  ('쉬움', 68),
#  ('인맥', 68),
#  ('으신', 68),
#  ('간호사', 68),
#  ('단체', 67),
#  ('과거', 67),
#  ('비중', 67),
#  ('이유', 67),
#  ('정해져', 67),
#  ('12', 67),
#  ('숙소', 67),
#  ('기계', 67),
#  ('지원금', 66),
#  ('근시', 66),
#  ('주어진', 66),
#  ('권한', 66),
#  ('목표', 66),
#  ('최상', 66),
#  ('강남', 66),
#  ('국책', 66),
#  ('기존', 66),
#  ('최소', 66),
#  ('상여', 66),
#  ('제시', 66),
#  ('국제', 66),
#  ('단기간', 66),
#  ('도시', 66),
#  ('자금', 65),
#  ('아무', 65),
#  ('즐거운', 65),
#  ('독점', 65),
#  ('대상', 65),
#  ('상관', 65),
#  ('여타', 65),
#  ('퀄리티', 65),
#  ('보직', 64),
#  ('느껴짐', 64),
#  ('걸로', 64),
#  ('바탕', 64),
#  ('상품권', 64),
#  ('취업', 64),
#  ('플랜트', 64),
#  ('경제', 64),
#  ('사항', 63),
#  ('스러움', 63),
#  ('요구', 63),
#  ('수록', 63),
#  ('모여', 63),
#  ('우대', 63),
#  ('실수', 63),
#  ('경조사', 63),
#  ('솔루션', 63),
#  ('경직', 62),
#  ('가까움', 62),
#  ('강조', 62),
#  ('점유', 62),
#  ('더욱', 62),
#  ('최적', 62),
#  ('대화', 62),
#  ('열린', 62),
#  ('투명', 62),
#  ('금액', 62),
#  ('엔지니어링', 62),
#  ('중상', 61),
#  ('종종', 61),
#  ('권위', 61),
#  ('세끼', 61),
#  ('대구', 61),
#  ('부품', 61),
#  ('이것저것', 61),
#  ('지낼', 61),
#  ('점차', 61),
#  ('자회사', 61),
#  ('유대', 61),
#  ('부문', 61),
#  ('외국어', 61),
#  ('대형', 61),
#  ('확장', 61),
#  ('주택', 60),
#  ('가까운', 60),
#  ('맞출', 60),
#  ('정규', 60),
#  ('화기애애', 60),
#  ('발휘', 60),
#  ('차원', 60),
#  ('유리', 60),
#  ('자료', 60),
#  ('컴퓨터', 60),
#  ('상식', 60),
#  ('불편', 60),
#  ('목적', 60),
#  ('최신', 59),
#  ('전통', 59),
#  ('전산', 59),
#  ('먼저', 59),
#  ('연휴', 59),
#  ('여가', 59),
#  ('정리', 59),
#  ...]

# %%
# 5개 이하
c_5 = c[-9935:]
c_5
# Out:
# [('느껴집니다', 5),
#  ('수동', 5),
#  ('그동안', 5),
#  ('겉모습', 5),
#  ('생겨', 5),
#  ('급속도', 5),
#  ('피티', 5),
#  ('디저트', 5),
#  ('바람', 5),
#  ('정형', 5),
#  ('들으며', 5),
#  ('도출', 5),
#  ('집착', 5),
#  ('가파른', 5),
#  ('필라테스', 5),
#  ('익명', 5),
#  ('강했', 5),
#  ('한발', 5),
#  ('그쪽', 5),
#  ('한다거나', 5),
#  ('초대', 5),
#  ('염색', 5),
#  ('고집', 5),
#  ('어려', 5),
#  ('안마기', 5),
#  ('접종', 5),
#  ('나머진', 5),
#  ('안착', 5),
#  ('고소득', 5),
#  ('개개', 5),
#  ('메이크업', 5),
#  ('독서실', 5),
#  ('점진', 5),
#  ('메디컬', 5),
#  ('pt', 5),
#  ('다채', 5),
#  ('카톡', 5),
#  ('인강', 5),
#  ('다이렉트', 5),
#  ('막힘', 5),
#  ('팍팍', 5),
#  ('수상', 5),
#  ('승승장구', 5),
#  ('어울림', 5),
#  ('생성', 5),
#  ('계열화', 5),
#  ('따라올', 5),
#  ('꿈꾼다면', 5),
#  ('활로', 5),
#  ('다녀볼', 5),
#  ('꺼져', 5),
#  ('해안', 5),
#  ('수혜', 5),
#  ('놔서', 5),
#  ('때때로', 5),
#  ('영남', 5),
#  ('인터', 5),
#  ('지어서', 5),
#  ('크나큰', 5),
#  ('조만간', 5),
#  ('반반', 5),
#  ('요충지', 5),
#  ('응원', 5),
#  ('당량', 5),
#  ('기술자', 5),
#  ('클래식', 5),
#  ('지자체', 5),
#  ('감리', 5),
#  ('리모', 5),
#  ('울타리', 5),
#  ('바꿀', 5),
#  ('기울임', 5),
#  ('명세서', 5),
#  ('종무식', 5),
#  ('줄어듦', 5),
#  ('입구', 5),
#  ('PB', 5),
#  ('어학연수', 5),
#  ('충청', 5),
#  ('연령층', 5),
#  ('관찰', 5),
#  ('걸친', 5),
#  ('탐방', 5),
#  ('초급', 5),
#  ('근교', 5),
#  ('각오', 5),
#  ('약해', 5),
#  ('쇄신', 5),
#  ('운영비', 5),
#  ('양날', 5),
#  ('부각', 5),
#  ('가함', 5),
#  ('시칼', 5),
#  ('가시', 5),
#  ('하급자', 5),
#  ('게시판', 5),
#  ('부사', 5),
#  ('소외', 5),
#  ('계층', 5),
#  ('부회장', 5),
#  ('해결책', 5),
#  ('전업', 5),
#  ('현직', 5),
#  ('PE', 5),
#  ('대근', 5),
#  ('계기', 5),
#  ('골고루', 5),
#  ('장담', 5),
#  ('필두', 5),
#  ('필름', 5),
#  ('극도', 5),
#  ('주중', 5),
#  ('다행히', 5),
#  ('반해', 5),
#  ('마주', 5),
#  ('95', 5),
#  ('아껴', 5),
#  ('이념', 5),
#  ('종근당', 5),
#  ('정돈', 5),
#  ('풍요', 5),
#  ('부담감', 5),
#  ('국적', 5),
#  ('괜찬음', 5),
#  ('자유자재', 5),
#  ('330', 5),
#  ('보전', 5),
#  ('명실상부', 5),
#  ('도태', 5),
#  ('갈지', 5),
#  ('휴계', 5),
#  ('첫발', 5),
#  ('오버', 5),
#  ('실업', 5),
#  ('외향', 5),
#  ('바이저', 5),
#  ('만도', 5),
#  ('성인', 5),
#  ('통과', 5),
#  ('내줌', 5),
#  ('다과', 5),
#  ('대놓고', 5),
#  ('넘친다', 5),
#  ('받아들여', 5),
#  ('국공립', 5),
#  ('철판', 5),
#  ('짜여져', 5),
#  ('싸이트', 5),
#  ('level', 5),
#  ('big', 5),
#  ('고위직', 5),
#  ('근무일', 5),
#  ('Value', 5),
#  ('고스란히', 5),
#  ('벤치마킹', 5),
#  ('영입', 5),
#  ('옮긴', 5),
#  ('DB', 5),
#  ('사업자', 5),
#  ('in', 5),
#  ('국회', 5),
#  ('is', 5),
#  ('오산', 5),
#  ('펀드', 5),
#  ('건자재', 5),
#  ('뭉쳐', 5),
#  ('.).', 5),
#  ('상의', 5),
#  ('차례', 5),
#  ('엔터', 5),
#  ('생략', 5),
#  ('역시', 5),
#  ('승강기', 5),
#  ('쳐도', 5),
#  ('동경', 5),
#  ('격려금', 5),
#  ('쉐어', 5),
#  ('피시', 5),
#  ('부를', 5),
#  ('근강', 5),
#  ('일강', 5),
#  ('영업소', 5),
#  ('박혀', 5),
#  ('알려줌', 5),
#  ('나빠질', 5),
#  ('들어갔', 5),
#  ('명퇴', 5),
#  ('큰소리', 5),
#  ('무리없이', 5),
#  ('재취업', 5),
#  ('행위', 5),
#  ('장례식', 5),
#  ('위로금', 5),
#  ('평택', 5),
#  ('주야', 5),
#  ('고인', 5),
#  ('화성', 5),
#  ('진작', 5),
#  ('.......', 5),
#  ('거부', 5),
#  ('취지', 5),
#  ('와중', 5),
#  ('추울', 5),
#  ('객관적으로', 5),
#  ('완벽히', 5),
#  ('신분당선', 5),
#  ('한몫', 5),
#  ('조중', 5),
#  ('몰려', 5),
#  ('월급제', 5),
#  ('동아', 5),
#  ('그야말로', 5),
#  ('이론', 5),
#  ('머니', 5),
#  ('역삼역', 5),
#  ('외곽', 5),
#  ('신중', 5),
#  ('방안', 5),
#  ('계획서', 5),
#  ('묵묵히', 5),
#  ('한국식', 5),
#  ('다닙니다', 5),
#  ('학식', 5),
#  ('큽니다', 5),
#  ('수시', 5),
#  ('면제', 5),
#  ('열악', 5),
#  ('부사장', 5),
#  ('사대', 5),
#  ('베지', 5),
#  ('폭발', 5),
#  ('성능', 5),
#  ('보험료', 5),
#  ('당당히', 5),
#  ('삼성역', 5),
#  ('오더', 5),
#  ('식목일', 5),
#  ('다나까', 5),
#  ('전적', 5),
#  ('비등', 5),
#  ('메신저', 5),
#  ('항목', 5),
#  ('맞춰져', 5),
#  ('말랑말랑', 5),
#  ('pm', 5),
#  ('호화', 5),
#  ('뛰어나', 5),
#  ('다닐수록', 5),
#  ('접대', 5),
#  ('제일기획', 5),
#  ('판교역', 5),
#  ('진이', 5),
#  ('협의회', 5),
#  ('그럴싸한', 5),
#  ('채권', 5),
#  ('산직', 5),
#  ('culture', 5),
#  ('우리나라', 5),
#  ('설득', 5),
#  ('one', 5),
#  ('취침', 5),
#  ('범죄', 5),
#  ('채택', 5),
#  ('서지', 5),
#  ('농구장', 5),
#  ('매너리즘', 5),
#  ('SAP', 5),
#  ('온다', 5),
#  ('목욕탕', 5),
#  ('자동화', 5),
#  ('삭감', 5),
#  ('중하', 5),
#  ('base', 5),
#  ('Big', 5),
#  ('안락', 5),
#  ('알아볼', 5),
#  ('PF', 5),
#  ('부부', 5),
#  ('입행', 5),
#  ('책임진다는', 5),
#  ('엑셀', 5),
#  ('Project', 5),
#  ('부대시설', 5),
#  ('엿볼', 5),
#  ('쉼터', 5),
#  ('완공', 5),
#  ('lot', 5),
#  ('대덕연구단지', 5),
#  ('횟수', 5),
#  ('기업체', 5),
#  ('한강', 5),
#  ('타격', 5),
#  ('직도', 5),
#  ('도우며', 5),
#  ('태만', 5),
#  ('소서', 5),
#  ('바지', 5),
#  ('도보', 5),
#  ('체질', 5),
#  ('연구생', 5),
#  ('지질', 5),
#  ('정출', 5),
#  ('극상', 5),
#  ('팽배', 5),
#  ('쉬워', 5),
#  ('서민', 5),
#  ('어울려', 5),
#  ('일명', 5),
#  ('가진다', 5),
#  ('갈일', 5),
#  ('그래요', 5),
#  ('충격', 5),
#  ('시민', 5),
#  ('끝난다', 5),
#  ('역대', 5),
#  ('비할', 5),
#  ('이노베이션', 5),
#  ('.........................', 5),
#  ('지바', 5),
#  ('더울', 5),
#  ('삼겹살', 5),
#  ('상회', 5),
#  ('삼성동', 5),
#  ('가까웠', 5),
#  ('수출입', 5),
#  ('집안', 5),
#  ('공가', 5),
#  ('나아졌', 5),
#  ('난다면', 5),
#  ('정의', 5),
#  ('유가', 5),
#  ('프랑스', 5),
#  ('넘쳐남', 5),
#  ('안양', 5),
#  ('배우', 5),
#  ('서브', 5),
#  ('사업비', 5),
#  ('삽질', 5),
#  ('돌아옴', 5),
#  ('나와요', 5),
#  ('근무처', 5),
#  ('기운', 5),
#  ('FPS', 5),
#  ('업데이트', 5),
#  ('불화', 5),
#  ('주거지', 5),
#  ('겉보기', 5),
#  ('창의력', 5),
#  ('광교', 5),
#  ('현기', 5),
#  ('컬쳐', 5),
#  ('나간', 5),
#  ('수석', 5),
#  ('부러워한다', 5),
#  ('센스', 5),
#  ('-.', 5),
#  ('회원권', 5),
#  ('게스트', 5),
#  ('풀타임', 5),
#  ('노가다', 5),
#  ('페인트', 5),
#  ('아람', 5),
#  ('순박', 5),
#  ('대사관', 5),
#  ('마곡', 5),
#  ('요령', 5),
#  ('리스', 5),
#  ('소비', 5),
#  ('산속', 5),
#  ('외교', 5),
#  ('작성법', 5),
#  ('대행', 5),
#  ('쌍용', 5),
#  ('바닷가', 5),
#  ('마세요', 5),
#  ('광고업', 5),
#  ('구속', 5),
#  ('Cj', 5),
#  ('고양이', 5),
#  ('궁금', 5),
#  ('에이티', 5),
#  ('oa', 5),
#  ('쉬웠', 5),
#  ('산뜻', 5),
#  ('목재', 5),
#  ('인도', 5),
#  ('연명', 5),
#  ('emr', 5),
#  ('공립', 5),
#  ('외관', 5),
#  ('흡연', 5),
#  ('해진다', 5),
#  ('증축', 5),
#  ('영화인', 5),
#  ('보여요', 5),
#  ('스웨덴', 5),
#  ('스테이크', 5),
#  ('눌러', 4),
#  ('비나', 4),
#  ('약시', 4),
#  ('통신사', 4),
#  ('분당선', 4),
#  ('가만히', 4),
#  ('플랫', 4),
#  ('부담금', 4),
#  ('상세', 4),
#  ('남부', 4),
#  ('지실', 4),
#  ('명칭', 4),
#  ('감탄', 4),
#  ('컨디션', 4),
#  ('자울', 4),
#  ('대구경북', 4),
#  ('두각', 4),
#  ('커리큘럼', 4),
#  ('가려', 4),
#  ('필자', 4),
#  ('400', 4),
#  ('방판', 4),
#  ('불문', 4),
#  ('연장선', 4),
#  ('저녁밥', 4),
#  ('루트', 4),
#  ('안산', 4),
#  ('동정', 4),
#  ('옛말', 4),
#  ('천억', 4),
#  ('사와', 4),
#  ('단결력', 4),
#  ('............', 4),
#  ('gps', 4),
#  ('동선', 4),
#  ('차후', 4),
#  ('컨벤션', 4),
#  ('제하', 4),
#  ('만남', 4),
#  ('관료', 4),
#  ('노출', 4),
#  ('능력껏', 4),
#  ('늘어날', 4),
#  ('유부녀', 4),
#  ('진행시', 4),
#  ('넓혀', 4),
#  ('예술', 4),
#  ('전방', 4),
#  ('풍경', 4),
#  ('경복궁', 4),
#  ('지켜준다', 4),
#  ('중심가', 4),
#  ('모태', 4),
#  ('쭈욱', 4),
#  ('포스', 4),
#  ('어린이날', 4),
#  ('끈기', 4),
#  ('복합', 4),
#  ('도덕', 4),
#  ('명품', 4),
#  ('??', 4),
#  ('럭셔리', 4),
#  ('번역', 4),
#  ('푸쉬', 4),
#  ('피플', 4),
#  ('올드', 4),
#  ('다곤', 4),
#  ('삼양', 4),
#  ('쓴다면', 4),
#  ('다져진', 4),
#  ('견고', 4),
#  ('요처', 4),
#  ('급속', 4),
#  ('더딘', 4),
#  ('챙긴다', 4),
#  ('우회', 4),
#  ('렌트카', 4),
#  ('한국어', 4),
#  ('부근', 4),
#  ('낭만', 4),
#  ('가을', 4),
#  ('붉힐', 4),
#  ('접수', 4),
#  ('불허', 4),
#  ('대함', 4),
#  ('선한', 4),
#  ('소명', 4),
#  ('여외', 4),
#  ('현채', 4),
#  ('케미', 4),
#  ('바뀐다', 4),
#  ('나빠', 4),
#  ('작음', 4),
#  ('사직', 4),
#  ('남길', 4),
#  ('업적', 4),
#  ('경영난', 4),
#  ('굳건', 4),
#  ('사역', 4),
#  ('상업', 4),
#  ('중요도', 4),
#  ('일괄', 4),
#  ('그걸로', 4),
#  ('수기', 4),
#  ('장함', 4),
#  ('시청역', 4),
#  ('까칠', 4),
#  ('신다고', 4),
#  ('놀라울', 4),
#  ('감축', 4),
#  ('NO', 4),
#  ('일방', 4),
#  ('지나감', 4),
#  ('착실히', 4),
#  ('횡령', 4),
#  ('도중', 4),
#  ('가수', 4),
#  ('평상시', 4),
#  ('외형', 4),
#  ('~!', 4),
#  ('문턱', 4),
#  ('내방', 4),
#  ('프랜', 4),
#  ('걸릴', 4),
#  ('불안감', 4),
#  ('확충', 4),
#  ('이래저래', 4),
#  ('대상자', 4),
#  ('커트', 4),
#  ('변함', 4),
#  ('진다는', 4),
#  ('내고', 4),
#  ('질수록', 4),
#  ('대거', 4),
#  ('나태', 4),
#  ('엘레', 4),
#  ('고취', 4),
#  ('무궁', 4),
#  ('뭉친', 4),
#  ('적격', 4),
#  ('미용', 4),
#  ('바라볼', 4),
#  ('쿠키', 4),
#  ('리티', 4),
#  ('급격히', 4),
#  ('특출난', 4),
#  ('내재', 4),
#  ('시원시원', 4),
#  ('process', 4),
#  ('쑥쑥', 4),
#  ('구상', 4),
#  ('리워드', 4),
#  ('낭비', 4),
#  ('어워드', 4),
#  ('따윈', 4),
#  ('어제', 4),
#  ('술값', 4),
#  ('고기', 4),
#  ('살벌', 4),
#  ('자본금', 4),
#  ('선점', 4),
#  ('하림', 4),
#  ('벗어나', 4),
#  ('산다면', 4),
#  ('즐거울', 4),
#  ('소심', 4),
#  ('꿀릴', 4),
#  ('김해', 4),
#  ('평점', 4),
#  ('생긴', 4),
#  ('대내외', 4),
#  ('기점', 4),
#  ('밑바닥', 4),
#  ('오지', 4),
#  ('기관장', 4),
#  ('당함', 4),
#  ('CASE', 4),
#  ('선릉', 4),
#  ('개입', 4),
#  ('일관', 4),
#  ('61', 4),
#  ('사나', 4),
#  ('샌티', 4),
#  ('편승', 4),
#  ('스러울', 4),
#  ('일과', 4),
#  ('유신', 4),
#  ('항만', 4),
#  ('화이팅', 4),
#  ('다분', 4),
#  ('완성도', 4),
#  ('낙후', 4),
#  ('퇴장', 4),
#  ('작업량', 4),
#  ('삼교대', 4),
#  ('jw', 4),
#  ('실은', 4),
#  ('장거리', 4),
#  ('동의', 4),
#  ('외산', 4),
#  ('채워', 4),
#  ('주미', 4),
#  ('소매', 4),
#  ('벌기', 4),
#  ('선호도', 4),
#  ('입김', 4),
#  ('노인', 4),
#  ('선발', 4),
#  ('KPI', 4),
#  ('모였', 4),
#  ('신한', 4),
#  ('미지수', 4),
#  ('거친', 4),
#  ('커질', 4),
#  ('유화', 4),
#  ('졌으며', 4),
#  ('학문', 4),
#  ('양성', 4),
#  ('간다고', 4),
#  ('이어폰', 4),
#  ('리플레', 4),
#  ('업장', 4),
#  ('알라딘', 4),
#  ('법대', 4),
#  ('카카오톡', 4),
#  ('경청', 4),
#  ('소액', 4),
#  ('정통', 4),
#  ('소탈', 4),
#  ('허물없이', 4),
#  ('IC', 4),
#  ('놀람', 4),
#  ('CP', 4),
#  ('분양', 4),
#  ('공덕', 4),
#  ('어려웠', 4),
#  ('사라졌', 4),
#  ('쓸려고', 4),
#  ('콘서트', 4),
#  ('질서', 4),
#  ('서핑', 4),
#  ('내려', 4),
#  ('대장', 4),
#  ('인편', 4),
#  ('설렁설렁', 4),
#  ('브라질', 4),
#  ('무늬', 4),
#  ('터짐', 4),
#  ('오케이', 4),
#  ('지방대', 4),
#  ('겸비', 4),
#  ('Job', 4),
#  ('무한대', 4),
#  ('컵라면', 4),
#  ('할애', 4),
#  ('만져', 4),
#  ('어설픈', 4),
#  ('튼실', 4),
#  ('웨이', 4),
#  ('일요일', 4),
#  ('회복', 4),
#  ('잡음', 4),
#  ('강해짐', 4),
#  ('고퀄', 4),
#  ('쌓임', 4),
#  ('오티', 4),
#  ('발효', 4),
#  ('진단', 4),
#  ('크루', 4),
#  ('취항', 4),
#  ('큼직', 4),
#  ('방위', 4),
#  ('외벌', 4),
#  ('포토', 4),
#  ('폴리오', 4),
#  ('휴양', 4),
#  ('온다고', 4),
#  ('알찬', 4),
#  ('비슷비슷', 4),
#  ('꿈꿀', 4),
#  ('일반인', 4),
#  ('지킵니다', 4),
#  ('꽁짜', 4),
#  ('다지기', 4),
#  ('통함', 4),
#  ('숙지', 4),
#  ('희망자', 4),
#  ('바빠도', 4),
#  ('행보', 4),
#  ('개봉', 4),
#  ('못해도', 4),
#  ('나온다고', 4),
#  ('자판기', 4),
#  ('달려', 4),
#  ('먼지', 4),
#  ('케이티', 4),
#  ('꿀맛', 4),
#  ('괜찬은', 4),
#  ('쓴다고', 4),
#  ('분만', 4),
#  ('립니', 4),
#  ('아마도', 4),
#  ('고도', 4),
#  ('바나나', 4),
#  ('일머리', 4),
#  ('주재', 4),
#  ('완화', 4),
#  ('승무', 4),
#  ('항공기', 4),
#  ('아동', 4),
#  ('교구', 4),
#  ('야경', 4),
#  ('조음', 4),
#  ('매트릭스', 4),
#  ('ifc', 4),
#  ('내맘대로', 4),
#  ('소신껏', 4),
#  ('well', 4),
#  ('품격', 4),
#  ('콜라보', 4),
#  ('Practice', 4),
#  ('사물함', 4),
#  ('제기', 4),
#  ('이어져', 4),
#  ('선진국', 4),
#  ('랭크', 4),
#  ('성숙', 4),
#  ('office', 4),
#  ('on', 4),
#  ('role', 4),
#  ('have', 4),
#  ('things', 4),
#  ('your', 4),
#  ('돋보입니다', 4),
#  ('움직여서', 4),
#  ('코치', 4),
#  ('물질', 4),
#  ('어느새', 4),
#  ('로워요', 4),
#  ('어려서', 4),
#  ('식견', 4),
#  ('후드', 4),
#  ('간담회', 4),
#  ('주된', 4),
#  ('직함', 4),
#  ('나아가', 4),
#  ('선박', 4),
#  ('친화력', 4),
#  ('끼워', 4),
#  ('쟁이', 4),
#  ('굵직굵직', 4),
#  ('구직자', 4),
#  ('괴리', 4),
#  ('갈려고', 4),
#  ('고장', 4),
#  ('심할', 4),
#  ('라지만', 4),
#  ('변수', 4),
#  ('파생', 4),
#  ('압력', 4),
#  ('무한리필', 4),
#  ('사안', 4),
#  ('꺼져서', 4),
#  ('원시', 4),
#  ('럴함', 4),
#  ('구리', 4),
#  ('챙겨서', 4),
#  ('실시간', 4),
#  ('판매량', 4),
#  ('바리스타', 4),
#  ('스터', 4),
#  ('트래픽', 4),
#  ('트레인', 4),
#  ('대졸자', 4),
#  ('징수', 4),
#  ('심해서', 4),
#  ('차종', 4),
#  ('용어', 4),
#  ('장난아', 4),
#  ('빌릴', 4),
#  ('꼽힐', 4),
#  ('터미널', 4),
#  ('펄프', 4),
#  ('4200', 4),
#  ('SDS', 4),
#  ('구두', 4),
#  ('내규', 4),
#  ('노래방', 4),
#  ('카로', 4),
#  ('정류장', 4),
#  ('생기', 4),
#  ('브랜드력', 4),
#  ('랜덤', 4),
#  ('하기휴가', 4),
#  ('안동', 4),
#  ('외수', 4),
#  ('benefit', 4),
#  ('올바른', 4),
#  ('선함', 4),
#  ('놓칠', 4),
#  ('달랐', 4),
#  ('보탬', 4),
#  ('종업원', 4),
#  ('신념', 4),
#  ('55', 4),
#  ('테헤란로', 4),
#  ('산학', 4),
#  ('역삼동', 4),
#  ('선릉역', 4),
#  ('케임', 4),
#  ('잔류', 4),
#  ('교원', 4),
#  ('온도', 4),
#  ("'~", 4),
#  ('막대', 4),
#  ('저명', 4),
#  ('사립', 4),
#  ('공조', 4),
#  ('싸이코', 4),
#  ('지배', 4),
#  ('유업', 4),
#  ('애착', 4),
#  ('배제', 4),
#  ('장려금', 4),
#  ('직결', 4),
#  ('배당금', 4),
#  ('노동절', 4),
#  ('네이트', 4),
#  ('소기업', 4),
#  ('싸이월드', 4),
#  ('아닌데', 4),
#  ('장사', 4),
#  ('결속', 4),
#  ('연대', 4),
#  ('자타', 4),
#  ('일부러', 4),
#  ('틀림', 4),
#  ('자아실현', 4),
#  ('그래서인지', 4),
#  ('견해', 4),
#  ('함꼐', 4),
#  ('상향', 4),
#  ('북미', 4),
#  ('구색', 4),
#  ('부지런', 4),
#  ('일례', 4),
#  ('난방', 4),
#  ('프로그래머', 4),
#  ('외지', 4),
#  ('아침잠', 4),
#  ('후원', 4),
#  ('나간다는', 4),
#  ('숙련', 4),
#  ('받쳐', 4),
#  ('나간다', 4),
#  ('늘릴', 4),
#  ('firm', 4),
#  ('솔직', 4),
#  ('시책', 4),
#  ('아빠', 4),
#  ('짜여', 4),
#  ('21', 4),
#  ('뺑뺑이', 4),
#  ('방지법', 4),
#  ('체득', 4),
#  ('기직', 4),
#  ('였음에도', 4),
#  ('올라서', 4),
#  ('119', 4),
#  ('모자', 4),
#  ('중석', 4),
#  ('보존', 4),
#  ('발기회', 4),
#  ('항공료', 4),
#  ('수신', 4),
#  ('서무', 4),
#  ('공직', 4),
#  ('선사', 4),
#  ('현명', 4),
#  ('나무', 4),
#  ('전념', 4),
#  ('코리아', 4),
#  ('축구장', 4),
#  ('종각역', 4),
#  ('밥집', 4),
#  ('time', 4),
#  ('59', 4),
#  ('뒷담화', 4),
#  ('지켜져서', 4),
#  ('즈음', 4),
#  ('개정', 4),
#  ('내점', 4),
#  ('담보', 4),
#  ('~~~~~', 4),
#  ('이럴', 4),
#  ('맡겨', 4),
#  ('Pc', 4),
#  ('기피', 4),
#  ('제각각', 4),
#  ('지켜서', 4),
#  ('사연', 4),
#  ('가히', 4),
#  ('자차', 4),
#  ('스페셜', 4),
#  ('직간', 4),
#  ('폐쇄', 4),
#  ('어림', 4),
#  ('스카이', 4),
#  ('가벼운', 4),
#  ('가계', 4),
#  ('발전시설', 4),
#  ('감당', 4),
#  ('괜춘', 4),
#  ('시공사', 4),
#  ('전보', 4),
#  ('중대', 4),
#  ('자정', 4),
#  ('모아서', 4),
#  ('끊임', 4),
#  ('벗어날', 4),
#  ('건보', 4),
#  ('견줄', 4),
#  ('63', 4),
#  ('회사기', 4),
#  ('단순히', 4),
#  ('명예퇴직', 4),
#  ('가끔가다', 4),
#  ('수면', 4),
#  ('체불', 4),
#  ('심했', 4),
#  ('꾸려', 4),
#  ('안식년', 4),
#  ('노려볼', 4),
#  ('network', 4),
#  ('거리낌', 4),
#  ('베드', 4),
#  ('평준', 4),
#  ('경쟁의식', 4),
#  ('일일이', 4),
#  ('맞이', 4),
#  ('경평', 4),
#  ('훈훈', 4),
#  ('인턴사원', 4),
#  ('신고', 4),
#  ('바름', 4),
#  ('집합', 4),
#  ('자면', 4),
#  ('변해', 4),
#  ('마셔도', 4),
#  ('보상비', 4),
#  ('의왕역', 4),
#  ('양재', 4),
#  ('냉매', 4),
#  ('금등', 4),
#  ('일산', 4),
#  ('빈도수', 4),
#  ('추상', 4),
#  ('아메리카노', 4),
#  ('프로덕트', 4),
#  ('임사', 4),
#  ('커뮤니티', 4),
#  ('이메일', 4),
#  ('종교', 4),
#  ('넘어감', 4),
#  ('이뤄진', 4),
#  ('핸들링', 4),
#  ('플레이스', 4),
#  ('품성', 4),
#  ('경조', 4),
#  ('일거', 4),
#  ('주기도', 4),
#  ('침해', 4),
#  ('인등', 4),
#  ('가감', 4),
#  ('학구', 4),
#  ('버팀', 4),
#  ('대용량', 4),
#  ('접시', 4),
#  ('명동', 4),
#  ('NGO', 4),
#  ('차림', 4),
#  ('별정직', 4),
#  ('육박', 4),
#  ('사비', 4),
#  ('그램', 4),
#  ('재공', 4),
#  ('그분', 4),
#  ('왕복', 4),
#  ('It', 4),
#  ('수영장', 4),
#  ('수영', 4),
#  ('에버', 4),
#  ('오브', 4),
#  ('다녀옴', 4),
#  ('불법', 4),
#  ('움직여야', 4),
#  ('연기금', 4),
#  ('한꺼번에', 4),
#  ('발견', 4),
#  ('사립대', 4),
#  ('청춘', 4),
#  ('어트랙션', 4),
#  ('기숙', 4),
#  ...]

# %%
c_5_ls=[]

for z in range(len(c_5)):
    c_5_ls.append(c_5[z][0])
#5개 이하 리스트로만들기

# %%
ls_total=[]

s = set(c_5_ls)
for i in tqdm_notebook(range(len(total_word))):
    ls = [x for x in total_word[i] if x not in s]
    ls_total.append(ls)
    
# 5개 이하 빼기
# Out:
# HBox(children=(IntProgress(value=0, max=38091), HTML(value='')))

# %% [markdown]
# # 문서 최대 길이 구하기

# %%
from eunjeon import Mecab
from collections import Counter

# %%
max_len =[]
for i in range(len(total_word)):
    max_len.append(len(total_word[i]))

max(max_len)
# Out:
# 169

# %%
count_len = Counter(max_len).most_common()
cnt_sort = count_len.sort(reverse=True)
count_len
# Out:
# [(169, 1),
#  (166, 1),
#  (164, 3),
#  (161, 1),
#  (155, 1),
#  (140, 2),
#  (129, 2),
#  (127, 1),
#  (126, 1),
#  (122, 1),
#  (117, 2),
#  (116, 1),
#  (114, 2),
#  (111, 1),
#  (108, 13),
#  (106, 2),
#  (105, 3),
#  (102, 1),
#  (101, 2),
#  (98, 3),
#  (97, 2),
#  (96, 1),
#  (95, 2),
#  (92, 1),
#  (91, 1),
#  (89, 2),
#  (87, 2),
#  (85, 4),
#  (84, 3),
#  (83, 4),
#  (82, 2),
#  (81, 1),
#  (80, 2),
#  (79, 2),
#  (78, 1),
#  (77, 1),
#  (76, 6),
#  (74, 4),
#  (73, 3),
#  (72, 2),
#  (71, 4),
#  (70, 3),
#  (69, 4),
#  (68, 1),
#  (67, 3),
#  (66, 3),
#  (65, 8),
#  (64, 4),
#  (63, 8),
#  (62, 4),
#  (61, 4),
#  (60, 9),
#  (59, 5),
#  (58, 2),
#  (57, 6),
#  (56, 8),
#  (55, 9),
#  (54, 12),
#  (53, 7),
#  (52, 8),
#  (51, 6),
#  (50, 8),
#  (49, 16),
#  (48, 16),
#  (47, 17),
#  (46, 24),
#  (45, 18),
#  (44, 20),
#  (43, 18),
#  (42, 18),
#  (41, 39),
#  (40, 23),
#  (39, 34),
#  (38, 29),
#  (37, 63),
#  (36, 38),
#  (35, 62),
#  (34, 50),
#  (33, 62),
#  (32, 81),
#  (31, 86),
#  (30, 98),
#  (29, 107),
#  (28, 121),
#  (27, 153),
#  (26, 193),
#  (25, 203),
#  (24, 220),
#  (23, 248),
#  (22, 331),
#  (21, 375),
#  (20, 474),
#  (19, 552),
#  (18, 711),
#  (17, 814),
#  (16, 972),
#  (15, 1213),
#  (14, 1387),
#  (13, 1754),
#  (12, 2097),
#  (11, 2535),
#  (10, 3088),
#  (9, 3715),
#  (8, 3973),
#  (7, 3970),
#  (6, 3447),
#  (5, 2436),
#  (4, 1242),
#  (3, 511),
#  (2, 162),
#  (1, 54),
#  (0, 5)]

# %% [markdown]
# ### 문서 길이 데이터 시각화 및 정규분포화, 기업리뷰가 특정개수 이하는 제거

# %%
# ㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇㅇ

# %% [markdown]
# # 불용어, 불용품사, 1글자 토큰 제거 후 토큰이 없는 리뷰 제거

# %%
for i in range(len(total_word)-1, -1 , -1):
    if len(total_word[i]) == 0:
        del total_word[i]

# %%
len(total_word)
# Out:
# 38086

# %% [markdown]
# # Train, Test 나누기

# %%
x_train = total_word[:30400]
x_test = total_word[30400:]
y_train = total_data['label'][:30400].values.tolist()
y_test = total_data['label'][30400:].values.tolist()

# %% [markdown]
# # Padding

# %%
# Sequence Length를 맞추기 위한 padding
def add_padding(token_ls, max_len):
    pad = '<PAD>'
    seq_length_ls = []
    
    for i, tokens in enumerate(token_ls):
        seq_length = len(tokens)
        
        # 짧으면 padding을 추가
        if seq_length < max_len:
            seq_length_ls.append(seq_length)
            token_ls[i] += [pad] * (max_len - seq_length)
        
        # 길이가 길면, max_len까지의 token만 사용
        elif seq_length >= max_len:
            seq_length_ls.append(max_len)
            token_ls[i] = tokens[:max_len]
            
    return token_ls, seq_length_ls

# %%
max_sequence_length = 50
x_train, x_train_seq_length = add_padding(x_train, max_sequence_length)
x_test, x_test_seq_length = add_padding(x_test, max_sequence_length)

# %% [markdown]
# # Converting token to index

# %%
# 단어에 대한 idx 부여
def convert_token_to_idx(token_ls):
    for tokens in token_ls:
        yield [token2idx[token] for token in tokens]
    return

# %%
token2idx = defaultdict(lambda: len(token2idx))
pad = token2idx['<PAD>']

x_train = list(convert_token_to_idx(x_train))
x_test = list(convert_token_to_idx(x_test))

idx2token = {val : key for key,val in token2idx.items()}

# %%
' '.join([idx2token[x] for x in x_train[30]])
# Out:
# '회사 재무 구조 걱정 없이 오래 회사 직원 누릴 복지 업계 상위 연봉 중상 커리어 시작 사회 초년병 추천 회사 <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'

# %% [markdown]
# ### Packing을 위해, 긴 문장이 위로 오도록 순서를 sorting and Variable로 변환

# %%
def sort_by_sequence_length(x, y, seq_len):
    sorted_idx = np.argsort(np.array(seq_len))[::-1]
    
    x = Variable(torch.LongTensor(np.array(x)[sorted_idx]))
    y = Variable(torch.LongTensor(np.array(y)[sorted_idx]))
    seq_len = Variable(torch.LongTensor(np.array(seq_len)[sorted_idx]))
    
    return x, y, seq_len

# %%
x_train, y_train, x_train_seq_length = sort_by_sequence_length(x_train, y_train, x_train_seq_length)
x_test, y_test, x_test_seq_length = sort_by_sequence_length(x_test, y_test, x_test_seq_length)

# %% [markdown]
# # Pretrain 된 word2vec 모델 벡터 값 불러오기

# %%
# import gensim

# wv_model = gensim.models.KeyedVectors.load('Word2vec_model')
# weights = torch.FloatTensor(wv_model.wv.vectors)

# %%
# embedding = nn.Embedding.from_pretrained(weights)
# # Get embeddings for index 1
# input = torch.LongTensor([1])
# embedding(input)

# %% [markdown]
# # LSTM

# %%
class LSTM(nn.Module):
    def __init__(self, token2idx, max_sequence, vocab_size, embed_size, hid_size, n_layers, dropout, bidirectional, n_category):
        super(LSTM, self).__init__() 
        self.vocab_size = vocab_size                # 고유한 단어의 수
        self.embed_size = embed_size                # 임베딩 차원의 크기
        self.padding_index = token2idx['<PAD>']     # 패딩 토큰
        
        self.embed = nn.Embedding(
            num_embeddings=vocab_size, 
            embedding_dim=embed_size, 
            padding_idx=self.padding_index
        )
        
        self.max_sequence = max_sequence           # 한 문장의 최대 길이
        self.hid_size = hid_size                   # LSTM 뉴런의 갯수
        self.n_layers = n_layers                   # LSTM layer의 수
        self.drouput = dropout                     # 드롭아웃
        self.n_category = n_category               # 분류 카테고리 갯수
        self.bidirectional = bidirectional         # optinal, True : bidirectional 
        
        self.lstm = nn.LSTM(embed_size, hid_size, n_layers, batch_first=True, bidirectional=True)
        
        if bidirectional:
            input_dim = 2*hid_size*max_sequence
        else:
            input_dim = hid_size*max_sequence

        self.lin = nn.Linear(input_dim, n_category)
        self.outputs = []
        
    def init_hidden(self, batch_size):
        # 최초에 h_0와 c_0의 초기값 부여 (n_layers, batch_size, hid_size(n_neuron))
        # bidirectional일 경우, (2*n_layers, batch_size, hid_size)
        if self.bidirectional:
            h_0 = Variable(torch.randn(2*self.n_layers, batch_size, self.hid_size)) * 0.1
            c_0 = Variable(torch.randn(2*self.n_layers, batch_size, self.hid_size)) * 0.1
        else:
            h_0 = Variable(torch.randn(self.n_layers, batch_size, self.hid_size)) * 0.1
            c_0 = Variable(torch.randn(self.n_layers, batch_size, self.hid_size)) * 0.1
        return (h_0, c_0)    
    
    def forward(self, x, x_sequence_length):
        # init h randomly
        batch_size = x.size(0)
        self.h_c = self.init_hidden(batch_size)
        
        # embedding
        x = self.embed(x) # sequence_length(max_len), batch_size, embed_size
        
        # packing for LSTM
        x = torch.nn.utils.rnn.pack_padded_sequence(x, x_sequence_length, batch_first=True)
        
        # LSTM
        output, self.h_c = self.lstm(x, self.h_c)
        
        # unpack
        # unpacking 과정에서, size(1) S가 가장 긴 sequence 길이를 갖는 data에 맞춰진다.
        # S가 max_sequence_length로 고정되는 것이 아님을 주의
        x, _ = torch.nn.utils.rnn.pad_packed_sequence(output, batch_first=True)
        #print(x.shape)
        
        # flatten
        x = x.contiguous()
        x = x.view(batch_size, -1)
        
        # fully-connect
        logit = self.lin(x)
        
        return logit

# %%
params = {
    'token2idx' : token2idx,
    'max_sequence' : 50,
    'vocab_size' : len(token2idx),
    'embed_size' : 30,
    'hid_size' : 32,
    'n_layers' : 2,
    'dropout' : 0.5,
    'bidirectional' : True,
    'n_category' : 5
}

# %%
model = LSTM(**params)

# %%
model
# Out:
# LSTM(
#   (embed): Embedding(13974, 30, padding_idx=0)
#   (lstm): LSTM(30, 32, num_layers=2, batch_first=True, bidirectional=True)
#   (lin): Linear(in_features=3200, out_features=5, bias=True)
# )

# %% [markdown]
# # Train

# %%
def adjust_learning_rate(optimizer, epoch, init_lr=0.001, lr_decay_epoch=10):
    """Decay learning rate by a factor of 0.1 every lr_decay_epoch epochs."""
    lr = init_lr * (0.1**(epoch // lr_decay_epoch))

    if epoch % lr_decay_epoch == 0:
        print('LR is set to %s'%(lr))

    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

    return optimizer

# %%
epochs = 20
lr = 0.01
batch_size = 10000

train_idx = np.arange(x_train.size(0))
test_idx = np.arange(x_test.size(0))
optimizer = torch.optim.Adam(model.parameters(),lr)
criterion = nn.CrossEntropyLoss(reduction='sum')

loss_ls = []

for epoch in range(1, epochs+1):
    model.train()
    
    # input 데이터 순서 섞기
    random.shuffle(train_idx)
    x_train, y_train = x_train[train_idx], y_train[train_idx]
    x_train_seq_length = x_train_seq_length[train_idx]
    
    train_loss = 0
    
    for start_idx, end_idx in zip(range(0, x_train.size(0), batch_size),
                                  range(batch_size, x_train.size(0)+1, batch_size)):
        # batch 뽑기
        x_batch = x_train[start_idx : end_idx]
        y_batch = y_train[start_idx : end_idx].long()
        x_batch_seq_length = x_train_seq_length[start_idx: end_idx]
        
        # sequence 순서대로 정렬하기
        x_batch, y_batch, x_batch_seq_length = sort_by_sequence_length(x_batch, y_batch, x_batch_seq_length)
        
        scores = model(x_batch, x_batch_seq_length)
        predict = F.softmax(scores, dim=1).argmax(dim = 1)
        
        acc = (predict == y_batch).sum().item() / batch_size
        
        loss = criterion(scores, y_batch)
        train_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print('Train epoch : %s,  loss : %s,  accuracy :%.3f'%(epoch, train_loss / batch_size, acc))
    print('=================================================================================================')
    
    loss_ls.append(train_loss)
    optimizer = adjust_learning_rate(optimizer, epoch, lr, 100) # adjust learning_rate while training
    
    if (epoch) % 5 == 0:
        model.eval()
        scores = model(x_test, x_test_seq_length)
        predict = F.softmax(scores, dim=1).argmax(dim = 1)
        
        acc = (predict == y_test.long()).sum().item() / y_test.size(0)
        loss = criterion(scores, y_test.long())
        
        print('*************************************************************************************************')
        print('*************************************************************************************************')
        print('Test Epoch : %s, Test Loss : %.03f , Test Accuracy : %.03f'%(epoch, loss.item()/y_test.size(0), acc))
        print('*************************************************************************************************')
        print('*************************************************************************************************')
# Out:
# Train epoch : 1,  loss : 4.76512744140625,  accuracy :0.294
# =================================================================================================
# Train epoch : 2,  loss : 4.51932783203125,  accuracy :0.380
# =================================================================================================
# Train epoch : 3,  loss : 4.20841650390625,  accuracy :0.429
# =================================================================================================
# Train epoch : 4,  loss : 3.93385419921875,  accuracy :0.477
# =================================================================================================
# Train epoch : 5,  loss : 3.69765224609375,  accuracy :0.514
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Test Epoch : 5, Test Loss : 1.278 , Test Accuracy : 0.476
# *************************************************************************************************
# *************************************************************************************************
# Train epoch : 6,  loss : 3.467755859375,  accuracy :0.543
# =================================================================================================
# Train epoch : 7,  loss : 3.2453755859375,  accuracy :0.582
# =================================================================================================
# Train epoch : 8,  loss : 3.03221015625,  accuracy :0.609
# =================================================================================================
# Train epoch : 9,  loss : 2.83741484375,  accuracy :0.638
# =================================================================================================
# Train epoch : 10,  loss : 2.665146875,  accuracy :0.669
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Test Epoch : 10, Test Loss : 1.182 , Test Accuracy : 0.562
# *************************************************************************************************
# *************************************************************************************************
# Train epoch : 11,  loss : 2.504333740234375,  accuracy :0.694
# =================================================================================================
# Train epoch : 12,  loss : 2.3517787109375,  accuracy :0.702
# =================================================================================================
# Train epoch : 13,  loss : 2.21214931640625,  accuracy :0.722
# =================================================================================================
# Train epoch : 14,  loss : 2.08870498046875,  accuracy :0.742
# =================================================================================================
# Train epoch : 15,  loss : 1.979692431640625,  accuracy :0.764
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Test Epoch : 15, Test Loss : 1.245 , Test Accuracy : 0.568
# *************************************************************************************************
# *************************************************************************************************
# Train epoch : 16,  loss : 1.859832958984375,  accuracy :0.771
# =================================================================================================
# Train epoch : 17,  loss : 1.760348583984375,  accuracy :0.781
# =================================================================================================
# Train epoch : 18,  loss : 1.661493212890625,  accuracy :0.797
# =================================================================================================
# Train epoch : 19,  loss : 1.56320546875,  accuracy :0.807
# =================================================================================================
# Train epoch : 20,  loss : 1.466440625,  accuracy :0.824
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Test Epoch : 20, Test Loss : 1.417 , Test Accuracy : 0.581
# *************************************************************************************************
# *************************************************************************************************
