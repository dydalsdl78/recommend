# %%
from collections import defaultdict
from collections import Counter

import torch.nn as nn
import torch
from torch.autograd import Variable
import torch.nn.functional as F

import random
import pandas as pd
import numpy as np

from eunjeon import Mecab
from tqdm import tqdm_notebook

# %% [markdown]
# # 데이터 불러오기

# %%
data = pd.read_csv(r"..\data\test_file.csv")
data
# Out:
#        링크 순서       기업   평점     산업분류 직원의 기업 추천율 직원이 전망하는 성장 가능성 이 기업의 CEO 지지율  \
# 0          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 1          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 2          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 3          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 4          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# ...      ...      ...  ...      ...        ...             ...           ...
# 98348     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98349     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98350     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98351     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98352     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
#
#        승진 기회 및 가능성  복지 및 급여  업무와 삶의 균형  ...  경영진  \
# 0              2.8      3.2        2.9  ...  2.2
# 1              2.8      3.2        2.9  ...  2.2
# 2              2.8      3.2        2.9  ...  2.2
# 3              2.8      3.2        2.9  ...  2.2
# 4              2.8      3.2        2.9  ...  2.2
# ...            ...      ...        ...  ...  ...
# 98348          3.0      3.5        2.7  ...  2.7
# 98349          3.0      3.5        2.7  ...  2.7
# 98350          3.0      3.5        2.7  ...  2.7
# 98351          3.0      3.5        2.7  ...  2.7
# 98352          3.0      3.5        2.7  ...  2.7
#
#                                                       제목  \
# 0                       "관리만 하려하는 상위직급이 다수 사원 대리 과장은 적음"
# 1                   "변화가 없다. 근 10년동안 비슷한 프로젝트만 유지하고 있다."
# 2              "탄탄했던 회사 같음! 나쁘지 않아요! 복지좋고 편하게 다닐 수 있어요!"
# 3      "개발자와 기획자간의 괴리감이 크고 팀장과 팀원들과의 관계도 적대적인 분위기다. 줄...
# 4              "외국계 회사지만 실상은 국내 중소기업 분위기임. 합병이후 가치가 하락중"
# ...                                                  ...
# 98348           "업계 중 연봉은 타은행대비 보통이나 잘하면 승진및 교육기회가 있는 곳"
# 98349         "가장효율적인 조직이며 위기에 강한은행 끝까지 마지막까지 살아남을 은행이다"
# 98350         "합병으로 인해 성장성이 돋보이는 회사임. 앞으로 두 회사의 시너지가 기대"
# 98351            "적당한 수준의 연봉과 적당한 수준의 개인생활을 유지하고 싶다면 추천"
# 98352                       "매일 몰려오는 손님들을 상대할 수 있는멘탈 필요"
#
#                                                       장점  \
# 0         10년차 정도면 it 중견기업 2~3년차 연봉에 맞먹음\n지원부서 대우가 높을수있음
# 1              자유로운 분위기, 타 IT 회사에 비해 경직되지 않고 근무를 할 수 있다.
# 2      사람들이랑 사이가 좋아서 즐겁게 다녔음 / 비품을 많이 사용할 수 있어서 좋았음\n...
# 3      해마다 복지카드가 나오고 원하는대로 쓸 수 있다. 연차나 휴가, 칼퇴에 대해 눈치보...
# 4                      사무용품 업계 1위업체. 워라벨은 보장 됨.연차사용 제약없음
# ...                                                  ...
# 98348                  역동적인 문화로 마케팅 ㅡ좋아하면 추천입니다 연봉은 보통수준
# 98349   외환은행 통합으로 글로벌과 자산관리에 강점이 있음\n철저한 비용관리로 리스크관리가 우수
# 98350  안정적인 급여와 은행원이라는 것에 대한 자부심을 느낄 수 있음 여자행원들에 대한 복...
# 98351  개인 휴가가 보장되어 있고 타 은행에 비해 비교적 퇴근이 빠름. 분위기도 뭔가 혁신...
# 98352  복지하나는 하나은행이 짱, 주말이 보장되고 현금성 복지가 있음, 전세자금 대출도 장...
#
#                                                       단점  \
# 0                   경직된 상하관계\n명령하달식 커뮤니케이션\n대우개선에대한 희망고문
# 1            성장세가 없다. 기존의 사업만 고수하고 신규사업에 대해 투자가 소홀한 편이다.
# 2      집에서 출퇴근길이 멀어서 힘들었음/ 딱히 단점이 없었던 회사\n2년 열심히 다니고 ...
# 3      단, 일이 많다. 팀마다 분위기가 상이하고 줄을 잘 서야한다. 야근이 강요되지 않지...
# 4                   연봉이 현저히 작음. 합병이후 시스템 이나 프로세스 통합이 미비함
# ...                                                  ...
# 98348                     빡센문화 야근을 밥먹듯이하는사람많음 승진과열경쟁 부추김
# 98349                  다양한 은행이 모인만큼 문화가 다르지만 성과로 평가하는 은행
# 98350        과도한 업무와 합병에 따른 전산처리가 아직 미비한점 인사제도에 대한 개선 필요
# 98351  늘 그 자리에 머무는 연봉과 출신의 한계로 인한 넘사벽이 존재. 그리고 일단 비전없...
# 98352  진상고객들 처리가 최대의 단점. 고객들의 민원을 이겨낼 수 있는 멘탈관리와 성실함이...
#
#                                              경영진에게 바라는 점 각 리뷰 평점         직무  \
# 0                      낙하산 및 고인물의 교체 필요\n실무자에 대한 대우개선 필요       1     IT/인터넷
# 1                               기존 사업보다는 신규사업에 투자해야 할 시기       3     IT/인터넷
# 2               경영진에게 크게 바라는점은 없음 !! 그렇게 심한 터치가 없어서 편했나봄       2     IT/인터넷
# 3                 신규 사업에 대한 투자는 좋지만 사람도 돌보는 회사가 됐으면 좋겠다.       3     IT/인터넷
# 4           직원들에 대한 복지나 연봉을 개선하여 동기부여가 될 수 있게 해줬으면 하는 바람       2  경영/기획/컨설팅
# ...                                                  ...     ...        ...
# 98348            야근을최소화하고 경쟁과 영업압박을 너무 주지않아야 임직원들이 버팀...       4      금융/재무
# 98349  단기실적 보단 지속가능 경영의 실현이 필요할때\n통합에 관한 제도 등의 결정은 빠르...       2      금융/재무
# 98350            합병 시너지를 행원들까지 누릴 수 있게 인사제도 개선이 필요해 보입니다       3      금융/재무
# 98351                               개인과 기업을 구분하지 말고 대우하길       2      금융/재무
# 98352  영업압박에 대한 부담감이 낮았으면 좋겠고, 은행원들의 고충을 좀 더 면밀하게 살펴서...       3      금융/재무
#
#       재직상태  지역 리뷰 좋아요 개수
# 0      전직원  경기         0
# 1      현직원  경기         0
# 2      전직원  경기         0
# 3      전직원  서울         0
# 4      전직원  서울         0
# ...    ...  ..       ...
# 98348  전직원  서울         0
# 98349  현직원  서울         0
# 98350  현직원  서울         0
# 98351  전직원  서울         0
# 98352  현직원  서울         1
#
# [98353 rows x 21 columns]

# %%
# 데이터 순서 섞기
# data=data.sample(frac=1)
# data=data.reset_index(drop=True)

# %%
label = pd.read_csv(r"..\data\label.csv", names=['기업','label'] )
label['label'] = label['label'].astype(int) 
label
# Out:
#                    기업  label
# 1             조이시티(주)      2
# 2             중소기업연구원      0
# 4               쿠팡(주)      2
# 6              퍼스텍(주)      1
# 7            평화홀딩스(주)      1
# ...               ...    ...
# 1195         (주)디트라이브      2
# 1197          (주)스마트로      0
# 1200  미쓰비시다나베파마코리아(주)      1
# 1201       법무법인(유)태평양      0
# 1203           삼정회계법인      2
#
# [562 rows x 2 columns]

# %% [markdown]
# # 기업의 리뷰마다 labeling 해주기

# %%
total_data = pd.merge(data, label , on="기업", how='left')
total_data
# Out:
#        링크 순서       기업   평점     산업분류 직원의 기업 추천율 직원이 전망하는 성장 가능성 이 기업의 CEO 지지율  \
# 0          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 1          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 2          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 3          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# 4          0   유엔젤(주)  3.0  IT/웹/통신        35%              5%           53%
# ...      ...      ...  ...      ...        ...             ...           ...
# 98348     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98349     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98350     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98351     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
# 98352     65  하나은행(주)  3.1   은행/금융업        43%             37%           44%
#
#        승진 기회 및 가능성  복지 및 급여  업무와 삶의 균형  ...  \
# 0              2.8      3.2        2.9  ...
# 1              2.8      3.2        2.9  ...
# 2              2.8      3.2        2.9  ...
# 3              2.8      3.2        2.9  ...
# 4              2.8      3.2        2.9  ...
# ...            ...      ...        ...  ...
# 98348          3.0      3.5        2.7  ...
# 98349          3.0      3.5        2.7  ...
# 98350          3.0      3.5        2.7  ...
# 98351          3.0      3.5        2.7  ...
# 98352          3.0      3.5        2.7  ...
#
#                                                       제목  \
# 0                       "관리만 하려하는 상위직급이 다수 사원 대리 과장은 적음"
# 1                   "변화가 없다. 근 10년동안 비슷한 프로젝트만 유지하고 있다."
# 2              "탄탄했던 회사 같음! 나쁘지 않아요! 복지좋고 편하게 다닐 수 있어요!"
# 3      "개발자와 기획자간의 괴리감이 크고 팀장과 팀원들과의 관계도 적대적인 분위기다. 줄...
# 4              "외국계 회사지만 실상은 국내 중소기업 분위기임. 합병이후 가치가 하락중"
# ...                                                  ...
# 98348           "업계 중 연봉은 타은행대비 보통이나 잘하면 승진및 교육기회가 있는 곳"
# 98349         "가장효율적인 조직이며 위기에 강한은행 끝까지 마지막까지 살아남을 은행이다"
# 98350         "합병으로 인해 성장성이 돋보이는 회사임. 앞으로 두 회사의 시너지가 기대"
# 98351            "적당한 수준의 연봉과 적당한 수준의 개인생활을 유지하고 싶다면 추천"
# 98352                       "매일 몰려오는 손님들을 상대할 수 있는멘탈 필요"
#
#                                                       장점  \
# 0         10년차 정도면 it 중견기업 2~3년차 연봉에 맞먹음\n지원부서 대우가 높을수있음
# 1              자유로운 분위기, 타 IT 회사에 비해 경직되지 않고 근무를 할 수 있다.
# 2      사람들이랑 사이가 좋아서 즐겁게 다녔음 / 비품을 많이 사용할 수 있어서 좋았음\n...
# 3      해마다 복지카드가 나오고 원하는대로 쓸 수 있다. 연차나 휴가, 칼퇴에 대해 눈치보...
# 4                      사무용품 업계 1위업체. 워라벨은 보장 됨.연차사용 제약없음
# ...                                                  ...
# 98348                  역동적인 문화로 마케팅 ㅡ좋아하면 추천입니다 연봉은 보통수준
# 98349   외환은행 통합으로 글로벌과 자산관리에 강점이 있음\n철저한 비용관리로 리스크관리가 우수
# 98350  안정적인 급여와 은행원이라는 것에 대한 자부심을 느낄 수 있음 여자행원들에 대한 복...
# 98351  개인 휴가가 보장되어 있고 타 은행에 비해 비교적 퇴근이 빠름. 분위기도 뭔가 혁신...
# 98352  복지하나는 하나은행이 짱, 주말이 보장되고 현금성 복지가 있음, 전세자금 대출도 장...
#
#                                                       단점  \
# 0                   경직된 상하관계\n명령하달식 커뮤니케이션\n대우개선에대한 희망고문
# 1            성장세가 없다. 기존의 사업만 고수하고 신규사업에 대해 투자가 소홀한 편이다.
# 2      집에서 출퇴근길이 멀어서 힘들었음/ 딱히 단점이 없었던 회사\n2년 열심히 다니고 ...
# 3      단, 일이 많다. 팀마다 분위기가 상이하고 줄을 잘 서야한다. 야근이 강요되지 않지...
# 4                   연봉이 현저히 작음. 합병이후 시스템 이나 프로세스 통합이 미비함
# ...                                                  ...
# 98348                     빡센문화 야근을 밥먹듯이하는사람많음 승진과열경쟁 부추김
# 98349                  다양한 은행이 모인만큼 문화가 다르지만 성과로 평가하는 은행
# 98350        과도한 업무와 합병에 따른 전산처리가 아직 미비한점 인사제도에 대한 개선 필요
# 98351  늘 그 자리에 머무는 연봉과 출신의 한계로 인한 넘사벽이 존재. 그리고 일단 비전없...
# 98352  진상고객들 처리가 최대의 단점. 고객들의 민원을 이겨낼 수 있는 멘탈관리와 성실함이...
#
#                                              경영진에게 바라는 점 각 리뷰 평점         직무  \
# 0                      낙하산 및 고인물의 교체 필요\n실무자에 대한 대우개선 필요       1     IT/인터넷
# 1                               기존 사업보다는 신규사업에 투자해야 할 시기       3     IT/인터넷
# 2               경영진에게 크게 바라는점은 없음 !! 그렇게 심한 터치가 없어서 편했나봄       2     IT/인터넷
# 3                 신규 사업에 대한 투자는 좋지만 사람도 돌보는 회사가 됐으면 좋겠다.       3     IT/인터넷
# 4           직원들에 대한 복지나 연봉을 개선하여 동기부여가 될 수 있게 해줬으면 하는 바람       2  경영/기획/컨설팅
# ...                                                  ...     ...        ...
# 98348            야근을최소화하고 경쟁과 영업압박을 너무 주지않아야 임직원들이 버팀...       4      금융/재무
# 98349  단기실적 보단 지속가능 경영의 실현이 필요할때\n통합에 관한 제도 등의 결정은 빠르...       2      금융/재무
# 98350            합병 시너지를 행원들까지 누릴 수 있게 인사제도 개선이 필요해 보입니다       3      금융/재무
# 98351                               개인과 기업을 구분하지 말고 대우하길       2      금융/재무
# 98352  영업압박에 대한 부담감이 낮았으면 좋겠고, 은행원들의 고충을 좀 더 면밀하게 살펴서...       3      금융/재무
#
#        재직상태  지역 리뷰 좋아요 개수 label
# 0       전직원  경기         0   NaN
# 1       현직원  경기         0   NaN
# 2       전직원  경기         0   NaN
# 3       전직원  서울         0   NaN
# 4       전직원  서울         0   NaN
# ...     ...  ..       ...   ...
# 98348   전직원  서울         0   0.0
# 98349   현직원  서울         0   0.0
# 98350   현직원  서울         0   0.0
# 98351   전직원  서울         0   0.0
# 98352   현직원  서울         1   0.0
#
# [98353 rows x 22 columns]

# %%
total_data = total_data.dropna(axis=0)
total_data.reset_index(inplace=True)
total_data['label'] = total_data['label'].astype(int)
total_data
# Out:
# c:\users\kym\.conda\envs\venv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        index  링크 순서       기업   평점     산업분류 직원의 기업 추천율 직원이 전망하는 성장 가능성  \
# 0        102      1  조이시티(주)  3.0  IT/웹/통신        41%             14%
# 1        103      1  조이시티(주)  3.0  IT/웹/통신        41%             14%
# 2        104      1  조이시티(주)  3.0  IT/웹/통신        41%             14%
# 3        105      1  조이시티(주)  3.0  IT/웹/통신        41%             14%
# 4        106      1  조이시티(주)  3.0  IT/웹/통신        41%             14%
# ...      ...    ...      ...  ...      ...        ...             ...
# 45810  98348     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 45811  98349     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 45812  98350     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 45813  98351     65  하나은행(주)  3.1   은행/금융업        43%             37%
# 45814  98352     65  하나은행(주)  3.1   은행/금융업        43%             37%
#
#       이 기업의 CEO 지지율  승진 기회 및 가능성  복지 및 급여  ...  \
# 0               41%          2.8      2.7  ...
# 1               41%          2.8      2.7  ...
# 2               41%          2.8      2.7  ...
# 3               41%          2.8      2.7  ...
# 4               41%          2.8      2.7  ...
# ...             ...          ...      ...  ...
# 45810           44%          3.0      3.5  ...
# 45811           44%          3.0      3.5  ...
# 45812           44%          3.0      3.5  ...
# 45813           44%          3.0      3.5  ...
# 45814           44%          3.0      3.5  ...
#
#                                                       제목  \
# 0           "개발자가 무난하게 다니기 좋은 회사.. 부서차이가 있지만 야근도 많지는 않음"
# 1      "나름 안정적으로 다닐 수 있는 곳, 프리스타일 덕에 회사 상황이 악화될 가능성은 적음"
# 2          "철저한 성과주의 조직. 게임업계다 보니 빡셈은 기본. 신입이 성장하기엔 힘듦."
# 3      "무난한 회사였으나 사원에 대한 관심이 그다지 없어보였음. 개인의 역량에 따라 많이...
# 4        "굉장히 자유로운 분위기이며, 눈치볼 일이 거의 없다. 직원들 간 유대관계 좋은 편"
# ...                                                  ...
# 45810           "업계 중 연봉은 타은행대비 보통이나 잘하면 승진및 교육기회가 있는 곳"
# 45811         "가장효율적인 조직이며 위기에 강한은행 끝까지 마지막까지 살아남을 은행이다"
# 45812         "합병으로 인해 성장성이 돋보이는 회사임. 앞으로 두 회사의 시너지가 기대"
# 45813            "적당한 수준의 연봉과 적당한 수준의 개인생활을 유지하고 싶다면 추천"
# 45814                       "매일 몰려오는 손님들을 상대할 수 있는멘탈 필요"
#
#                                                       장점  \
# 0             수평적인 분위기 지향 (호칭은 전부 ~님으로 통일), 연차 눈치없이 사용가능
# 1      5년 채우면 1달 유갑휴가 + 휴가비 지원\n근태 빡세지 않음\n게임 회사 중에는 ...
# 2      1. 권한의 자유로움\n인트라넷, 통계툴 등 신입사원이 열람할 수 있는 정보가 많은...
# 3      꽤 자유로운 분위기. 팀원간의 사이가꽤 좋아보였고 어느정도 챙겨주려고는 함. 회사자...
# 4      야근이 많지는 않으나 야근할 경우 택시비와 식대 있음. 연차 반차 눈치 안봄 연령대...
# ...                                                  ...
# 45810                  역동적인 문화로 마케팅 ㅡ좋아하면 추천입니다 연봉은 보통수준
# 45811   외환은행 통합으로 글로벌과 자산관리에 강점이 있음\n철저한 비용관리로 리스크관리가 우수
# 45812  안정적인 급여와 은행원이라는 것에 대한 자부심을 느낄 수 있음 여자행원들에 대한 복...
# 45813  개인 휴가가 보장되어 있고 타 은행에 비해 비교적 퇴근이 빠름. 분위기도 뭔가 혁신...
# 45814  복지하나는 하나은행이 짱, 주말이 보장되고 현금성 복지가 있음, 전세자금 대출도 장...
#
#                                                       단점  \
# 0                은근 사내정치가 존재, 직원들 연령대가 젊지만 젊은 꼰대도 상당히 존재
# 1      모바일에서 성공작이 별로 없음\n경영진 입김이 센편이라 회의가 길어지는 편\n모회사...
# 2      1. 신입 교육 시스템의 부족\n일련의 신입 교육 프로세스가 있는 것은 맞으나, 교...
# 3      퇴근할때 눈치가 보였음. 파트간의 갈등이 꽤 있어서 사이에서 눈치보고 어떻게 해야할...
# 4      야근은 팀바팀으로 야근 많이 하는 팀이 따로 있음. 아직 포괄임금제인점? 일을 편하...
# ...                                                  ...
# 45810                     빡센문화 야근을 밥먹듯이하는사람많음 승진과열경쟁 부추김
# 45811                  다양한 은행이 모인만큼 문화가 다르지만 성과로 평가하는 은행
# 45812        과도한 업무와 합병에 따른 전산처리가 아직 미비한점 인사제도에 대한 개선 필요
# 45813  늘 그 자리에 머무는 연봉과 출신의 한계로 인한 넘사벽이 존재. 그리고 일단 비전없...
# 45814  진상고객들 처리가 최대의 단점. 고객들의 민원을 이겨낼 수 있는 멘탈관리와 성실함이...
#
#                                              경영진에게 바라는 점 각 리뷰 평점      직무 재직상태  \
# 0      전망 있는 사업을 추진했으면 좋겠음. 중국쪽은 그나마 괜찮은거 같지만 한국에서 최근...       3  IT/인터넷  전직원
# 1      꽂히면 끝까지 투자하는 스타일이라 종종 다소 무모하다는 느낌의 투자가 발생하는 것 ...       4  IT/인터넷  현직원
# 2      신입 교육 시스템 좀 확실히 만들어 주셨으면 좋겠어요. 물어보고 어깨너머로 배우는 ...       3  IT/인터넷  전직원
# 3      경영진과는 직접적인 대화는 잘 안해서 모르겠지만 조금 더 부드러운 분위기면 좋을 것...       3  IT/인터넷  전직원
# 4         포괄임금제가 없어지면 좋겠다. 사옥이 따로 생기면 좋겠다.\n식비가 너무 많이 든다       4  IT/인터넷  현직원
# ...                                                  ...     ...     ...  ...
# 45810            야근을최소화하고 경쟁과 영업압박을 너무 주지않아야 임직원들이 버팀...       4   금융/재무  전직원
# 45811  단기실적 보단 지속가능 경영의 실현이 필요할때\n통합에 관한 제도 등의 결정은 빠르...       2   금융/재무  현직원
# 45812            합병 시너지를 행원들까지 누릴 수 있게 인사제도 개선이 필요해 보입니다       3   금융/재무  현직원
# 45813                               개인과 기업을 구분하지 말고 대우하길       2   금융/재무  전직원
# 45814  영업압박에 대한 부담감이 낮았으면 좋겠고, 은행원들의 고충을 좀 더 면밀하게 살펴서...       3   금융/재무  현직원
#
#        지역 리뷰 좋아요 개수 label
# 0      경기         0     2
# 1      경기         0     2
# 2      경기         0     2
# 3      경기         0     2
# 4      경기         0     2
# ...    ..       ...   ...
# 45810  서울         0     0
# 45811  서울         0     0
# 45812  서울         0     0
# 45813  서울         0     0
# 45814  서울         1     0
#
# [45815 rows x 23 columns]

# %% [markdown]
# # label 비중

# %%
label_cnt = list(total_data.groupby('label').size())

# %%
label_per = []

for i in range(len(label_cnt)):
    per = label_cnt[i]/sum(label_cnt) * 100
    label_per.append(per)

# %%
label_per
# Out:
# [42.74800829422678, 18.192731638109787, 39.05926006766343]

# %% [markdown]
# # 특수문자 제거

# %%
data['제목'] = data['제목'].str.replace("[^a-zA-Zㄱ-ㅎ가-힣0-9]", " ")
data['장점'] = data['장점'].str.replace("[^a-zA-Zㄱ-ㅎ가-힣0-9]", " ")
data['단점'] = data['단점'].str.replace("[^a-zA-Zㄱ-ㅎ가-힣0-9]", " ")
data['경영진에게 바라는 점'] = data['경영진에게 바라는 점'].str.replace("[^a-zA-Zㄱ-ㅎ가-힣0-9]", " ")

# %% [markdown]
# # 형태소화, pos태그 카운트, 불용품사, 불용어, 단어 길이 1개 토큰 제거

# %%
total_word=[]
tag_count=[]
mecab=Mecab()

for i in tqdm_notebook(range(len(total_data))):
    
    
    mecab_text=total_data['장점'][i]

    Mecab_tag=mecab.pos(mecab_text)
    
    tag_count.append(Counter(Mecab_tag).most_common())
    

    mecab.morphs(mecab_text)
    
    
    stopPos=['MAJ','IC','JKS','JKC','JKG','JKO','JKB','JKV','JKQ','JX','JC','XSA','EP','EF','EC','ETN','ETM','VV','VA','VX','MM','SF']

    stopwords = pd.read_csv('../data/stopwords.csv', dtype=str, sep=',', encoding='utf-8', names=['stopword'])
    stopWord = np.array(stopwords['stopword'])

    
    # 불용품사, 불용어 제거 및 한 글자 토큰 제거
    word = []
    for tag in Mecab_tag:
        if tag[1] not in stopPos:
            if tag[0] not in stopWord :
                if len(tag[0]) > 1 :
                    word.append(tag[0])
       
    
    
    total_word.append(word)
# Out:
# c:\users\kym\.conda\envs\venv\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
#   0%|          | 0/45815 [00:00<?, ?it/s]

# %% [markdown]
# # 특정 갯수 이하 토큰 제거

# %%
cnt_ls =[]

for a in range(len(total_word)):
    cnt_ls += total_word[a]
    
counter_word=Counter(cnt_ls).most_common()  

c=counter_word

# %%
c
# Out:
# [('분위기', 10483),
#  ('복지', 9596),
#  ('업무', 9435),
#  ('자유', 7838),
#  ('가능', 6800),
#  ('연차', 6561),
#  ('근무', 6355),
#  ('연봉', 6215),
#  ('사람', 5594),
#  ('직원', 5005),
#  ('문화', 4816),
#  ('눈치', 3848),
#  ('사용', 3753),
#  ('로운', 3722),
#  ('다양', 3579),
#  ('장점', 3503),
#  ('수평', 3496),
#  ('안정', 3457),
#  ('많이', 3406),
#  ('휴가', 3349),
#  ('부서', 2896),
#  ('야근', 2681),
#  ('지원', 2644),
#  ('퇴근', 2641),
#  ('급여', 2598),
#  ('보장', 2435),
#  ('비교', 2366),
#  ('기회', 2365),
#  ('환경', 2292),
#  ('경험', 2268),
#  ('생각', 2212),
#  ('강도', 2162),
#  ('사내', 2123),
#  ('때문', 2063),
#  ('출퇴근', 2049),
#  ('제공', 2029),
#  ('수준', 2019),
#  ('공기업', 1957),
#  ('배울', 1862),
#  ('매우', 1834),
#  ('비해', 1783),
#  ('대한', 1767),
#  ('교육', 1706),
#  ('조직', 1691),
#  ('경우', 1634),
#  ('개인', 1597),
#  ('정도', 1595),
#  ('입니다', 1588),
#  ('기관', 1541),
#  ('체계', 1522),
#  ('직장', 1470),
#  ('나름', 1417),
#  ('최고', 1411),
#  ('출근', 1384),
#  ('수당', 1383),
#  ('성장', 1378),
#  ('자부심', 1334),
#  ('위치', 1308),
#  ('합니다', 1235),
#  ('제도', 1196),
#  ('회식', 1184),
#  ('본인', 1152),
#  ('노력', 1152),
#  ('대부분', 1134),
#  ('워라', 1114),
#  ('정말', 1097),
#  ('해서', 1087),
#  ('시스템', 1058),
#  ('정년', 1053),
#  ('서로', 1043),
#  ('자율', 1042),
#  ('없이', 1016),
#  ('만큼', 1012),
#  ('공공', 1010),
#  ('관계', 1001),
#  ('월급', 988),
#  ('대비', 988),
#  ('점심', 985),
#  ('사업', 984),
#  ('가족', 970),
#  ('개발', 936),
#  ('혜택', 933),
#  ('글로벌', 914),
#  ('인턴', 892),
#  ('은행', 884),
#  ('능력', 875),
#  ('국내', 851),
#  ('챙겨', 849),
#  ('육아', 837),
#  ('분야', 836),
#  ('휴직', 834),
#  ('신입', 832),
#  ('다닐', 826),
#  ('사무실', 815),
#  ('영업', 812),
#  ('해외', 787),
#  ('시설', 784),
#  ('생활', 781),
#  ('자유로움', 775),
#  ('복리', 772),
#  ('존중', 762),
#  ('금융', 757),
#  ('스트레스', 756),
#  ('서울', 749),
#  ('상대', 748),
#  ('프로젝트', 747),
#  ('승진', 744),
#  ('발전', 740),
#  ('정규직', 737),
#  ('후생', 736),
#  ('구조', 730),
#  ('압박', 725),
#  ('여성', 720),
#  ('본사', 715),
#  ('관리', 714),
#  ('만족', 714),
#  ('외국', 704),
#  ('칼퇴근', 702),
#  ('사원', 678),
#  ('연구', 677),
#  ('상사', 677),
#  ('정시', 668),
#  ('전문', 660),
#  ('관련', 656),
#  ('유연', 653),
#  ('동종', 649),
#  ('계발', 648),
#  ('네임', 638),
#  ('지급', 634),
#  ('복장', 625),
#  ('필요', 621),
#  ('아르바이트', 612),
#  ('보수', 610),
#  ('부분', 603),
#  ('전반', 603),
#  ('윗사람', 600),
#  ('해도', 590),
#  ('계약직', 590),
#  ('지점', 581),
#  ('로움', 579),
#  ('고객', 578),
#  ('동료', 576),
#  ('느낌', 569),
#  ('여자', 569),
#  ('굉장히', 567),
#  ('강요', 567),
#  ('확실', 566),
#  ('된다', 559),
#  ('성과', 555),
#  ('경력', 555),
#  ('기본', 548),
#  ('10', 547),
#  ('자체', 545),
#  ('오래', 545),
#  ('대해', 541),
#  ('제외', 541),
#  ('할인', 540),
#  ('규모', 538),
#  ('직급', 538),
#  ('전체', 535),
#  ('아주', 534),
#  ('식당', 533),
#  ('지역', 528),
#  ('특성', 527),
#  ('준다', 524),
#  ('초봉', 524),
#  ('대체', 522),
#  ('느낄', 518),
#  ('여유', 518),
#  ('노조', 511),
#  ('대체로', 498),
#  ('대우', 497),
#  ('위한', 493),
#  ('삼성', 491),
#  ('편안', 488),
#  ('서비스', 488),
#  ('차이', 487),
#  ('병원', 484),
#  ('해줌', 481),
#  ('실적', 481),
#  ('산업', 470),
#  ('위해', 466),
#  ('나옴', 466),
#  ('역량', 459),
#  ('주말', 458),
#  ('진행', 457),
#  ('열심히', 456),
#  ('건물', 456),
#  ('계열사', 453),
#  ('적당', 451),
#  ('법인', 451),
#  ('고용', 449),
#  ('식대', 447),
#  ('신경', 447),
#  ('너무', 446),
#  ('추천', 443),
#  ('일반', 443),
#  ('식사', 440),
#  ('입사', 438),
#  ('저녁', 438),
#  ('평균', 432),
#  ('기숙사', 431),
#  ('우수', 430),
#  ('영어', 429),
#  ('도움', 425),
#  ('아님', 424),
#  ('무료', 422),
#  ('사기업', 422),
#  ('상당히', 421),
#  ('별로', 421),
#  ('이용', 420),
#  ('한다는', 418),
#  ('끼리', 417),
#  ('브랜드', 413),
#  ('마인드', 409),
#  ('의견', 409),
#  ('순환', 409),
#  ('터치', 407),
#  ('상위', 405),
#  ('존재', 400),
#  ('밸류', 400),
#  ('사택', 400),
#  ('운영', 399),
#  ('꼰대', 398),
#  ('지사', 397),
#  ('해야', 396),
#  ('보임', 392),
#  ('30', 392),
#  ('포인트', 382),
#  ('배려', 381),
#  ('아침', 380),
#  ('공무원', 376),
#  ('직무', 375),
#  ('카페', 373),
#  ('빠른', 368),
#  ('주변', 364),
#  ('이직', 364),
#  ('대표', 363),
#  ('됩니다', 363),
#  ('매장', 361),
#  ('중소기업', 358),
#  ('편함', 357),
#  ('기준', 356),
#  ('아닌', 354),
#  ('합리', 353),
#  ('택시', 352),
#  ('실력', 351),
#  ('훌륭', 351),
#  ('그룹', 348),
#  ('통해', 348),
#  ('깔끔', 345),
#  ('깨끗', 345),
#  ('기반', 342),
#  ('간식', 340),
#  ('기술', 340),
#  ('비슷', 338),
#  ('공부', 337),
#  ('계속', 335),
#  ('음료', 335),
#  ('지방', 334),
#  ('학교', 334),
#  ('그만큼', 333),
#  ('제품', 333),
#  ('인정', 329),
#  ('편한', 329),
#  ('그나마', 328),
#  ('임금', 327),
#  ('인간', 324),
#  ('상승', 323),
#  ('수직', 322),
#  ('컨설팅', 322),
#  ('커피', 321),
#  ('이미지', 321),
#  ('행사', 321),
#  ('평가', 320),
#  ('새로운', 319),
#  ('균형', 317),
#  ('쾌적', 316),
#  ('확실히', 315),
#  ('활동', 313),
#  ('기간', 311),
#  ('가질', 311),
#  ('시장', 311),
#  ('보상', 309),
#  ('라서', 309),
#  ('중요', 307),
#  ('인지', 307),
#  ('무난', 304),
#  ('활용', 304),
#  ('업체', 303),
#  ('수도', 303),
#  ('관심', 301),
#  ('교대', 301),
#  ('내부', 300),
#  ('커리어', 300),
#  ('친절', 299),
#  ('바이', 299),
#  ('단점', 296),
#  ('잡혀', 295),
#  ('시급', 295),
#  ('문제', 293),
#  ('소통', 293),
#  ('편리', 291),
#  ('연령', 291),
#  ('사회', 291),
#  ('수행', 290),
#  ('매출', 290),
#  ('출장', 290),
#  ('팀장', 289),
#  ('경영진', 287),
#  ('워크', 287),
#  ('버스', 286),
#  ('투자', 286),
#  ('탄탄', 285),
#  ('IT', 285),
#  ('부담', 284),
#  ('스케줄', 284),
#  ('한국', 284),
#  ('인센티브', 283),
#  ('지켜', 283),
#  ('비용', 281),
#  ('그런지', 280),
#  ('유지', 280),
#  ('성과급', 277),
#  ('사이', 275),
#  ('무제', 275),
#  ('회계', 274),
#  ('휴일', 273),
#  ('자동차', 273),
#  ('그냥', 272),
#  ('카드', 271),
#  ('마음', 271),
#  ('처리', 270),
#  ('유연근', 265),
#  ('명절', 265),
#  ('나이', 265),
#  ('개선', 263),
#  ('근속', 261),
#  ('자주', 261),
#  ('분담', 261),
#  ('구내식당', 261),
#  ('매니저', 260),
#  ('경쟁', 259),
#  ('보람', 259),
#  ('미래', 258),
#  ('전문가', 258),
#  ('차별', 258),
#  ('구성원', 258),
#  ('휴식', 257),
#  ('최대', 254),
#  ('걱정', 254),
#  ('현장', 254),
#  ('학생', 254),
#  ('딱히', 253),
#  ('보통', 253),
#  ('비해서', 252),
#  ('본부', 250),
#  ('광고', 250),
#  ('이름', 248),
#  ('지식', 248),
#  ('성격', 247),
#  ('누릴', 247),
#  ('인력', 245),
#  ('추가', 244),
#  ('조정', 244),
#  ('세계', 244),
#  ('지속', 243),
#  ('인지도', 243),
#  ('정확', 242),
#  ('다름', 241),
#  ('전혀', 240),
#  ('대학', 239),
#  ('사장', 238),
#  ('항상', 238),
#  ('책임', 237),
#  ('인해', 237),
#  ('적응', 237),
#  ('도서', 236),
#  ('의지', 236),
#  ('방학', 235),
#  ('바케', 234),
#  ('교대근무', 234),
#  ('시즌', 233),
#  ('근무지', 233),
#  ('탄력', 232),
#  ('대구', 232),
#  ('시작', 231),
#  ('자리', 229),
#  ('안전', 228),
#  ('모습', 227),
#  ('프로세스', 226),
#  ('현재', 226),
#  ('점점', 225),
#  ('선물', 225),
#  ('가끔', 224),
#  ('보유', 223),
#  ('적극', 222),
#  ('휴무', 222),
#  ('열정', 222),
#  ('집중', 221),
#  ('20', 221),
#  ('팀원', 220),
#  ('월차', 220),
#  ('단축', 220),
#  ('제약', 219),
#  ('52', 218),
#  ('절대', 217),
#  ('무조건', 217),
#  ('연구원', 216),
#  ('보너스', 216),
#  ('상하', 215),
#  ('이전', 215),
#  ('진급', 215),
#  ('외부', 214),
#  ('줍니다', 214),
#  ('일정', 213),
#  ('국가', 213),
#  ('충분히', 211),
#  ('밸런스', 211),
#  ('인한', 210),
#  ('따로', 210),
#  ('출산', 210),
#  ('상여금', 210),
#  ('직접', 209),
#  ('아이스크림', 208),
#  ('벨류', 208),
#  ('기대', 207),
#  ('적절', 207),
#  ('구입', 205),
#  ('변화', 204),
#  ('교통', 204),
#  ('유일', 204),
#  ('정부', 204),
#  ('일찍', 204),
#  ('진짜', 204),
#  ('향상', 204),
#  ('제일', 204),
#  ('개발자', 202),
#  ('철저', 201),
#  ('힘든', 200),
#  ('부산', 200),
#  ('정책', 199),
#  ('현대', 199),
#  ('인사', 198),
#  ('커뮤니케이션', 198),
#  ('단위', 198),
#  ('금요일', 197),
#  ('클라이언트', 197),
#  ('경영', 196),
#  ('공간', 196),
#  ('얘기', 193),
#  ('연수', 193),
#  ('엄청', 192),
#  ('통근', 192),
#  ('퇴사', 192),
#  ('망할', 191),
#  ('일부', 189),
#  ('효율', 188),
#  ('인재', 187),
#  ('일본', 187),
#  ('형성', 187),
#  ('출신', 187),
#  ('대신', 186),
#  ('박사', 186),
#  ('마케팅', 186),
#  ('임원', 186),
#  ('이벤트', 185),
#  ('여건', 185),
#  ('스스로', 184),
#  ('하루', 183),
#  ('딱딱', 183),
#  ('빨리', 182),
#  ('영화', 182),
#  ('이동', 182),
#  ('업종', 182),
#  ('시험', 181),
#  ('메리트', 181),
#  ('이외', 180),
#  ('특별', 179),
#  ('시행', 179),
#  ('위주', 179),
#  ('50', 179),
#  ('호봉', 179),
#  ('라이프', 178),
#  ('그렇게', 177),
#  ('인상', 177),
#  ('의사', 177),
#  ('계열', 177),
#  ('욕심', 176),
#  ('수월', 175),
#  ('메뉴', 174),
#  ('에선', 174),
#  ('선택', 172),
#  ('준수', 172),
#  ('협업', 171),
#  ('담당', 171),
#  ('매년', 171),
#  ('부족', 171),
#  ('시도', 170),
#  ('포함', 170),
#  ('공휴일', 170),
#  ('프로그램', 170),
#  ('반도체', 170),
#  ('여의도', 169),
#  ('봐도', 168),
#  ('비율', 168),
#  ('접근', 167),
#  ('다를', 167),
#  ('접할', 167),
#  ('장비', 167),
#  ('중견', 166),
#  ('처음', 166),
#  ('만날', 166),
#  ('지금', 166),
#  ('적용', 165),
#  ('갖춰져', 165),
#  ('연말', 165),
#  ('게임', 163),
#  ('생산', 163),
#  ('결정', 162),
#  ('연장', 160),
#  ('제대로', 159),
#  ('부여', 159),
#  ('준비', 159),
#  ('시중', 159),
#  ('충분', 158),
#  ('활발', 158),
#  ('왠만', 158),
#  ('널널', 158),
#  ('선배', 158),
#  ('개개인', 157),
#  ('도입', 157),
#  ('기술력', 157),
#  ('단순', 157),
#  ('공단', 157),
#  ('해당', 156),
#  ('연금', 156),
#  ('정보', 154),
#  ('적당히', 154),
#  ('유동', 153),
#  ('에겐', 152),
#  ('바쁜', 152),
#  ('개인주의', 152),
#  ('사무', 152),
#  ('참여', 152),
#  ('협력', 152),
#  ('중심', 152),
#  ('대리', 152),
#  ('제한', 150),
#  ('친구', 150),
#  ('용이', 150),
#  ('데이', 150),
#  ('주휴', 150),
#  ('파견', 149),
#  ('최대한', 149),
#  ('근로', 149),
#  ('수익', 149),
#  ('조건', 149),
#  ('상황', 148),
#  ('인원', 148),
#  ('이해', 148),
#  ('헬스', 147),
#  ('가정', 147),
#  ('부바', 147),
#  ('보단', 147),
#  ('뛰어난', 147),
#  ('똑똑', 146),
#  ('열려', 146),
#  ('젠틀', 146),
#  ('반차', 145),
#  ('학원', 145),
#  ('중시', 145),
#  ('라면', 145),
#  ('대졸', 144),
#  ('특유', 144),
#  ('철저히', 144),
#  ('직종', 143),
#  ('보험', 143),
#  ('여서', 143),
#  ('서비스업', 143),
#  ('사고', 142),
#  ('공장', 142),
#  ('채용', 142),
#  ('불구', 142),
#  ('그리', 141),
#  ('과장', 141),
#  ('정치', 141),
#  ('건강', 141),
#  ('편의', 141),
#  ('평생', 140),
#  ('구성', 140),
#  ('감사', 140),
#  ('상호', 139),
#  ('줘서', 139),
#  ('향후', 139),
#  ('사옥', 138),
#  ('야간', 138),
#  ('지향', 137),
#  ('성향', 137),
#  ('소소', 137),
#  ('페이', 137),
#  ('형태', 137),
#  ('장기', 137),
#  ('임직원', 137),
#  ('나라', 137),
#  ('구축', 136),
#  ('교수', 136),
#  ('스러운', 136),
#  ('위생', 136),
#  ('호칭', 135),
#  ('카페테리아', 135),
#  ('조용', 135),
#  ('비전', 135),
#  ('장려', 135),
#  ('또래', 135),
#  ('남자', 135),
#  ('어려운', 134),
#  ('강남', 134),
#  ('계약', 134),
#  ('가진', 134),
#  ('식비', 134),
#  ('추구', 133),
#  ('작업', 133),
#  ('동호회', 133),
#  ('확보', 133),
#  ('홍보', 133),
#  ('조절', 132),
#  ('기획', 132),
#  ('어려움', 131),
#  ('반영', 131),
#  ('매일', 131),
#  ('중간', 131),
#  ('타이틀', 131),
#  ('스타트업', 131),
#  ('자회사', 129),
#  ('지하철', 128),
#  ('꼬박꼬박', 128),
#  ('저렴', 128),
#  ('도전', 128),
#  ('공짜', 128),
#  ('통한', 127),
#  ('도와', 127),
#  ('여직', 127),
#  ('전국', 127),
#  ('주일', 126),
#  ('전공', 126),
#  ('유통', 126),
#  ('프리', 125),
#  ('대학교', 125),
#  ('네트워크', 125),
#  ('기를', 125),
#  ('상관없이', 125),
#  ('도시', 125),
#  ('근태', 124),
#  ('마련', 124),
#  ('교통비', 124),
#  ('배치', 124),
#  ('데이터', 124),
#  ('실무', 123),
#  ('인성', 123),
#  ('강제', 123),
#  ('측면', 122),
#  ('해결', 122),
#  ('음식', 122),
#  ('이야기', 122),
#  ('조성', 122),
#  ('사무직', 122),
#  ('엔지니어', 122),
#  ('맞춰', 122),
#  ('직업', 122),
#  ('동기', 121),
#  ('예전', 121),
#  ('근무자', 121),
#  ('잔업', 121),
#  ('평등', 121),
#  ('교직원', 121),
#  ('주도', 120),
#  ('다운', 120),
#  ('직군', 120),
#  ('과정', 120),
#  ('재무', 120),
#  ('합병', 120),
#  ('대행사', 120),
#  ('실제로', 119),
#  ('근처', 119),
#  ('역할', 118),
#  ('인프라', 118),
#  ('아무래도', 118),
#  ('요즘', 118),
#  ('교류', 117),
#  ('타사', 117),
#  ('알바', 117),
#  ('정신', 117),
#  ('대한민국', 117),
#  ('라인', 116),
#  ('기본급', 116),
#  ('영역', 116),
#  ('인식', 116),
#  ('입장', 115),
#  ('일본어', 115),
#  ('방향', 114),
#  ('정해진', 114),
#  ('즐길', 114),
#  ('신청', 114),
#  ('습득', 114),
#  ('매달', 113),
#  ('특정', 113),
#  ('웬만', 113),
#  ('점장', 113),
#  ('스펙', 113),
#  ('주어짐', 112),
#  ('시기', 112),
#  ('40', 112),
#  ('키울', 112),
#  ('가치', 112),
#  ('최상위', 112),
#  ('난이도', 112),
#  ('주로', 111),
#  ('마음껏', 111),
#  ('유명', 111),
#  ('여름', 111),
#  ('파트', 111),
#  ('먼저', 111),
#  ('오픈', 111),
#  ('나온다', 110),
#  ('동일', 110),
#  ('대출', 110),
#  ('강점', 110),
#  ('회의', 110),
#  ('이익', 110),
#  ('에너지', 110),
#  ('군대', 109),
#  ('명확', 109),
#  ('샌드위치', 109),
#  ('자녀', 109),
#  ('센터', 109),
#  ('대외', 108),
#  ('적합', 108),
#  ('긍정', 108),
#  ('100', 108),
#  ('외근', 108),
#  ('케이스', 107),
#  ('그대로', 107),
#  ('연구소', 107),
#  ('체력', 107),
#  ('고민', 106),
#  ('쉬움', 106),
#  ('행정', 106),
#  ('청소', 106),
#  ('비정규직', 105),
#  ('배움', 105),
#  ('자연', 105),
#  ('휴게실', 105),
#  ('개월', 104),
#  ('체험', 104),
#  ('디자인', 104),
#  ('빵빵', 104),
#  ('발령', 104),
#  ('공정', 103),
#  ('권장', 103),
#  ('삼성전자', 103),
#  ('프로', 103),
#  ('공사', 103),
#  ('간섭', 102),
#  ('상당', 102),
#  ('파트너', 102),
#  ('구매', 102),
#  ('거리', 102),
#  ('어린이집', 102),
#  ('운편', 101),
#  ('선생', 101),
#  ('학자금', 101),
#  ('상여', 101),
#  ('11', 101),
#  ('연고지', 101),
#  ('재택근무', 100),
#  ('생산직', 100),
#  ('개방', 100),
#  ('사소', 100),
#  ('공유', 100),
#  ('활성', 99),
#  ('15', 99),
#  ('사실', 99),
#  ('패밀리', 99),
#  ('여행', 99),
#  ('단기간', 99),
#  ('메이저', 99),
#  ('회계사', 99),
#  ('덕분', 98),
#  ('의사소통', 98),
#  ('온라인', 98),
#  ('전환', 98),
#  ('특근', 98),
#  ('된다는', 98),
#  ('강압', 98),
#  ('취업', 98),
#  ('사학', 98),
#  ('강의', 97),
#  ('독점', 97),
#  ('노하우', 97),
#  ('민원', 97),
#  ('대전', 97),
#  ('생일', 96),
#  ('결혼', 96),
#  ('제조', 96),
#  ('프라이드', 96),
#  ('기억', 96),
#  ('양호', 96),
#  ('셔틀버스', 96),
#  ('된다면', 95),
#  ('여가', 95),
#  ('원활', 95),
#  ('알려', 94),
#  ('년수', 94),
#  ('처우', 94),
#  ('쏠쏠', 94),
#  ('기한', 94),
#  ('한가', 94),
#  ('어학', 93),
#  ('방식', 93),
#  ('제조업', 93),
#  ('도서관', 93),
#  ('정착', 93),
#  ('모여', 93),
#  ('강한', 93),
#  ('조기', 93),
#  ('제때', 92),
#  ('동아리', 92),
#  ('빠름', 92),
#  ('발비', 92),
#  ('만족도', 92),
#  ('기계', 91),
#  ('자동', 91),
#  ('외국어', 91),
#  ('남녀', 91),
#  ('들어왔', 91),
#  ('최상', 90),
#  ('열린', 90),
#  ('엄청난', 90),
#  ('교육비', 90),
#  ('원한다면', 90),
#  ('금전', 90),
#  ('성공', 90),
#  ('정해져', 90),
#  ('권한', 89),
#  ('경기', 89),
#  ('경쟁력', 89),
#  ('판매', 89),
#  ('정직', 89),
#  ('추세', 89),
#  ('과제', 88),
#  ('한편', 88),
#  ('시켜', 88),
#  ('요구', 88),
#  ('꾸준', 88),
#  ('미리', 88),
#  ('화목', 88),
#  ('12', 88),
#  ('이사', 88),
#  ('소속', 88),
#  ('타임', 88),
#  ('착함', 88),
#  ('부장', 87),
#  ('조식', 87),
#  ('바쁠', 87),
#  ('여름휴가', 87),
#  ('자료', 87),
#  ('파워', 87),
#  ('집단', 87),
#  ('반복', 86),
#  ('인맥', 86),
#  ('설비', 86),
#  ('대형', 86),
#  ('지낼', 86),
#  ('초과', 86),
#  ('특별히', 85),
#  ('이유', 85),
#  ('연휴', 85),
#  ('초반', 85),
#  ('달리', 85),
#  ('심야', 85),
#  ('동절기', 85),
#  ('신규', 84),
#  ('영향', 84),
#  ('연월', 84),
#  ('유리', 84),
#  ('자랑', 84),
#  ('스마트', 84),
#  ('상품', 84),
#  ('자기계', 84),
#  ('농협', 84),
#  ('불만', 83),
#  ('작성', 83),
#  ('보직', 83),
#  ('실시', 83),
#  ('생김', 82),
#  ('익숙', 82),
#  ('이것저것', 82),
#  ('석식', 82),
#  ('특수', 82),
#  ('오프', 82),
#  ('오피스', 82),
#  ('인천', 82),
#  ('투명', 82),
#  ('선입', 82),
#  ('선출', 82),
#  ('목표', 81),
#  ('무리', 81),
#  ('연구실', 81),
#  ('기술직', 81),
#  ('최저', 81),
#  ('따뜻', 80),
#  ('경력직', 80),
#  ('차원', 80),
#  ('운동', 80),
#  ('무시', 80),
#  ('아무', 79),
#  ('발생', 79),
#  ('추진', 79),
#  ('매주', 79),
#  ('외국인', 79),
#  ('화장품', 79),
#  ('수요일', 79),
#  ('공항', 79),
#  ('단체', 78),
#  ('근시', 78),
#  ('끈끈', 78),
#  ('상이', 78),
#  ('자금', 78),
#  ('파악', 78),
#  ('상관', 78),
#  ('과일', 78),
#  ('중앙', 78),
#  ('단련', 78),
#  ('군대식', 78),
#  ('가까운', 77),
#  ('진출', 77),
#  ('겨울', 77),
#  ('경제', 77),
#  ('계획', 77),
#  ('걸로', 77),
#  ('주어진', 76),
#  ('전망', 76),
#  ('구비', 76),
#  ('수주', 76),
#  ('스러움', 76),
#  ('직영', 76),
#  ('더욱', 76),
#  ('당연', 76),
#  ('독보', 76),
#  ('세대', 76),
#  ('현금', 76),
#  ('셔서', 76),
#  ('휴가비', 75),
#  ('대학원', 75),
#  ('쉬운', 75),
#  ('실제', 75),
#  ('혁신', 75),
#  ('중식', 75),
#  ('중상', 75),
#  ('전략', 75),
#  ('기분', 75),
#  ('아이디어', 75),
#  ('응대', 75),
#  ('간호사', 75),
#  ('장기근속', 74),
#  ('써도', 74),
#  ('편차', 74),
#  ('기존', 74),
#  ('공기', 74),
#  ('사항', 74),
#  ('검진', 74),
#  ('무기', 74),
#  ('풍부', 74),
#  ('유한', 74),
#  ('면접', 74),
#  ('안마', 73),
#  ('튼튼', 73),
#  ('발휘', 73),
#  ('권위', 73),
#  ('예상', 73),
#  ('별도', 73),
#  ('수록', 73),
#  ('금방', 73),
#  ('자격증', 73),
#  ('새로', 73),
#  ('타행', 73),
#  ('국책은행', 73),
#  ('이건', 72),
#  ('들어옴', 72),
#  ('선후배', 72),
#  ('대화', 72),
#  ('광고주', 72),
#  ('스포츠', 72),
#  ('60', 72),
#  ('모난', 71),
#  ('가까움', 71),
#  ('리더', 71),
#  ('상품권', 71),
#  ('추석', 71),
#  ...]

# %%
# 5개 이하
c_5 = c[-9935:]
c_5
# Out:
# [('Sk', 4),
#  ('다닐수록', 4),
#  ('낮잠', 4),
#  ('~)', 4),
#  ('총괄', 4),
#  ('불분명', 4),
#  ('일례', 4),
#  ('도달', 4),
#  ('경지', 4),
#  ('허울', 4),
#  ('진화', 4),
#  ('긴장', 4),
#  ('게이머', 4),
#  ('형평', 4),
#  ('선사', 4),
#  ('들으려고', 4),
#  ('허례허식', 4),
#  ('중요히', 4),
#  ('수소', 4),
#  ('내라', 4),
#  ('져도', 4),
#  ('밤낮', 4),
#  ('소등', 4),
#  ('곤란', 4),
#  ('뭉침', 4),
#  ('전개', 4),
#  ('확연', 4),
#  ('윤택', 4),
#  ('걸려서', 4),
#  ('섹터', 4),
#  ('개국', 4),
#  ('시책', 4),
#  ('아빠', 4),
#  ('취침', 4),
#  ('농후', 4),
#  ('바글바글', 4),
#  ('신의', 4),
#  ('서지', 4),
#  ('에코', 4),
#  ('월화', 4),
#  ('쾌활', 4),
#  ('목욕탕', 4),
#  ('벌이', 4),
#  ('중산', 4),
#  ('종각', 4),
#  ('야외', 4),
#  ('방지법', 4),
#  ('당기', 4),
#  ('만년', 4),
#  ('PE', 4),
#  ('구상', 4),
#  ('도구', 4),
#  ('서든', 4),
#  ('주워', 4),
#  ('하드웨어', 4),
#  ('%,', 4),
#  ('법칙', 4),
#  ('수신', 4),
#  ('트레이딩', 4),
#  ('ib', 4),
#  ('솔선수범', 4),
#  ('드신', 4),
#  ('종각역', 4),
#  ('밥집', 4),
#  ('기부', 4),
#  ('이관', 4),
#  ('전수', 4),
#  ('기보', 4),
#  ('위해선', 4),
#  ('양반', 4),
#  ('이수', 4),
#  ('원시', 4),
#  ('으쓱', 4),
#  ('예측', 4),
#  ('휴가일', 4),
#  ('식스', 4),
#  ('상세히', 4),
#  ('시칼', 4),
#  ('막중', 4),
#  ('둥글', 4),
#  ('수력', 4),
#  ('개개', 4),
#  ('활짝', 4),
#  ('트레이드', 4),
#  ('삼성역', 4),
#  ('박람회', 4),
#  ('회비', 4),
#  ('세기', 4),
#  ('삼성동', 4),
#  ('평과', 4),
#  ('변환', 4),
#  ('숨겨', 4),
#  ('피시', 4),
#  ('내점', 4),
#  ('담보', 4),
#  ('Pc', 4),
#  ('갑인', 4),
#  ('로비', 4),
#  ('찬스', 4),
#  ('소장', 4),
#  ('비상', 4),
#  ('작동', 4),
#  ('원리', 4),
#  ('자연주의', 4),
#  ('잔잔', 4),
#  ('파이프', 4),
#  ('이기주의', 4),
#  ('sky', 4),
#  ('극상', 4),
#  ('직간', 4),
#  ('산업단지', 4),
#  ('살만', 4),
#  ('울진', 4),
#  ('무이자', 4),
#  ('고리', 4),
#  ('월성', 4),
#  ('만료', 4),
#  ('수영장', 4),
#  ('회관', 4),
#  ('몰입', 4),
#  ('나쁨', 4),
#  ('can', 4),
#  ('바빴', 4),
#  ('어울려', 4),
#  ('일명', 4),
#  ('가계', 4),
#  ('발전시설', 4),
#  ('당량', 4),
#  ('감당', 4),
#  ('선의', 4),
#  ('변함', 4),
#  ('우회', 4),
#  ('Case', 4),
#  ('아주머니', 4),
#  ('다인', 4),
#  ('설거지', 4),
#  ('놀람', 4),
#  ('법대', 4),
#  ('주민', 4),
#  ('자정', 4),
#  ('부드러움', 4),
#  ('통화', 4),
#  ('99', 4),
#  ('미사', 4),
#  ('보사', 4),
#  ('토박이', 4),
#  ('비번', 4),
#  ('실속', 4),
#  ('건보', 4),
#  ('남대문', 4),
#  ('8000', 4),
#  ('임차', 4),
#  ('관공서', 4),
#  ('출판', 4),
#  ('완수', 4),
#  ('심했', 4),
#  ('소모임', 4),
#  ('앞날', 4),
#  ('대해야', 4),
#  ('계신다', 4),
#  ('일일이', 4),
#  ('계장', 4),
#  ('수수료', 4),
#  ('부점', 4),
#  ('연공', 4),
#  ('오를수록', 4),
#  ('지참', 4),
#  ('이데이', 4),
#  ('돌아다닐', 4),
#  ('남북', 4),
#  ('고속도로', 4),
#  ('교과서', 4),
#  ('보조비', 4),
#  ('가져왔', 4),
#  ('종업원', 4),
#  ('보인다면', 4),
#  ('인문', 4),
#  ('집합', 4),
#  ('상향', 4),
#  ('함꼐', 4),
#  ('시범', 4),
#  ('자면', 4),
#  ('거절', 4),
#  ('다룬다는', 4),
#  ('순찰', 4),
#  ('사태', 4),
#  ('db', 4),
#  ('의왕역', 4),
#  ('마진', 4),
#  ('대산', 4),
#  ('냉매', 4),
#  ('대내외', 4),
#  ('융자', 4),
#  ('계기', 4),
#  ('잔치', 4),
#  ('형제', 4),
#  ('양복', 4),
#  ('미칠', 4),
#  ('빈도수', 4),
#  ('고용부', 4),
#  ('추상', 4),
#  ('관광', 4),
#  ('일치', 4),
#  ('이뤄진', 4),
#  ('이뻐서', 4),
#  ('?).', 4),
#  ('견실', 4),
#  ('시임', 4),
#  ('게임기', 4),
#  ('부대', 4),
#  ('배출', 4),
#  ('북미', 4),
#  ('임산부', 4),
#  ('주기도', 4),
#  ('소외', 4),
#  ('가감', 4),
#  ('요샌', 4),
#  ('돌아옴', 4),
#  ('시일', 4),
#  ('가방', 4),
#  ('사갈', 4),
#  ('자요', 4),
#  ('시설물', 4),
#  ('폐기물', 4),
#  ('오갈', 4),
#  ('선함', 4),
#  ('봉사자', 4),
#  ('소유자', 4),
#  ('다채', 4),
#  ('smart', 4),
#  ('허물없이', 4),
#  ('정신력', 4),
#  ('그분', 4),
#  ('스낵바', 4),
#  ('행정원', 4),
#  ('폐지', 4),
#  ('인과', 4),
#  ('수영', 4),
#  ('연기금', 4),
#  ('.............', 4),
#  ('회가', 4),
#  ('극성', 4),
#  ('봐요', 4),
#  ('23', 4),
#  ('포용', 4),
#  ('보여도', 4),
#  ('와이프', 4),
#  ('산재', 4),
#  ('구할', 4),
#  ('부러워한다', 4),
#  ('시청역', 4),
#  ('트렉', 4),
#  ('호남', 4),
#  ('정수장', 4),
#  ('유무', 4),
#  ('각방', 4),
#  ('여사', 4),
#  ('기능직', 4),
#  ('특허청', 4),
#  ('이래저래', 4),
#  ('구리', 4),
#  ('임시직', 4),
#  ('중증', 4),
#  ('만남', 4),
#  ('카톡', 4),
#  ('콘서트', 4),
#  ('석촌', 4),
#  ('즐거울', 4),
#  ('출근길', 4),
#  ('MLCC', 4),
#  ('명찰', 4),
#  ('도덕', 4),
#  ('문법', 4),
#  ('수험', 4),
#  ('수능', 4),
#  ('신용산역', 4),
#  ('CGV', 4),
#  ('상영', 4),
#  ('미뤄', 4),
#  ('마이너', 4),
#  ('에스프레소', 4),
#  ('헤어', 4),
#  ('나잇', 4),
#  ('풀타임', 4),
#  ('커니', 4),
#  ('ktx', 4),
#  ('약소', 4),
#  ('평촌역', 4),
#  ('스페인어', 4),
#  ('올리브', 4),
#  ('기업가', 4),
#  ('수고', 4),
#  ('넷째', 4),
#  ('카운트', 4),
#  ('바뀐다', 4),
#  ('수리', 4),
#  ('늘어납니다', 4),
#  ('어치', 4),
#  ('맀음', 4),
#  ('리원데', 4),
#  ('iv', 4),
#  ('외래', 4),
#  ('신년', 4),
#  ('때론', 4),
#  ('다년간', 4),
#  ('ppr', 4),
#  ('환경친화', 4),
#  ('특권', 4),
#  ('consulting', 4),
#  ('밀려', 4),
#  ('타이어', 4),
#  ('사서', 4),
#  ('제련', 4),
#  ('임사', 4),
#  ('가산', 4),
#  ('월급제', 4),
#  ('지켜준다', 4),
#  ('전장', 4),
#  ('통한다', 4),
#  ('미세먼지', 4),
#  ('서현', 3),
#  ('불러야', 3),
#  ('ㅇㅇ님', 3),
#  ('개발력', 3),
#  ('잘지', 3),
#  ('플랫', 3),
#  ('선가', 3),
#  ('직분', 3),
#  ('~~~~', 3),
#  ('계십니다', 3),
#  ('언제든지', 3),
#  ('의복', 3),
#  ('부턴', 3),
#  ('속자', 3),
#  ('남부', 3),
#  ('참치', 3),
#  ('대대', 3),
#  ('해져서', 3),
#  ('버거울', 3),
#  ('자울', 3),
#  ('내려갈', 3),
#  ('소지자', 3),
#  ('연반', 3),
#  ('쿠팡', 3),
#  ('점식', 3),
#  ('400', 3),
#  ('고무', 3),
#  ('애서', 3),
#  ('우체국', 3),
#  ('페이도', 3),
#  ('랜덤', 3),
#  ('새끼', 3),
#  ('집안일', 3),
#  ('귀향', 3),
#  ('내기', 3),
#  ('GPS', 3),
#  ('명심', 3),
#  ('training', 3),
#  ('가졌으며', 3),
#  ('뭉쳐서', 3),
#  ('들림', 3),
#  ('피로도', 3),
#  ('재기', 3),
#  ('모양새', 3),
#  ('바자회', 3),
#  ('정보력', 3),
#  ('gps', 3),
#  ('셰프', 3),
#  ('휴가철', 3),
#  ('배낭', 3),
#  ('판매처', 3),
#  ('전방', 3),
#  ('의의', 3),
#  ('파라다이스', 3),
#  ('내공', 3),
#  ('만능', 3),
#  ('유부남', 3),
#  ('가입자', 3),
#  ('건수', 3),
#  ('나온다면', 3),
#  ('동급', 3),
#  ('미혼', 3),
#  ('사라졌', 3),
#  ('억지', 3),
#  ('인제', 3),
#  ('커플', 3),
#  ('맞춰줄', 3),
#  ('할로윈', 3),
#  ('치가', 3),
#  ('지켜졌', 3),
#  ('잠잘', 3),
#  ('소지', 3),
#  ('장단', 3),
#  ('럭셔리', 3),
#  ('홍콩', 3),
#  ('각국', 3),
#  ('푸쉬', 3),
#  ('통보', 3),
#  ('차림', 3),
#  ('종목', 3),
#  ('축구', 3),
#  ('고개', 3),
#  ('한국어', 3),
#  ('낭만', 3),
#  ('두려움', 3),
#  ('늡니다', 3),
#  ('접수', 3),
#  ('안음', 3),
#  ('누굴', 3),
#  ('안달', 3),
#  ('잡지사', 3),
#  ('언론사', 3),
#  ('옮겨서', 3),
#  ('본질', 3),
#  ('주니', 3),
#  ('근자', 3),
#  ('Line', 3),
#  ('열망', 3),
#  ('보조원', 3),
#  ('관광지', 3),
#  ('이겨', 3),
#  ('사이코', 3),
#  ('제네릭', 3),
#  ('보도', 3),
#  ('풀린', 3),
#  ('지대', 3),
#  ('종병', 3),
#  ('클리닉', 3),
#  ('알파', 3),
#  ('틀어져', 3),
#  ('축척', 3),
#  ('주당', 3),
#  ('졌었', 3),
#  ('꿀잠', 3),
#  ('불량', 3),
#  ('기프', 3),
#  ('어머니', 3),
#  ('붙혀', 3),
#  ('인격체', 3),
#  ('난무', 3),
#  ('막힌', 3),
#  ('사당', 3),
#  ('천청', 3),
#  ('따라감', 3),
#  ('배식', 3),
#  ('질병', 3),
#  ('다룸', 3),
#  ('마친다면', 3),
#  ('속시', 3),
#  ('극소수', 3),
#  ('용무', 3),
#  ('생깁니다', 3),
#  ('이브닝', 3),
#  ('한결', 3),
#  ('츄리닝', 3),
#  ('97', 3),
#  ('young', 3),
#  ('조곤조곤', 3),
#  ('별점', 3),
#  ('생동감', 3),
#  ('이어폰', 3),
#  ('후드', 3),
#  ('샌티', 3),
#  ('스마트폰', 3),
#  ('칸막이', 3),
#  ('둔다면', 3),
#  ('보인다고', 3),
#  ('찾아봐도', 3),
#  ('박기', 3),
#  ('믹스', 3),
#  ('플랜트', 3),
#  ('한다기', 3),
#  ('무도', 3),
#  ('온다면', 3),
#  ('배관', 3),
#  ('pcb', 3),
#  ('처분', 3),
#  ('될수록', 3),
#  ('밴드', 3),
#  ('빌려서', 3),
#  ('high', 3),
#  ('해옴', 3),
#  ('영속', 3),
#  ('강소', 3),
#  ('대치', 3),
#  ('양돈', 3),
#  ('술값', 3),
#  ('오빠', 3),
#  ('고기', 3),
#  ('열림', 3),
#  ('계열화', 3),
#  ('순회', 3),
#  ('돼지', 3),
#  ('떨어졌', 3),
#  ('중추', 3),
#  ('문의', 3),
#  ('오바', 3),
#  ('창업자', 3),
#  ('기강', 3),
#  ('나무', 3),
#  ('꺼져', 3),
#  ('전성기', 3),
#  ('상벌', 3),
#  ('소신', 3),
#  ('밑바닥', 3),
#  ('기관장', 3),
#  ('축제', 3),
#  ('역세권', 3),
#  ('BY', 3),
#  ('심도', 3),
#  ('프린터', 3),
#  ('스카이라운지', 3),
#  ('돼요', 3),
#  ('느린', 3),
#  ('답변', 3),
#  ('농정', 3),
#  ('그쪽', 3),
#  ('붙일', 3),
#  ('시그', 3),
#  ('수위', 3),
#  ('입문', 3),
#  ('고령', 3),
#  ('작업량', 3),
#  ('끝낼', 3),
#  ('판로', 3),
#  ('실제론', 3),
#  ('ㅜㅜ', 3),
#  ('일편', 3),
#  ('뽑힌', 3),
#  ('연타', 3),
#  ('휴로', 3),
#  ('징징', 3),
#  ('korea', 3),
#  ('갑작스런', 3),
#  ('표대', 3),
#  ('센트', 3),
#  ('지킨다면', 3),
#  ('일급', 3),
#  ('장함', 3),
#  ('3200', 3),
#  ('이긴', 3),
#  ('mba', 3),
#  ('사함', 3),
#  ('경호', 3),
#  ('미과', 3),
#  ('노인', 3),
#  ('연령층', 3),
#  ('nice', 3),
#  ('로인', 3),
#  ('둬서', 3),
#  ('거친', 3),
#  ('다각', 3),
#  ('라던가', 3),
#  ('Asia', 3),
#  ('Standard', 3),
#  ('터널', 3),
#  ('Career', 3),
#  ('자상', 3),
#  ('스테이', 3),
#  ('험한', 3),
#  ('인공', 3),
#  ('착각', 3),
#  ('오해', 3),
#  ('듣보잡', 3),
#  ('혁명', 3),
#  ('그리드', 3),
#  ('번듯', 3),
#  ('한국전력', 3),
#  ('이언', 3),
#  ('그간', 3),
#  ('무한정', 3),
#  ('몰래', 3),
#  ('자자', 3),
#  ('개구리', 3),
#  ('부러웠', 3),
#  ('소기업', 3),
#  ('입소문', 3),
#  ('날카로운', 3),
#  ('쓰일', 3),
#  ('어쨌든', 3),
#  ('냉난방', 3),
#  ('반장', 3),
#  ('앞자리', 3),
#  ('지냅니다', 3),
#  ('근대', 3),
#  ('눈치봐야', 3),
#  ('후자', 3),
#  ('ESS', 3),
#  ('DNA', 3),
#  ('가동', 3),
#  ('시행착오', 3),
#  ('친해서', 3),
#  ('양해', 3),
#  ('내려서', 3),
#  ('벗어남', 3),
#  ('고학력', 3),
#  ('골라서', 3),
#  ('본다는', 3),
#  ('위반', 3),
#  ('위로금', 3),
#  ('아쉬웠', 3),
#  ('쏠쏠히', 3),
#  ('캐리비안', 3),
#  ('택할', 3),
#  ('명사', 3),
#  ('토의', 3),
#  ('파트너십', 3),
#  ('약점', 3),
#  ('플라스틱', 3),
#  ('모태', 3),
#  ('ms', 3),
#  ('전계', 3),
#  ('더할', 3),
#  ('간간이', 3),
#  ('데이트', 3),
#  ('서지원', 3),
#  ('초급', 3),
#  ('...............', 3),
#  ('애교', 3),
#  ('뻔한', 3),
#  ('제하', 3),
#  ('부릅니다', 3),
#  ('Valeo', 3),
#  ('깐깐', 3),
#  ('HKMC', 3),
#  ('DCT', 3),
#  ('시킨다는', 3),
#  ('주물', 3),
#  ('놀라운', 3),
#  ('경영인', 3),
#  ('에스', 3),
#  ('lg', 3),
#  ('월별', 3),
#  ('부사', 3),
#  ('극한', 3),
#  ('자름', 3),
#  ('민노총', 3),
#  ('분임', 3),
#  ('쓰려', 3),
#  ('상어', 3),
#  ('반찬', 3),
#  ('불러서', 3),
#  ('캐리', 3),
#  ('만하면', 3),
#  ('밤새', 3),
#  ('모니터링', 3),
#  ('수긍', 3),
#  ('인쇄', 3),
#  ('출력', 3),
#  ('부스', 3),
#  ('해체', 3),
#  ('원두커피', 3),
#  ('나타낼', 3),
#  ('초초', 3),
#  ('비데이', 3),
#  ('권력', 3),
#  ('돋보일', 3),
#  ('슬로건', 3),
#  ('몰라서', 3),
#  ('합류', 3),
#  ('위한다는', 3),
#  ('다녀요', 3),
#  ('영업부', 3),
#  ('본보기', 3),
#  ('과감히', 3),
#  ('빌라', 3),
#  ('패키지', 3),
#  ('트랜', 3),
#  ('16000', 3),
#  ('지탱', 3),
#  ('TV', 3),
#  ('사규', 3),
#  ('공백', 3),
#  ('예쁩니다', 3),
#  ('안타까움', 3),
#  ('날로', 3),
#  ('벌리', 3),
#  ('project', 3),
#  ('식힐', 3),
#  ('물씬', 3),
#  ('시달릴', 3),
#  ('테이', 3),
#  ('성추행', 3),
#  ('계고', 3),
#  ('learning', 3),
#  ('커넥션', 3),
#  ('수임', 3),
#  ('추정', 3),
#  ('모음', 3),
#  ('kpmg', 3),
#  ('뚜렷이', 3),
#  ('아래층', 3),
#  ('cross', 3),
#  ('대한항공', 3),
#  ('미안', 3),
#  ('부른다', 3),
#  ('뮤지컬', 3),
#  ('보여진다', 3),
#  ('뒷담', 3),
#  ('선수', 3),
#  ('무대', 3),
#  ('갈지', 3),
#  ('돈벌이', 3),
#  ('개근', 3),
#  ('멀티', 3),
#  ('팝콘', 3),
#  ('실업', 3),
#  ('흡연자', 3),
#  ('엔지', 3),
#  ('나와도', 3),
#  ('중압감', 3),
#  ('악한', 3),
#  ('걸린다면', 3),
#  ('관장', 3),
#  ('리포트', 3),
#  ('가르칠', 3),
#  ('립니', 3),
#  ('무동', 3),
#  ('라운', 3),
#  ('골프장', 3),
#  ('고집', 3),
#  ('종업', 3),
#  ('일머리', 3),
#  ('여외', 3),
#  ('대금', 3),
#  ('외투', 3),
#  ('주니어급', 3),
#  ('펼쳐볼', 3),
#  ('asset', 3),
#  ('본사내', 3),
#  ('IBMer', 3),
#  ('고스란히', 3),
#  ('침체', 3),
#  ('소수자', 3),
#  ('놀라울', 3),
#  ('비엠', 3),
#  ('발행', 3),
#  ('free', 3),
#  ('다져진', 3),
#  ('new', 3),
#  ('라이브러리', 3),
#  ('Local', 3),
#  ('경로', 3),
#  ('가져도', 3),
#  ('companies', 3),
#  ('ownership', 3),
#  ('also', 3),
#  ('if', 3),
#  ('are', 3),
#  ('선구자', 3),
#  ('범용', 3),
#  ('코스피', 3),
#  ('버텨온', 3),
#  ('어느새', 3),
#  ('리서', 3),
#  ('치사', 3),
#  ('간담회', 3),
#  ('부려', 3),
#  ('etc', 3),
#  ('기장', 3),
#  ('어릴', 3),
#  ('순해서', 3),
#  ('아이유', 3),
#  ('치여서', 3),
#  ('취업자', 3),
#  ('레딧', 3),
#  ('애널리스트', 3),
#  ('커리', 3),
#  ('크라', 3),
#  ('조달', 3),
#  ('따른다', 3),
#  ('역시', 3),
#  ('고취', 3),
#  ('굵직굵직', 3),
#  ('Creative', 3),
#  ('명실상부', 3),
#  ('요금', 3),
#  ('사시', 3),
#  ('성사', 3),
#  ('익혀', 3),
#  ('월급쟁이', 3),
#  ('양보', 3),
#  ('팀플레이', 3),
#  ('바닷가', 3),
#  ('생물학', 3),
#  ('고장', 3),
#  ('돌아다녀', 3),
#  ('엘레', 3),
#  ('쓸모', 3),
#  ('급급', 3),
#  ('확실이', 3),
#  ('지유', 3),
#  ('동경', 3),
#  ('지났', 3),
#  ('MS', 3),
#  ('써볼', 3),
#  ('이뤄졌', 3),
#  ('UI', 3),
#  ('관료', 3),
#  ('찮음', 3),
#  ('없애', 3),
#  ('무한리필', 3),
#  ('평점', 3),
#  ('엔드', 3),
#  ('대관', 3),
#  ('마당', 3),
#  ('상상마당', 3),
#  ('숙사', 3),
#  ('결혼식', 3),
#  ('긴다', 3),
#  ('현대제철', 3),
#  ('결금', 3),
#  ('졸자', 3),
#  ('갑과', 3),
#  ('파이팅', 3),
#  ('사안', 3),
#  ('헬스클럽', 3),
#  ('모비스', 3),
#  ('지체', 3),
#  ('관심사', 3),
#  ('기획사', 3),
#  ('모호', 3),
#  ('해져', 3),
#  ('장정', 3),
#  ('떨어진다', 3),
#  ('독서실', 3),
#  ('동문', 3),
#  ('이대', 3),
#  ('못한다고', 3),
#  ('운항', 3),
#  ('................', 3),
#  ('MRO', 3),
#  ('메스', 3),
#  ('몸값', 3),
#  ('지소', 3),
#  ('쎕니다', 3),
#  ('외곽', 3),
#  ('돌봐', 3),
#  ('따라갈', 3),
#  ('kb', 3),
#  ('피라미드형', 3),
#  ('고로케', 3),
#  ('쌰의쌰하는', 3),
#  ('노무', 3),
#  ('견뎌야', 3),
#  ('집기', 3),
#  ('역삼동', 3),
#  ('매식', 3),
#  ('통폐합', 3),
#  ('건대', 3),
#  ('본교', 3),
#  ('쓴다면', 3),
#  ('싸이코', 3),
#  ('갈릴', 3),
#  ('고착', 3),
#  ('망한다', 3),
#  ('터져', 3),
#  ('아스팔트', 3),
#  ('참견', 3),
#  ('청정기', 3),
#  ('시판', 3),
#  ('실리', 3),
#  ('구현', 3),
#  ('적립금', 3),
#  ('커갈', 3),
#  ('파업', 3),
#  ('가슴', 3),
#  ('출도', 3),
#  ('귀가', 3),
#  ('일본인', 3),
#  ('알아봐', 3),
#  ('비투비', 3),
#  ('활황', 3),
#  ('화끈', 3),
#  ('next', 3),
#  ('인도네시아', 3),
#  ('SKT', 3),
#  ('VIP', 3),
#  ('발현', 3),
#  ('다이렉트', 3),
#  ('겉모습', 3),
#  ('아이맥', 3),
#  ('OS', 3),
#  ('경품', 3),
#  ('이용자', 3),
#  ('버텨', 3),
#  ('교육열', 3),
#  ('떄도', 3),
#  ('경계선', 3),
#  ('버드', 3),
#  ('수상', 3),
#  ('구색', 3),
#  ('임팩트', 3),
#  ('open', 3),
#  ('collaboration', 3),
#  ('질투', 3),
#  ('업적', 3),
#  ('레전드', 3),
#  ('관습', 3),
#  ('부흥', 3),
#  ('아침잠', 3),
#  ('전면', 3),
#  ('타자', 3),
#  ('점진', 3),
#  ('버릴', 3),
#  ('배고픔', 3),
#  ('달랠', 3),
#  ('넘쳐서', 3),
#  ('국외', 3),
#  ('도매', 3),
#  ('재부', 3),
#  ('최상위권', 3),
#  ('최전선', 3),
#  ('그리워', 3),
#  ('갖춰졌', 3),
#  ('skill', 3),
#  ('둘러싸여', 3),
#  ('냉정', 3),
#  ('두뇌', 3),
#  ('Function', 3),
#  ('experience', 3),
#  ('생가', 3),
#  ('매리', 3),
#  ('메트로', 3),
#  ('어마', 3),
#  ('외지', 3),
#  ('궤도', 3),
#  ('충돌', 3),
#  ('지금껏', 3),
#  ('배드민턴', 3),
#  ('걸렸', 3),
#  ('미진', 3),
#  ('삭감', 3),
#  ('정인', 3),
#  ('시원시원', 3),
#  ('추측', 3),
#  ('인금', 3),
#  ('메세지', 3),
#  ('군필', 3),
#  ('atmosphere', 3),
#  ('profile', 3),
#  ('토픽', 3),
#  ('needs', 3),
#  ('fun', 3),
#  ('Ra', 3),
#  ('Brand', 3),
#  ('BIG', 3),
#  ('OK', 3),
#  ('영종도', 3),
#  ('쌥니다', 3),
#  ('재벌', 3),
#  ('가업', 3),
#  ('항공료', 3),
#  ('금융인', 3),
#  ('나무랄', 3),
#  ('탐사', 3),
#  ('임용', 3),
#  ('불리', 3),
#  ('신장', 3),
#  ('감정싸움', 3),
#  ('부정부패', 3),
#  ('실행력', 3),
#  ('들으러', 3),
#  ('초입', 3),
#  ('도메인', 3),
#  ('BIFC', 3),
#  ('국회의사당', 3),
#  ('흐뭇', 3),
#  ('미약', 3),
#  ('항만', 3),
#  ('일과', 3),
#  ('at', 3),
#  ('밀집', 3),
#  ('비축', 3),
#  ('질책', 3),
#  ('동기간', 3),
#  ('루즈', 3),
#  ('타격', 3),
#  ('북카페', 3),
#  ('지켜본', 3),
#  ('장부', 3),
#  ('사비', 3),
#  ('수집', 3),
#  ('갈림', 3),
#  ('된다거나', 3),
#  ('촉박', 3),
#  ('초고', 3),
#  ('UAE', 3),
#  ('구멍가게', 3),
#  ('어려우나', 3),
#  ('신용보증기금', 3),
#  ('이럴', 3),
#  ('가진다고', 3),
#  ('비스', 3),
#  ('240', 3),
#  ('흘러', 3),
#  ('내사', 3),
#  ('부합', 3),
#  ('세밀', 3),
#  ('지기', 3),
#  ...]

# %%
c_5_ls=[]

for z in range(len(c_5)):
    c_5_ls.append(c_5[z][0])
#5개 이하 리스트로만들기

# %%
ls_total=[]

s = set(c_5_ls)
for i in tqdm_notebook(range(len(total_word))):
    ls = [x for x in total_word[i] if x not in s]
    ls_total.append(ls)
    
# 5개 이하 빼기
# Out:
# c:\users\kym\.conda\envs\venv\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
#   0%|          | 0/45815 [00:00<?, ?it/s]

# %% [markdown]
# # 문서 최대 길이 구하기

# %%
from collections import Counter

# %%
max_len =[]
for i in range(len(total_word)):
    max_len.append(len(total_word[i]))

max(max_len)
# Out:
# 162

# %%
count_len = Counter(max_len).most_common()
cnt_sort = count_len.sort(reverse=True)
count_len
# Out:
# [(162, 3),
#  (155, 1),
#  (150, 1),
#  (141, 1),
#  (139, 1),
#  (137, 1),
#  (135, 1),
#  (134, 1),
#  (126, 1),
#  (125, 1),
#  (120, 1),
#  (118, 1),
#  (117, 1),
#  (112, 1),
#  (108, 1),
#  (107, 1),
#  (105, 1),
#  (104, 3),
#  (103, 13),
#  (102, 2),
#  (100, 3),
#  (99, 2),
#  (98, 2),
#  (95, 4),
#  (94, 1),
#  (93, 1),
#  (91, 1),
#  (89, 4),
#  (88, 1),
#  (85, 1),
#  (83, 2),
#  (82, 4),
#  (81, 6),
#  (80, 2),
#  (79, 3),
#  (78, 3),
#  (77, 3),
#  (76, 2),
#  (75, 3),
#  (74, 2),
#  (73, 4),
#  (72, 3),
#  (71, 3),
#  (70, 3),
#  (69, 5),
#  (68, 7),
#  (67, 3),
#  (66, 4),
#  (65, 6),
#  (64, 5),
#  (63, 4),
#  (62, 5),
#  (61, 10),
#  (60, 7),
#  (59, 9),
#  (58, 4),
#  (57, 5),
#  (56, 8),
#  (55, 16),
#  (54, 5),
#  (53, 10),
#  (52, 6),
#  (51, 8),
#  (50, 20),
#  (49, 20),
#  (48, 15),
#  (47, 24),
#  (46, 23),
#  (45, 20),
#  (44, 25),
#  (43, 28),
#  (42, 46),
#  (41, 31),
#  (40, 40),
#  (39, 37),
#  (38, 39),
#  (37, 79),
#  (36, 45),
#  (35, 51),
#  (34, 58),
#  (33, 70),
#  (32, 94),
#  (31, 88),
#  (30, 120),
#  (29, 123),
#  (28, 132),
#  (27, 158),
#  (26, 228),
#  (25, 256),
#  (24, 261),
#  (23, 303),
#  (22, 392),
#  (21, 436),
#  (20, 509),
#  (19, 615),
#  (18, 798),
#  (17, 862),
#  (16, 1190),
#  (15, 1414),
#  (14, 1711),
#  (13, 1957),
#  (12, 2420),
#  (11, 2913),
#  (10, 3596),
#  (9, 4213),
#  (8, 4765),
#  (7, 4724),
#  (6, 4337),
#  (5, 3310),
#  (4, 1860),
#  (3, 803),
#  (2, 255),
#  (1, 69),
#  (0, 5)]

# %% [markdown]
# ### 문서 길이 데이터 시각화 및 정규분포화

# %%
import matplotlib.pyplot as plt

# %%
len_data = []

for i in range(len(ls_total)):
    len_data.append(len(ls_total[i]))

# %%
plt.hist(len_data, bins=50)
plt.show()

# %% [markdown]
# # 불용어, 불용품사, 1글자 토큰 제거 후 토큰이 없는 리뷰 제거

# %%
for i in range(len(total_word)-1, -1 , -1):
    if len(total_word[i]) == 0:
        del total_word[i]

# %%
len(total_word)
# Out:
# 38086

# %% [markdown]
# # Train, Test 나누기

# %%
x_train = total_word[:30400]
x_test = total_word[30400:]
y_train = total_data['label'][:30400].values.tolist()
y_test = total_data['label'][30400:].values.tolist()

# %% [markdown]
# # Padding

# %%
# Sequence Length를 맞추기 위한 padding
def add_padding(token_ls, max_len):
    pad = '<PAD>'
    seq_length_ls = []
    
    for i, tokens in enumerate(token_ls):
        seq_length = len(tokens)
        
        # 짧으면 padding을 추가
        if seq_length < max_len:
            seq_length_ls.append(seq_length)
            token_ls[i] += [pad] * (max_len - seq_length)
        
        # 길이가 길면, max_len까지의 token만 사용
        elif seq_length >= max_len:
            seq_length_ls.append(max_len)
            token_ls[i] = tokens[:max_len]
            
    return token_ls, seq_length_ls

# %%
max_sequence_length = 50
x_train, x_train_seq_length = add_padding(x_train, max_sequence_length)
x_test, x_test_seq_length = add_padding(x_test, max_sequence_length)

# %% [markdown]
# # Converting token to index

# %%
# 단어에 대한 idx 부여
def convert_token_to_idx(token_ls):
    for tokens in token_ls:
        yield [token2idx[token] for token in tokens]
    return

# %%
token2idx = defaultdict(lambda: len(token2idx))
pad = token2idx['<PAD>']

x_train = list(convert_token_to_idx(x_train))
x_test = list(convert_token_to_idx(x_test))

idx2token = {val : key for key,val in token2idx.items()}

# %%
' '.join([idx2token[x] for x in x_train[30]])
# Out:
# '회사 재무 구조 걱정 없이 오래 회사 직원 누릴 복지 업계 상위 연봉 중상 커리어 시작 사회 초년병 추천 회사 <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'

# %% [markdown]
# ### Packing을 위해, 긴 문장이 위로 오도록 순서를 sorting and Variable로 변환

# %%
def sort_by_sequence_length(x, y, seq_len):
    sorted_idx = np.argsort(np.array(seq_len))[::-1]
    
    x = Variable(torch.LongTensor(np.array(x)[sorted_idx]))
    y = Variable(torch.LongTensor(np.array(y)[sorted_idx]))
    seq_len = Variable(torch.LongTensor(np.array(seq_len)[sorted_idx]))
    
    return x, y, seq_len

# %%
x_train, y_train, x_train_seq_length = sort_by_sequence_length(x_train, y_train, x_train_seq_length)
x_test, y_test, x_test_seq_length = sort_by_sequence_length(x_test, y_test, x_test_seq_length)

# %% [markdown]
# # Pretrain 된 word2vec 모델 벡터 값 불러오기

# %%
# import gensim

# wv_model = gensim.models.KeyedVectors.load('Word2vec_model')
# weights = torch.FloatTensor(wv_model.wv.vectors)

# %%
# embedding = nn.Embedding.from_pretrained(weights)
# # Get embeddings for index 1
# input = torch.LongTensor([1])
# embedding(input)

# %% [markdown]
# # LSTM

# %%
class LSTM(nn.Module):
    def __init__(self, token2idx, max_sequence, vocab_size, embed_size, hid_size, n_layers, dropout, bidirectional, n_category):
        super(LSTM, self).__init__() 
        self.vocab_size = vocab_size                # 고유한 단어의 수
        self.embed_size = embed_size                # 임베딩 차원의 크기
        self.padding_index = token2idx['<PAD>']     # 패딩 토큰
        
        self.embed = nn.Embedding(
            num_embeddings=vocab_size, 
            embedding_dim=embed_size, 
            padding_idx=self.padding_index
        )
        
        self.max_sequence = max_sequence           # 한 문장의 최대 길이
        self.hid_size = hid_size                   # LSTM 뉴런의 갯수
        self.n_layers = n_layers                   # LSTM layer의 수
        self.drouput = dropout                     # 드롭아웃
        self.n_category = n_category               # 분류 카테고리 갯수
        self.bidirectional = bidirectional         # optinal, True : bidirectional 
        
        self.lstm = nn.LSTM(embed_size, hid_size, n_layers, batch_first=True, bidirectional=True)
        
        if bidirectional:
            input_dim = 2*hid_size*max_sequence
        else:
            input_dim = hid_size*max_sequence

        self.lin = nn.Linear(input_dim, n_category)
        self.outputs = []
        
    def init_hidden(self, batch_size):
        # 최초에 h_0와 c_0의 초기값 부여 (n_layers, batch_size, hid_size(n_neuron))
        # bidirectional일 경우, (2*n_layers, batch_size, hid_size)
        if self.bidirectional:
            h_0 = Variable(torch.randn(2*self.n_layers, batch_size, self.hid_size)) * 0.1
            c_0 = Variable(torch.randn(2*self.n_layers, batch_size, self.hid_size)) * 0.1
        else:
            h_0 = Variable(torch.randn(self.n_layers, batch_size, self.hid_size)) * 0.1
            c_0 = Variable(torch.randn(self.n_layers, batch_size, self.hid_size)) * 0.1
        return (h_0, c_0)    
    
    def forward(self, x, x_sequence_length):
        # init h randomly
        batch_size = x.size(0)
        self.h_c = self.init_hidden(batch_size)
        
        # embedding
        x = self.embed(x) # sequence_length(max_len), batch_size, embed_size
        
        # packing for LSTM
        x = torch.nn.utils.rnn.pack_padded_sequence(x, x_sequence_length, batch_first=True)
        
        # LSTM
        output, self.h_c = self.lstm(x, self.h_c)
        
        # unpack
        # unpacking 과정에서, size(1) S가 가장 긴 sequence 길이를 갖는 data에 맞춰진다.
        # S가 max_sequence_length로 고정되는 것이 아님을 주의
        x, _ = torch.nn.utils.rnn.pad_packed_sequence(output, batch_first=True)
        #print(x.shape)
        
        # flatten
        x = x.contiguous()
        x = x.view(batch_size, -1)
        
        # fully-connect
        logit = self.lin(x)
        
        return logit

# %%
params = {
    'token2idx' : token2idx,
    'max_sequence' : 50,
    'vocab_size' : len(token2idx),
    'embed_size' : 30,
    'hid_size' : 32,
    'n_layers' : 2,
    'dropout' : 0.5,
    'bidirectional' : True,
    'n_category' : 5
}

# %%
model = LSTM(**params)

# %%
model
# Out:
# LSTM(
#   (embed): Embedding(13974, 30, padding_idx=0)
#   (lstm): LSTM(30, 32, num_layers=2, batch_first=True, bidirectional=True)
#   (lin): Linear(in_features=3200, out_features=5, bias=True)
# )

# %% [markdown]
# # Train

# %%
def adjust_learning_rate(optimizer, epoch, init_lr=0.001, lr_decay_epoch=10):
    """Decay learning rate by a factor of 0.1 every lr_decay_epoch epochs."""
    lr = init_lr * (0.1**(epoch // lr_decay_epoch))

    if epoch % lr_decay_epoch == 0:
        print('LR is set to %s'%(lr))

    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

    return optimizer

# %%
epochs = 20
lr = 0.01
batch_size = 10000

train_idx = np.arange(x_train.size(0))
test_idx = np.arange(x_test.size(0))
optimizer = torch.optim.Adam(model.parameters(),lr)
criterion = nn.CrossEntropyLoss(reduction='sum')

loss_ls = []

for epoch in range(1, epochs+1):
    model.train()
    
    # input 데이터 순서 섞기
    random.shuffle(train_idx)
    x_train, y_train = x_train[train_idx], y_train[train_idx]
    x_train_seq_length = x_train_seq_length[train_idx]
    
    train_loss = 0
    
    for start_idx, end_idx in zip(range(0, x_train.size(0), batch_size),
                                  range(batch_size, x_train.size(0)+1, batch_size)):
        # batch 뽑기
        x_batch = x_train[start_idx : end_idx]
        y_batch = y_train[start_idx : end_idx].long()
        x_batch_seq_length = x_train_seq_length[start_idx: end_idx]
        
        # sequence 순서대로 정렬하기
        x_batch, y_batch, x_batch_seq_length = sort_by_sequence_length(x_batch, y_batch, x_batch_seq_length)
        
        scores = model(x_batch, x_batch_seq_length)
        predict = F.softmax(scores, dim=1).argmax(dim = 1)
        
        acc = (predict == y_batch).sum().item() / batch_size
        
        loss = criterion(scores, y_batch)
        train_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print('Train epoch : %s,  loss : %s,  accuracy :%.3f'%(epoch, train_loss / batch_size, acc))
    print('=================================================================================================')
    
    loss_ls.append(train_loss)
    optimizer = adjust_learning_rate(optimizer, epoch, lr, 100) # adjust learning_rate while training
    
    if (epoch) % 5 == 0:
        model.eval()
        scores = model(x_test, x_test_seq_length)
        predict = F.softmax(scores, dim=1).argmax(dim = 1)
        
        acc = (predict == y_test.long()).sum().item() / y_test.size(0)
        loss = criterion(scores, y_test.long())
        
        print('*************************************************************************************************')
        print('*************************************************************************************************')
        print('Test Epoch : %s, Test Loss : %.03f , Test Accuracy : %.03f'%(epoch, loss.item()/y_test.size(0), acc))
        print('*************************************************************************************************')
        print('*************************************************************************************************')
# Out:
# Train epoch : 1,  loss : 4.76512744140625,  accuracy :0.294
# =================================================================================================
# Train epoch : 2,  loss : 4.51932783203125,  accuracy :0.380
# =================================================================================================
# Train epoch : 3,  loss : 4.20841650390625,  accuracy :0.429
# =================================================================================================
# Train epoch : 4,  loss : 3.93385419921875,  accuracy :0.477
# =================================================================================================
# Train epoch : 5,  loss : 3.69765224609375,  accuracy :0.514
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Test Epoch : 5, Test Loss : 1.278 , Test Accuracy : 0.476
# *************************************************************************************************
# *************************************************************************************************
# Train epoch : 6,  loss : 3.467755859375,  accuracy :0.543
# =================================================================================================
# Train epoch : 7,  loss : 3.2453755859375,  accuracy :0.582
# =================================================================================================
# Train epoch : 8,  loss : 3.03221015625,  accuracy :0.609
# =================================================================================================
# Train epoch : 9,  loss : 2.83741484375,  accuracy :0.638
# =================================================================================================
# Train epoch : 10,  loss : 2.665146875,  accuracy :0.669
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Test Epoch : 10, Test Loss : 1.182 , Test Accuracy : 0.562
# *************************************************************************************************
# *************************************************************************************************
# Train epoch : 11,  loss : 2.504333740234375,  accuracy :0.694
# =================================================================================================
# Train epoch : 12,  loss : 2.3517787109375,  accuracy :0.702
# =================================================================================================
# Train epoch : 13,  loss : 2.21214931640625,  accuracy :0.722
# =================================================================================================
# Train epoch : 14,  loss : 2.08870498046875,  accuracy :0.742
# =================================================================================================
# Train epoch : 15,  loss : 1.979692431640625,  accuracy :0.764
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Test Epoch : 15, Test Loss : 1.245 , Test Accuracy : 0.568
# *************************************************************************************************
# *************************************************************************************************
# Train epoch : 16,  loss : 1.859832958984375,  accuracy :0.771
# =================================================================================================
# Train epoch : 17,  loss : 1.760348583984375,  accuracy :0.781
# =================================================================================================
# Train epoch : 18,  loss : 1.661493212890625,  accuracy :0.797
# =================================================================================================
# Train epoch : 19,  loss : 1.56320546875,  accuracy :0.807
# =================================================================================================
# Train epoch : 20,  loss : 1.466440625,  accuracy :0.824
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Test Epoch : 20, Test Loss : 1.417 , Test Accuracy : 0.581
# *************************************************************************************************
# *************************************************************************************************
